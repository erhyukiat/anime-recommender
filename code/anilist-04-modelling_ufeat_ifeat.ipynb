# %% [markdown]
# # Anime Recommender 04: Modelling and Conclusion

# %% [markdown]
# ## LightFM model with user features and item features
#
# Identified 6 possible variants of user features and will pick the feature that yields the best model scores
# - User feature type 1: Genres that the user likes (defined as genres of animes that the user has rated equal to or greater than their average rating)
# - User feature type 2: Genres that the user likes (defined as genres of animes that the user has rated equal to or greater than their 75th percentile rating)
# - User feature type 3: Top 3 genres among the genres that the user likes (defined as top 3 genres of animes that the user has rated equal to or greater than their average rating)
# - User feature type 4: Top 5 genres among the genres that the user likes (defined as top 5 genres of animes that the user has rated equal to or greater than their average rating)
# - User feature type 5: Top 3 genres among the genres that the user likes (defined as top 3 genres of animes that the user has rated equal to or greater than their 75th percentile rating)
# - User feature type 6: Top 5 genres among the genres that the user likes (defined as top 5 genres of animes that the user has rated equal to or greater than their 75th percentile rating)

# %% [markdown]
# ## Imports

# %%
import time
import itertools
import pandas as pd
import numpy as np
import pickle

from lightfm import LightFM
from lightfm.data import Dataset
from lightfm import cross_validation
from lightfm.evaluation import precision_at_k as lightfm_prec_at_k
from lightfm.evaluation import recall_at_k as lightfm_recall_at_k, auc_score
from lightfm.evaluation import reciprocal_rank as lightfm_reciprocal_rank
from recommenders.models.lightfm.lightfm_utils import similar_items
from scipy import sparse
from tqdm import tqdm
from tqdm.auto import trange
# Out:
# C:\Users\Internet\anaconda3\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(

# %%
# default number of recommendations
K = 10
# percentage of data used for testing
TEST_PERCENTAGE = 0.25
# no of threads to fit model
NO_THREADS = 32
# seed for pseudonumber generations
SEEDNO = 42

# %%
data = pd.read_pickle("../data/users_db_feateng.pkl")
print(data.shape)
data.head()
# Out:
# (912234, 10)
#    user_id  media_id  rating  \
# 0   710080      1535      70
# 1   710080     21459      70
# 2   710080    113415      70
# 3   710080     11757      70
# 4   710080      5114      70
#
#                                              genres  \
# 0  [Mystery, Psychological, Supernatural, Thriller]
# 1                       [Action, Adventure, Comedy]
# 2                     [Action, Drama, Supernatural]
# 3             [Action, Adventure, Fantasy, Romance]
# 4               [Action, Adventure, Drama, Fantasy]
#
#                                     liked_genres_avg  \
# 0  [Action, Adventure, Comedy, Drama, Ecchi, Fant...
# 1  [Action, Adventure, Comedy, Drama, Ecchi, Fant...
# 2  [Action, Adventure, Comedy, Drama, Ecchi, Fant...
# 3  [Action, Adventure, Comedy, Drama, Ecchi, Fant...
# 4  [Action, Adventure, Comedy, Drama, Ecchi, Fant...
#
#                                   liked_genres_75pct         top_3_genres_avg  \
# 0  [Action, Adventure, Comedy, Drama, Ecchi, Fant...  [Action, Comedy, Drama]
# 1  [Action, Adventure, Comedy, Drama, Ecchi, Fant...  [Action, Comedy, Drama]
# 2  [Action, Adventure, Comedy, Drama, Ecchi, Fant...  [Action, Comedy, Drama]
# 3  [Action, Adventure, Comedy, Drama, Ecchi, Fant...  [Action, Comedy, Drama]
# 4  [Action, Adventure, Comedy, Drama, Ecchi, Fant...  [Action, Comedy, Drama]
#
#                                  top_5_genres_avg       top_3_genres_75pct  \
# 0  [Action, Comedy, Drama, Fantasy, Supernatural]  [Action, Comedy, Drama]
# 1  [Action, Comedy, Drama, Fantasy, Supernatural]  [Action, Comedy, Drama]
# 2  [Action, Comedy, Drama, Fantasy, Supernatural]  [Action, Comedy, Drama]
# 3  [Action, Comedy, Drama, Fantasy, Supernatural]  [Action, Comedy, Drama]
# 4  [Action, Comedy, Drama, Fantasy, Supernatural]  [Action, Comedy, Drama]
#
#                                 top_5_genres_75pct
# 0  [Action, Comedy, Drama, Fantasy, Slice of Life]
# 1  [Action, Comedy, Drama, Fantasy, Slice of Life]
# 2  [Action, Comedy, Drama, Fantasy, Slice of Life]
# 3  [Action, Comedy, Drama, Fantasy, Slice of Life]
# 4  [Action, Comedy, Drama, Fantasy, Slice of Life]

# %%
anime_id_map = pd.read_pickle("../data/anime_id_mapping.pkl")
print(anime_id_map.shape)
anime_id_map.head()
# Out:
# (6195, 4)
#    id                     title_romaji  \
# 0   1                     Cowboy Bebop
# 1   5  Cowboy Bebop: Tengoku no Tobira
# 2   6                           TRIGUN
# 3   7               Witch Hunter ROBIN
# 4   8                   Bouken Ou Beet
#
#                                        title_english  \
# 0                                       Cowboy Bebop
# 1  Cowboy Bebop: The Movie - Knockin' on Heaven's...
# 2                                             Trigun
# 3                                 Witch Hunter ROBIN
# 4                             Beet the Vandel Buster
#
#                                        genres
# 0          [Action, Adventure, Drama, Sci-Fi]
# 1            [Action, Drama, Mystery, Sci-Fi]
# 2  [Action, Adventure, Comedy, Drama, Sci-Fi]
# 3      [Action, Drama, Mystery, Supernatural]
# 4          [Adventure, Fantasy, Supernatural]

# %%
anime_id_map.rename(columns={'id':'media_id'},inplace=True)

# %%
def format_newuser_input(user_feature_map, user_feature_list):
    #user_feature_map = user_feature_map  
    num_features = len(user_feature_list)
    normalised_val = 1.0 
    target_indices = []
    for feature in user_feature_list:
        try:
            target_indices.append(user_feature_map[feature])
        except KeyError:
            print(f"new user feature encountered '{feature}'")
            pass
    #print("target indices: {}".format(target_indices))
    new_user_features = np.zeros(len(user_feature_map.keys()))
    for i in target_indices:
        new_user_features[i] = normalised_val
    new_user_features = sparse.csr_matrix(new_user_features)
    return(new_user_features)

# %% [markdown]
# ## Baseline model

# %%
dataset_baseline = Dataset()

# %%
dataset_baseline.fit(data['user_id'],data['media_id'])

# %%
(interactions_baseline, weights_baseline) = dataset_baseline.build_interactions(data.iloc[:, 0:3].values)

# %%
train_interactions_baseline, test_interactions_baseline = cross_validation.random_train_test_split(interactions_baseline, 
                                                                                 test_percentage=TEST_PERCENTAGE, 
                                                                                 random_state = np.random.RandomState(SEEDNO))

# %%
model_baseline = LightFM(loss='warp', no_components = 10,
               learning_rate=.25,
               item_alpha=1e-6,
                random_state=np.random.RandomState(SEEDNO))

# %%
model_baseline.fit(interactions=train_interactions_baseline);

# %%
train_roc_auc_baseline = auc_score(model_baseline,train_interactions_baseline).mean()
test_roc_auc_baseline = auc_score(model_baseline,test_interactions_baseline).mean()
train_precision_lfm_baseline = lightfm_prec_at_k(model_baseline, train_interactions_baseline, k=K).mean()
test_precision_lfm_baseline = lightfm_prec_at_k(model_baseline, test_interactions_baseline, k=K).mean()
train_recall_lfm_baseline = lightfm_recall_at_k(model_baseline, train_interactions_baseline, k=K).mean()
test_recall_lfm_baseline = lightfm_recall_at_k(model_baseline, test_interactions_baseline, k=K).mean()
print("Baseline model")
print("=====AUC=====")
print(f'Train AUC: {train_roc_auc_baseline}')
print(f'Test AUC: {test_roc_auc_baseline}')
print("=====Precision@K=====")
print(f'Train Precision: {train_precision_lfm_baseline}')
print(f'Test Precision: {test_precision_lfm_baseline}')
print("=====Recall@K=====")
print(f'Train Recall: {train_recall_lfm_baseline}')
print(f'Test Recall: {test_recall_lfm_baseline}')
# Out:
# Baseline model
# =====AUC=====
# Train AUC: 0.5814570784568787
# Test AUC: 0.5537643432617188
# =====Precision@K=====
# Train Precision: 0.0014272527769207954
# Test Precision: 0.00034896068973466754
# =====Recall@K=====
# Train Recall: 0.0012337842748706763
# Test Recall: 0.0009256970245295735

# %% [markdown]
# ## User feature type 1: Genres that the user likes (defined as genres of animes that the user has rated equal to or greater than their average rating)

# %%
data1 = data[['user_id','media_id','rating','genres','liked_genres_avg']]
data1.head()
# Out:
#    user_id  media_id  rating  \
# 0   710080      1535      70
# 1   710080     21459      70
# 2   710080    113415      70
# 3   710080     11757      70
# 4   710080      5114      70
#
#                                              genres  \
# 0  [Mystery, Psychological, Supernatural, Thriller]
# 1                       [Action, Adventure, Comedy]
# 2                     [Action, Drama, Supernatural]
# 3             [Action, Adventure, Fantasy, Romance]
# 4               [Action, Adventure, Drama, Fantasy]
#
#                                     liked_genres_avg
# 0  [Action, Adventure, Comedy, Drama, Ecchi, Fant...
# 1  [Action, Adventure, Comedy, Drama, Ecchi, Fant...
# 2  [Action, Adventure, Comedy, Drama, Ecchi, Fant...
# 3  [Action, Adventure, Comedy, Drama, Ecchi, Fant...
# 4  [Action, Adventure, Comedy, Drama, Ecchi, Fant...

# %%
all_anime_genres1 = sorted(list(set(itertools.chain.from_iterable(data1['genres']))))

# %%
all_liked_genres1 = sorted(list(set(itertools.chain.from_iterable(data1['liked_genres_avg']))))

# %%
dataset1 = Dataset()

# %%
dataset1.fit(data1['user_id'],data1['media_id'],user_features=all_liked_genres1,item_features=all_anime_genres1)

# %%
item_features1 = dataset1.build_item_features((x,y) for x,y in zip(data1['media_id'],data1['genres']))

# %%
user_features1 = dataset1.build_user_features((x,y) for x,y in zip(data1['user_id'],data1['liked_genres_avg']))

# %%
(interactions1, weights1) = dataset1.build_interactions(data1.iloc[:, 0:3].values)

# %%
train_interactions1, test_interactions1 = cross_validation.random_train_test_split(interactions1, 
                                                                                 test_percentage=TEST_PERCENTAGE, 
                                                                                 random_state = np.random.RandomState(SEEDNO))

# %%
model1 = LightFM(loss='warp', no_components = 10,
               learning_rate=.25,
               item_alpha=1e-6,
                random_state=np.random.RandomState(SEEDNO))

# %%
model1.fit(interactions=train_interactions1,item_features=item_features1,user_features=user_features1,epochs=20);

# %%
train_roc_auc1 = auc_score(model1,train_interactions1,item_features=item_features1,user_features=user_features1).mean()
test_roc_auc1 = auc_score(model1,test_interactions1,item_features=item_features1,user_features=user_features1).mean()
train_precision_lfm1 = lightfm_prec_at_k(model1, train_interactions1,item_features=item_features1,user_features=user_features1, k=K).mean()
test_precision_lfm1 = lightfm_prec_at_k(model1, test_interactions1,item_features=item_features1,user_features=user_features1, k=K).mean()
train_recall_lfm1 = lightfm_recall_at_k(model1, train_interactions1,item_features=item_features1,user_features=user_features1, k=K).mean()
test_recall_lfm1 = lightfm_recall_at_k(model1, test_interactions1,item_features=item_features1,user_features=user_features1, k=K).mean()
print("User feature type 1: Genres that the user likes (defined as genres of animes that the user has rated equal to or greater than their average rating)")
print("=====AUC=====")
print(f'Train AUC: {train_roc_auc1}')
print(f'Test AUC: {test_roc_auc1}')
print("=====Precision@K=====")
print(f'Train Precision: {train_precision_lfm1}')
print(f'Test Precision: {test_precision_lfm1}')
print("=====Recall@K=====")
print(f'Train Recall: {train_recall_lfm1}')
print(f'Test Recall: {test_recall_lfm1}')
# Out:
# User feature type 1: Genres that the user likes (defined as genres of animes that the user has rated equal to or greater than their average rating)
# =====AUC=====
# Train AUC: 0.9531480073928833
# Test AUC: 0.9488025307655334
# =====Precision@K=====
# Train Precision: 0.2186678946018219
# Test Precision: 0.07796996086835861
# =====Recall@K=====
# Train Recall: 0.07146577015407743
# Test Recall: 0.06673994254823816

# %%
uid_map1, ufeature_map1, iid_map1, ifeature_map1 = dataset1.mapping()

# %%
iid_map1_reverse = dict((value,key) for key,value in iid_map1.items())

# %% [markdown]
# ### Predict for new user

# %%
# predict for new user
user_feature_list = ['Comedy','Romance','Slice of Life']

# %%
new_user_features = format_newuser_input(ufeature_map1, user_feature_list)

# %%
n_users1, n_items1 = interactions1.shape

# %%
model1_pred = model1.predict(0, np.arange(n_items1), user_features=new_user_features) # Here 0 means pick the first row of the user_features sparse matrix

# %%
pred_dict1 = {'media_id':data1['media_id'].unique(),'pred':model1_pred}

# %%
pred_df1 = pd.DataFrame(pred_dict1)

# %%
pred_df1 = pd.merge(pred_df1,anime_id_map,on='media_id')

# %%
pred_df1.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id         pred                            title_romaji  \
# 58      20923  5475.542480                      Shokugeki no Souma
# 221     20954  5404.202148                          Koe no Katachi
# 101     21087  3992.224854                           One Punch Man
# 199     21519  3892.060059                          Kimi no Na wa.
# 52      20665  3788.651367                 Shigatsu wa Kimi no Uso
# 11      19815  3738.680176                         No Game No Life
# 3       11757  3112.205566                        Sword Art Online
# 18      20594  2958.083252                     Sword Art Online II
# 104     21202  2848.407227  Kono Subarashii Sekai ni Shukufuku wo!
# 228     11061  2482.854248                    HUNTER×HUNTER (2011)
#
#                                          title_english  \
# 58                        Food Wars! Shokugeki no Soma
# 221                                     A Silent Voice
# 101                                      One-Punch Man
# 199                                         Your Name.
# 52                                   Your Lie in April
# 11                                    No Game, No Life
# 3                                     Sword Art Online
# 18                                 Sword Art Online II
# 104  KONOSUBA -God's blessing on this wonderful world!
# 228                             Hunter x Hunter (2011)
#
#                               relations  \
# 58                       [21518, 21691]
# 221                                None
# 101               [21416, 97668, 21386]
# 199                                None
# 52                              [21039]
# 11                       [20769, 21875]
# 3                [20021, 20594, 124140]
# 18        [20021, 21403, 100183, 11757]
# 104                      [21574, 21699]
# 228  [13271, 136, 137, 138, 139, 19951]
#
#                                      genres
# 58                          [Comedy, Ecchi]
# 221         [Drama, Romance, Slice of Life]
# 101  [Action, Comedy, Sci-Fi, Supernatural]
# 199          [Drama, Romance, Supernatural]
# 52   [Drama, Music, Romance, Slice of Life]
# 11      [Adventure, Comedy, Ecchi, Fantasy]
# 3     [Action, Adventure, Fantasy, Romance]
# 18     [Action, Adventure, Fantasy, Sci-Fi]
# 104            [Adventure, Comedy, Fantasy]
# 228            [Action, Adventure, Fantasy]

# %% [markdown]
# ### Predict for existing user

# %%
user_x = uid_map1[710080]
model1_pred_existing = model1.predict(user_x,np.arange(n_items1))

# %%
pred_dict1_existing = {'media_id':data1['media_id'].unique(),'pred':model1_pred_existing}

# %%
pred_df1_existing = pd.DataFrame(pred_dict1_existing)

# %%
pred_df1_existing = pd.merge(pred_df1_existing,anime_id_map,on='media_id')

# %%
pred_df1_existing.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id      pred                            title_romaji  \
# 58      20923  8.502268                      Shokugeki no Souma
# 221     20954  6.655103                          Koe no Katachi
# 199     21519  5.462017                          Kimi no Na wa.
# 454     21518  5.308857          Shokugeki no Souma: Ni no Sara
# 52      20665  5.293135                 Shigatsu wa Kimi no Uso
# 101     21087  5.286254                           One Punch Man
# 11      19815  5.257683                         No Game No Life
# 23     124080  4.928625                                Horimiya
# 104     21202  4.909211  Kono Subarashii Sekai ni Shukufuku wo!
# 18      20594  4.753656                     Sword Art Online II
#
#                                          title_english  \
# 58                        Food Wars! Shokugeki no Soma
# 221                                     A Silent Voice
# 199                                         Your Name.
# 454                        Food Wars! The Second Plate
# 52                                   Your Lie in April
# 101                                      One-Punch Man
# 11                                    No Game, No Life
# 23                                            Horimiya
# 104  KONOSUBA -God's blessing on this wonderful world!
# 18                                 Sword Art Online II
#
#                          relations                                  genres
# 58                  [21518, 21691]                         [Comedy, Ecchi]
# 221                           None         [Drama, Romance, Slice of Life]
# 199                           None          [Drama, Romance, Supernatural]
# 454          [20923, 98702, 99255]                         [Comedy, Ecchi]
# 52                         [21039]  [Drama, Music, Romance, Slice of Life]
# 101          [21416, 97668, 21386]  [Action, Comedy, Sci-Fi, Supernatural]
# 11                  [20769, 21875]     [Adventure, Comedy, Ecchi, Fantasy]
# 23                         [14753]        [Comedy, Romance, Slice of Life]
# 104                 [21574, 21699]            [Adventure, Comedy, Fantasy]
# 18   [20021, 21403, 100183, 11757]    [Action, Adventure, Fantasy, Sci-Fi]

# %% [markdown]
# ### Predict similar items

# %%
# Predicting for Yahari Ore no Seishun Love Come ga Machigatteiru.
# Comedy, Drama, Romance, Slice of Life
item_x = iid_map1[14813]

# %%
similar_pred1 = similar_items(item_id=item_x, item_features=item_features1, model=model1, N = 100)
similar_pred1['media_id'] = similar_pred1['itemID'].map(iid_map1_reverse)

# %%
similar_pred1 = pd.merge(similar_pred1,anime_id_map,on='media_id')

# %%
similar_pred1.sort_values('score',ascending=False).head(10)
# Out:
#     itemID  score  media_id  \
# 0       54    1.0      4224
# 4      118    1.0      6045
# 6      721    1.0     18671
# 5     1134    1.0    109261
# 1       63    1.0     14813
# 3      765    1.0    108489
# 2       65    1.0     14741
# 10     451    1.0       853
# 12     727    1.0     97766
# 11     224    1.0    103572
#
#                                          title_romaji  \
# 0                                           Toradora!
# 4                                      Kimi ni Todoke
# 6                  Chuunibyou demo Koi ga Shitai! Ren
# 5                              5-Toubun no Hanayome ∬
# 1   Yahari Ore no Seishun Love Come wa Machigatteiru.
# 3   Yahari Ore no Seishun Love Come wa Machigattei...
# 2                      Chuunibyou demo Koi ga Shitai!
# 10                             Ouran Koukou Host Club
# 12                                            Gamers!
# 11                               5-Toubun no Hanayome
#
#                                        title_english  \
# 0                                          Toradora!
# 4                     Kimi ni Todoke: From Me to You
# 6   Love, Chunibyo & Other Delusions - Heart Throb -
# 5                   The Quintessential Quintuplets 2
# 1                      My Teen Romantic Comedy SNAFU
# 3              My Teen Romantic Comedy SNAFU Climax!
# 2                   Love, Chunibyo & Other Delusions
# 10                       Ouran High School Host Club
# 12                                           GAMERS!
# 11                    The Quintessential Quintuplets
#
#                        relations                                   genres
# 0                  [6127, 11553]  [Comedy, Drama, Romance, Slice of Life]
# 4                         [9656]  [Comedy, Drama, Romance, Slice of Life]
# 6   [16934, 20582, 20777, 20889]  [Comedy, Drama, Romance, Slice of Life]
# 5               [103572, 131520]  [Comedy, Drama, Romance, Slice of Life]
# 1                 [18753, 20698]  [Comedy, Drama, Romance, Slice of Life]
# 3                [20698, 128643]  [Comedy, Drama, Romance, Slice of Life]
# 2   [16934, 15687, 15879, 19021]  [Comedy, Drama, Romance, Slice of Life]
# 10                          None  [Comedy, Drama, Romance, Slice of Life]
# 12                          None  [Comedy, Drama, Romance, Slice of Life]
# 11                      [109261]  [Comedy, Drama, Romance, Slice of Life]

# %% [markdown]
# ### Preliminary analysis for user feature type 1

# %% [markdown]
# Top 10 predictions for new and existing user are almost the same, but in different order for some titles. Model might just be predicting animes that are highly rated, and majority of the top 10 predictions are also the most popular animes based on the EDA of the dataset.
#
# The predictions for similar items look extremely good.

# %% [markdown]
# ## User feature type 2: Genres that the user likes (defined as genres of animes that the user has rated equal to or greater than their 75th percentile rating)

# %%
data2 = data[['user_id','media_id','rating','genres','liked_genres_75pct']]

# %%
all_anime_genres2 = sorted(list(set(itertools.chain.from_iterable(data2['genres']))))

# %%
all_liked_genres2 = sorted(list(set(itertools.chain.from_iterable(data2['liked_genres_75pct']))))

# %%
dataset2 = Dataset()

# %%
dataset2.fit(data2['user_id'],data2['media_id'],user_features=all_liked_genres2,item_features=all_anime_genres2)

# %%
item_features2 = dataset2.build_item_features((x,y) for x,y in zip(data2['media_id'],data2['genres']))

# %%
user_features2 = dataset2.build_user_features((x,y) for x,y in zip(data2['user_id'],data2['liked_genres_75pct']))

# %%
(interactions2, weights2) = dataset2.build_interactions(data2.iloc[:, 0:3].values)

# %%
train_interactions2, test_interactions2 = cross_validation.random_train_test_split(interactions2, 
                                                                                 test_percentage=TEST_PERCENTAGE, 
                                                                                 random_state = np.random.RandomState(SEEDNO))

# %%
model2 = LightFM(loss='warp', no_components = 10,
               learning_rate=.25,
               item_alpha=1e-6,
                random_state=np.random.RandomState(SEEDNO))

# %%
model2.fit(interactions=train_interactions2,item_features=item_features2,user_features=user_features2,epochs=20);

# %%
train_roc_auc2 = auc_score(model2,train_interactions2,item_features=item_features2,user_features=user_features2).mean()
test_roc_auc2 = auc_score(model2,test_interactions2,item_features=item_features2,user_features=user_features2).mean()
train_precision_lfm2 = lightfm_prec_at_k(model2, train_interactions2,item_features=item_features2,user_features=user_features2, k=K).mean()
test_precision_lfm2 = lightfm_prec_at_k(model2, test_interactions2,item_features=item_features2,user_features=user_features2, k=K).mean()
train_recall_lfm2 = lightfm_recall_at_k(model2, train_interactions2,item_features=item_features2,user_features=user_features2, k=K).mean()
test_recall_lfm2 = lightfm_recall_at_k(model2, test_interactions2,item_features=item_features2,user_features=user_features2, k=K).mean()
print("User feature type 2: Genres that the user likes")
print("(defined as genres of animes that the user has rated equal to or greater than their 75th percentile rating)")
print("=====AUC=====")
print(f'Train AUC: {train_roc_auc2}')
print(f'Test AUC: {test_roc_auc2}')
print("=====Precision@K=====")
print(f'Train Precision: {train_precision_lfm2}')
print(f'Test Precision: {test_precision_lfm2}')
print("=====Recall@K=====")
print(f'Train Recall: {train_recall_lfm2}')
print(f'Test Recall: {test_recall_lfm2}')
# Out:
# User feature type 2: Genres that the user likes
# (defined as genres of animes that the user has rated equal to or greater than their 75th percentile rating)
# =====AUC=====
# Train AUC: 0.9528266787528992
# Test AUC: 0.9484575986862183
# =====Precision@K=====
# Train Precision: 0.22304196655750275
# Test Precision: 0.07997269928455353
# =====Recall@K=====
# Train Recall: 0.07665977761628706
# Test Recall: 0.07269271179681663

# %%
uid_map2, ufeature_map2, iid_map2, ifeature_map2 = dataset2.mapping()

# %%
iid_map2_reverse = dict((value,key) for key,value in iid_map2.items())

# %% [markdown]
# ### Predict for new user

# %%
# predict for new user
user_feature_list = ['Comedy','Romance','Slice of Life']

# %%
new_user_features = format_newuser_input(ufeature_map2, user_feature_list)

# %%
n_users2, n_items2 = interactions2.shape

# %%
model2_pred = model2.predict(0, np.arange(n_items2), user_features=new_user_features) # Here 0 means pick the first row of the user_features sparse matrix

# %%
pred_dict2 = {'media_id':data2['media_id'].unique(),'pred':model2_pred}

# %%
pred_df2 = pd.DataFrame(pred_dict2)

# %%
pred_df2 = pd.merge(pred_df2,anime_id_map,on='media_id')

# %%
pred_df2.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id         pred                            title_romaji  \
# 58      20923  5480.367676                      Shokugeki no Souma
# 221     20954  5147.679688                          Koe no Katachi
# 199     21519  3706.275879                          Kimi no Na wa.
# 101     21087  3647.330566                           One Punch Man
# 52      20665  3589.352783                 Shigatsu wa Kimi no Uso
# 11      19815  3537.028076                         No Game No Life
# 3       11757  2887.373047                        Sword Art Online
# 18      20594  2771.747559                     Sword Art Online II
# 104     21202  2555.984619  Kono Subarashii Sekai ni Shukufuku wo!
# 228     11061  2314.376953                    HUNTER×HUNTER (2011)
#
#                                          title_english  \
# 58                        Food Wars! Shokugeki no Soma
# 221                                     A Silent Voice
# 199                                         Your Name.
# 101                                      One-Punch Man
# 52                                   Your Lie in April
# 11                                    No Game, No Life
# 3                                     Sword Art Online
# 18                                 Sword Art Online II
# 104  KONOSUBA -God's blessing on this wonderful world!
# 228                             Hunter x Hunter (2011)
#
#                               relations  \
# 58                       [21518, 21691]
# 221                                None
# 199                                None
# 101               [21416, 97668, 21386]
# 52                              [21039]
# 11                       [20769, 21875]
# 3                [20021, 20594, 124140]
# 18        [20021, 21403, 100183, 11757]
# 104                      [21574, 21699]
# 228  [13271, 136, 137, 138, 139, 19951]
#
#                                      genres
# 58                          [Comedy, Ecchi]
# 221         [Drama, Romance, Slice of Life]
# 199          [Drama, Romance, Supernatural]
# 101  [Action, Comedy, Sci-Fi, Supernatural]
# 52   [Drama, Music, Romance, Slice of Life]
# 11      [Adventure, Comedy, Ecchi, Fantasy]
# 3     [Action, Adventure, Fantasy, Romance]
# 18     [Action, Adventure, Fantasy, Sci-Fi]
# 104            [Adventure, Comedy, Fantasy]
# 228            [Action, Adventure, Fantasy]

# %% [markdown]
# ### Predict for existing user

# %%
user_x = uid_map2[710080]
model2_pred_existing = model2.predict(user_x,np.arange(n_items2))

# %%
pred_dict2_existing = {'media_id':data2['media_id'].unique(),'pred':model2_pred_existing}

# %%
pred_df2_existing = pd.DataFrame(pred_dict2_existing)

# %%
pred_df2_existing = pd.merge(pred_df2_existing,anime_id_map,on='media_id')

# %%
pred_df2_existing.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id      pred                            title_romaji  \
# 58      20923  9.213610                      Shokugeki no Souma
# 221     20954  7.383260                          Koe no Katachi
# 199     21519  6.112550                          Kimi no Na wa.
# 52      20665  5.961819                 Shigatsu wa Kimi no Uso
# 11      19815  5.902261                         No Game No Life
# 101     21087  5.864925                           One Punch Man
# 454     21518  5.687229          Shokugeki no Souma: Ni no Sara
# 23     124080  5.399632                                Horimiya
# 104     21202  5.324180  Kono Subarashii Sekai ni Shukufuku wo!
# 18      20594  5.302322                     Sword Art Online II
#
#                                          title_english  \
# 58                        Food Wars! Shokugeki no Soma
# 221                                     A Silent Voice
# 199                                         Your Name.
# 52                                   Your Lie in April
# 11                                    No Game, No Life
# 101                                      One-Punch Man
# 454                        Food Wars! The Second Plate
# 23                                            Horimiya
# 104  KONOSUBA -God's blessing on this wonderful world!
# 18                                 Sword Art Online II
#
#                          relations                                  genres
# 58                  [21518, 21691]                         [Comedy, Ecchi]
# 221                           None         [Drama, Romance, Slice of Life]
# 199                           None          [Drama, Romance, Supernatural]
# 52                         [21039]  [Drama, Music, Romance, Slice of Life]
# 11                  [20769, 21875]     [Adventure, Comedy, Ecchi, Fantasy]
# 101          [21416, 97668, 21386]  [Action, Comedy, Sci-Fi, Supernatural]
# 454          [20923, 98702, 99255]                         [Comedy, Ecchi]
# 23                         [14753]        [Comedy, Romance, Slice of Life]
# 104                 [21574, 21699]            [Adventure, Comedy, Fantasy]
# 18   [20021, 21403, 100183, 11757]    [Action, Adventure, Fantasy, Sci-Fi]

# %% [markdown]
# ### Predict similar items

# %%
# Predicting for Yahari Ore no Seishun Love Come ga Machigatteiru.
# Comedy, Drama, Romance, Slice of Life
item_x = iid_map2[14813]

# %%
similar_pred2 = similar_items(item_id=item_x, item_features=item_features2, model=model2,N=100)
similar_pred2['media_id'] = similar_pred2['itemID'].map(iid_map2_reverse)

# %%
similar_pred2 = pd.merge(similar_pred2,anime_id_map,on='media_id')

# %%
similar_pred2.sort_values('score',ascending=False).head(10)
# Out:
#     itemID  score  media_id  \
# 0       54    1.0      4224
# 2      483    1.0     98291
# 3      721    1.0     18671
# 4      455    1.0     20596
# 5      515    1.0     21049
# 6     1134    1.0    109261
# 1      727    1.0     97766
# 10     765    1.0    108489
# 13     118    1.0      6045
# 12     112    1.0     13759
#
#                                          title_romaji  \
# 0                                           Toradora!
# 2                                  Tsurezure Children
# 3                  Chuunibyou demo Koi ga Shitai! Ren
# 4                                        Ao Haru Ride
# 5                                              ReLIFE
# 6                              5-Toubun no Hanayome ∬
# 1                                             Gamers!
# 10  Yahari Ore no Seishun Love Come wa Machigattei...
# 13                                     Kimi ni Todoke
# 12                         Sakurasou no Pet na Kanojo
#
#                                        title_english  \
# 0                                          Toradora!
# 2                                 Tsuredure Children
# 3   Love, Chunibyo & Other Delusions - Heart Throb -
# 4                                   Blue Spring Ride
# 5                                             ReLIFE
# 6                   The Quintessential Quintuplets 2
# 1                                            GAMERS!
# 10             My Teen Romantic Comedy SNAFU Climax!
# 13                    Kimi ni Todoke: From Me to You
# 12                         The Pet Girl of Sakurasou
#
#                        relations                                   genres
# 0                  [6127, 11553]  [Comedy, Drama, Romance, Slice of Life]
# 2                           None  [Comedy, Drama, Romance, Slice of Life]
# 3   [16934, 20582, 20777, 20889]  [Comedy, Drama, Romance, Slice of Life]
# 4                 [20900, 20837]  [Comedy, Drama, Romance, Slice of Life]
# 5                        [98635]  [Comedy, Drama, Romance, Slice of Life]
# 6               [103572, 131520]  [Comedy, Drama, Romance, Slice of Life]
# 1                           None  [Comedy, Drama, Romance, Slice of Life]
# 10               [20698, 128643]  [Comedy, Drama, Romance, Slice of Life]
# 13                        [9656]  [Comedy, Drama, Romance, Slice of Life]
# 12                          None  [Comedy, Drama, Romance, Slice of Life]

# %% [markdown]
# ### Preliminary analysis for user feature type 2

# %% [markdown]
# Similar to type 1, top 10 predictions for new and existing user are the same, although in different order. Model might just be predicting animes that are highly rated, and majority of the top 10 predictions are also the most popular animes based on the EDA of the dataset.
#
# The results of the similar item predictions also look extremely good.
#
# In terms of model scores, type 1 & 2 have similar AUC scores, but type 2 has better recall.
#
# Between type 1 and 2, I would select type 2

# %% [markdown]
# ### User feature type 3: Top 3 genres among the genres that the user likes (defined as top 3 genres of animes that the user has rated equal to or greater than their average rating)

# %%
data3 = data[['user_id','media_id','rating','genres','top_3_genres_avg']]

# %%
all_anime_genres3 = sorted(list(set(itertools.chain.from_iterable(data3['genres']))))

# %%
all_liked_genres3 = sorted(list(set(itertools.chain.from_iterable(data3['top_3_genres_avg']))))

# %%
dataset3 = Dataset()

# %%
dataset3.fit(data3['user_id'],data3['media_id'],user_features=all_liked_genres3,item_features=all_anime_genres3)

# %%
item_features3 = dataset3.build_item_features((x,y) for x,y in zip(data3['media_id'],data3['genres']))

# %%
user_features3 = dataset3.build_user_features((x,y) for x,y in zip(data3['user_id'],data3['top_3_genres_avg']))

# %%
(interactions3, weights3) = dataset3.build_interactions(data3.iloc[:, 0:3].values)

# %%
train_interactions3, test_interactions3 = cross_validation.random_train_test_split(interactions3, 
                                                                                 test_percentage=TEST_PERCENTAGE, 
                                                                                 random_state = np.random.RandomState(SEEDNO))

# %%
model3 = LightFM(loss='warp', no_components = 10,
               learning_rate=.25,
               item_alpha=1e-6,
                random_state=np.random.RandomState(SEEDNO))

# %%
model3.fit(interactions=train_interactions3,item_features=item_features3,user_features=user_features3,epochs=20);

# %%
train_roc_auc3 = auc_score(model3,train_interactions3,item_features=item_features3,user_features=user_features3).mean()
test_roc_auc3 = auc_score(model3,test_interactions3,item_features=item_features3,user_features=user_features3).mean()
train_precision_lfm3 = lightfm_prec_at_k(model3, train_interactions3,item_features=item_features3,user_features=user_features3, k=K).mean()
test_precision_lfm3 = lightfm_prec_at_k(model3, test_interactions3,item_features=item_features3,user_features=user_features3, k=K).mean()
train_recall_lfm3 = lightfm_recall_at_k(model3, train_interactions3,item_features=item_features3,user_features=user_features3, k=K).mean()
test_recall_lfm3 = lightfm_recall_at_k(model3, test_interactions3,item_features=item_features3,user_features=user_features3, k=K).mean()
print("User feature type 3: Top 3 genres among the genres that the user likes")
print("(defined as top 3 genres of animes that the user has rated equal to or greater than their average rating)")
print("=====AUC=====")
print(f'Train AUC: {train_roc_auc3}')
print(f'Test AUC: {test_roc_auc3}')
print("=====Precision@K=====")
print(f'Train Precision: {train_precision_lfm3}')
print(f'Test Precision: {test_precision_lfm3}')
print("=====Recall@K=====")
print(f'Train Recall: {train_recall_lfm3}')
print(f'Test Recall: {test_recall_lfm3}')
# Out:
# User feature type 3: Top 3 genres among the genres that the user likes
# (defined as top 3 genres of animes that the user has rated equal to or greater than their average rating)
# =====AUC=====
# Train AUC: 0.9543743133544922
# Test AUC: 0.9491682052612305
# =====Precision@K=====
# Train Precision: 0.23796775937080383
# Test Precision: 0.08411470800638199
# =====Recall@K=====
# Train Recall: 0.09747065969652548
# Test Recall: 0.08289530351808082

# %%
uid_map3, ufeature_map3, iid_map3, ifeature_map3 = dataset3.mapping()

# %%
iid_map3_reverse = dict((value,key) for key,value in iid_map3.items())

# %% [markdown]
# ### Predict for new user

# %%
# predict for new user
user_feature_list = ['Comedy','Romance','Slice of Life']

# %%
new_user_features = format_newuser_input(ufeature_map3, user_feature_list)

# %%
n_users3, n_items3 = interactions3.shape

# %%
model3_pred = model3.predict(0, np.arange(n_items3), user_features=new_user_features) # Here 0 means pick the first row of the user_features sparse matrix

# %%
pred_dict3 = {'media_id':data3['media_id'].unique(),'pred':model3_pred}

# %%
pred_df3 = pd.DataFrame(pred_dict3)

# %%
pred_df3 = pd.merge(pred_df3,anime_id_map,on='media_id')

# %%
pred_df3.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id         pred                            title_romaji  \
# 221     20954  4559.840332                          Koe no Katachi
# 58      20923  4466.522461                      Shokugeki no Souma
# 52      20665  3693.887939                 Shigatsu wa Kimi no Uso
# 101     21087  3646.187256                           One Punch Man
# 11      19815  3543.696777                         No Game No Life
# 199     21519  3533.456543                          Kimi no Na wa.
# 3       11757  3231.106445                        Sword Art Online
# 18      20594  2963.987305                     Sword Art Online II
# 104     21202  2851.133301  Kono Subarashii Sekai ni Shukufuku wo!
# 24      15809  2706.138916                     Hataraku Maou-sama!
#
#                                          title_english  \
# 221                                     A Silent Voice
# 58                        Food Wars! Shokugeki no Soma
# 52                                   Your Lie in April
# 101                                      One-Punch Man
# 11                                    No Game, No Life
# 199                                         Your Name.
# 3                                     Sword Art Online
# 18                                 Sword Art Online II
# 104  KONOSUBA -God's blessing on this wonderful world!
# 24                          The Devil is a Part-Timer!
#
#                          relations                                     genres
# 221                           None            [Drama, Romance, Slice of Life]
# 58                  [21518, 21691]                            [Comedy, Ecchi]
# 52                         [21039]     [Drama, Music, Romance, Slice of Life]
# 101          [21416, 97668, 21386]     [Action, Comedy, Sci-Fi, Supernatural]
# 11                  [20769, 21875]        [Adventure, Comedy, Ecchi, Fantasy]
# 199                           None             [Drama, Romance, Supernatural]
# 3           [20021, 20594, 124140]      [Action, Adventure, Fantasy, Romance]
# 18   [20021, 21403, 100183, 11757]       [Action, Adventure, Fantasy, Sci-Fi]
# 104                 [21574, 21699]               [Adventure, Comedy, Fantasy]
# 24                        [130592]  [Comedy, Fantasy, Romance, Slice of Life]

# %% [markdown]
# ### Predict for existing user

# %%
# user id 710080 is my own account
user_x = uid_map3[710080]
model3_pred_existing = model3.predict(user_x,np.arange(n_items3))

# %%
pred_dict3_existing = {'media_id':data3['media_id'].unique(),'pred':model3_pred_existing}

# %%
pred_df3_existing = pd.DataFrame(pred_dict3_existing)

# %%
pred_df3_existing = pd.merge(pred_df3_existing,anime_id_map,on='media_id')

# %%
pred_df3_existing.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id      pred                            title_romaji  \
# 58      20923  0.966706                      Shokugeki no Souma
# 221     20954 -0.648251                          Koe no Katachi
# 52      20665 -1.229392                 Shigatsu wa Kimi no Uso
# 66      12189 -1.286155                                  Hyouka
# 11      19815 -1.357756                         No Game No Life
# 199     21519 -1.369898                          Kimi no Na wa.
# 23     124080 -1.430883                                Horimiya
# 104     21202 -1.483740  Kono Subarashii Sekai ni Shukufuku wo!
# 101     21087 -1.494548                           One Punch Man
# 454     21518 -1.509250          Shokugeki no Souma: Ni no Sara
#
#                                          title_english              relations  \
# 58                        Food Wars! Shokugeki no Soma         [21518, 21691]
# 221                                     A Silent Voice                   None
# 52                                   Your Lie in April                [21039]
# 66                                              Hyouka                [13469]
# 11                                    No Game, No Life         [20769, 21875]
# 199                                         Your Name.                   None
# 23                                            Horimiya                [14753]
# 104  KONOSUBA -God's blessing on this wonderful world!         [21574, 21699]
# 101                                      One-Punch Man  [21416, 97668, 21386]
# 454                        Food Wars! The Second Plate  [20923, 98702, 99255]
#
#                                      genres
# 58                          [Comedy, Ecchi]
# 221         [Drama, Romance, Slice of Life]
# 52   [Drama, Music, Romance, Slice of Life]
# 66                 [Mystery, Slice of Life]
# 11      [Adventure, Comedy, Ecchi, Fantasy]
# 199          [Drama, Romance, Supernatural]
# 23         [Comedy, Romance, Slice of Life]
# 104            [Adventure, Comedy, Fantasy]
# 101  [Action, Comedy, Sci-Fi, Supernatural]
# 454                         [Comedy, Ecchi]

# %% [markdown]
# ### Predict similar items

# %%
# Predicting for Yahari Ore no Seishun Love Come ga Machigatteiru.
# Comedy, Drama, Romance, Slice of Life
item_x = iid_map3[14813]

# %%
similar_pred3 = similar_items(item_id=item_x, item_features=item_features3, model=model3,N=100)
similar_pred3['media_id'] = similar_pred3['itemID'].map(iid_map3_reverse)

# %%
similar_pred3 = pd.merge(similar_pred3,anime_id_map,on='media_id')

# %%
similar_pred3.sort_values('score',ascending=False).head(10)
# Out:
#    itemID  score  media_id                                       title_romaji  \
# 0     642    1.0     20698  Yahari Ore no Seishun Love Come wa Machigattei...
# 1     224    1.0    103572                               5-Toubun no Hanayome
# 2      54    1.0      4224                                          Toradora!
# 3      63    1.0     14813  Yahari Ore no Seishun Love Come wa Machigatteiru.
# 4      65    1.0     14741                     Chuunibyou demo Koi ga Shitai!
# 5     727    1.0     97766                                            Gamers!
# 6     765    1.0    108489  Yahari Ore no Seishun Love Come wa Machigattei...
# 7     451    1.0       853                             Ouran Koukou Host Club
# 8    1134    1.0    109261                             5-Toubun no Hanayome ∬
# 9     112    1.0     13759                         Sakurasou no Pet na Kanojo
#
#                            title_english                     relations  \
# 0     My Teen Romantic Comedy SNAFU TOO!        [14813, 21769, 108489]
# 1         The Quintessential Quintuplets                      [109261]
# 2                              Toradora!                 [6127, 11553]
# 3          My Teen Romantic Comedy SNAFU                [18753, 20698]
# 4       Love, Chunibyo & Other Delusions  [16934, 15687, 15879, 19021]
# 5                                GAMERS!                          None
# 6  My Teen Romantic Comedy SNAFU Climax!               [20698, 128643]
# 7            Ouran High School Host Club                          None
# 8       The Quintessential Quintuplets 2              [103572, 131520]
# 9              The Pet Girl of Sakurasou                          None
#
#                                     genres
# 0  [Comedy, Drama, Romance, Slice of Life]
# 1  [Comedy, Drama, Romance, Slice of Life]
# 2  [Comedy, Drama, Romance, Slice of Life]
# 3  [Comedy, Drama, Romance, Slice of Life]
# 4  [Comedy, Drama, Romance, Slice of Life]
# 5  [Comedy, Drama, Romance, Slice of Life]
# 6  [Comedy, Drama, Romance, Slice of Life]
# 7  [Comedy, Drama, Romance, Slice of Life]
# 8  [Comedy, Drama, Romance, Slice of Life]
# 9  [Comedy, Drama, Romance, Slice of Life]

# %% [markdown]
# ### Preliminary analysis for user feature type 3

# %% [markdown]
# Top 10 predictions for new and existing user have less similarities, but they are still largely similar. For new user, model might just be predicting animes that are highly rated and that is expected since the model does not have any data about the new user. For existing user, although the pred column shows negative value, LightFM's prediction values are not interpretable and should instead be used only to rank titles.
#
# The results of the similar item predictions also look extremely good. It seems the similar item predictions are extremely similar between the 3 types, but in different order.
#
# In terms of model scores, type 1,2 & 3 have similar AUC scores, but type 3 has the best recall.
#
# Between type 1, 2 & 3, I would select type 3 due to the higher recall, as well as increase in variety of recommendations between new and existing users

# %% [markdown]
# ### User feature type 4: Top 5 genres among the genres that the user likes (defined as top 5 genres of animes that the user has rated equal to or greater than their average rating)

# %%
data4 = data[['user_id','media_id','rating','genres','top_5_genres_avg']]

# %%
all_anime_genres4 = sorted(list(set(itertools.chain.from_iterable(data4['genres']))))

# %%
all_liked_genres4 = sorted(list(set(itertools.chain.from_iterable(data4['top_5_genres_avg']))))

# %%
dataset4 = Dataset()

# %%
dataset4.fit(data4['user_id'],data4['media_id'],user_features=all_liked_genres4,item_features=all_anime_genres4)

# %%
item_features4 = dataset4.build_item_features((x,y) for x,y in zip(data4['media_id'],data4['genres']))

# %%
user_features4 = dataset4.build_user_features((x,y) for x,y in zip(data4['user_id'],data4['top_5_genres_avg']))

# %%
(interactions4, weights4) = dataset4.build_interactions(data4.iloc[:, 0:3].values)

# %%
train_interactions4, test_interactions4 = cross_validation.random_train_test_split(interactions4, 
                                                                                 test_percentage=TEST_PERCENTAGE, 
                                                                                 random_state = np.random.RandomState(SEEDNO))

# %%
model4 = LightFM(loss='warp', no_components = 10,
               learning_rate=.25,
               item_alpha=1e-6,
                random_state=np.random.RandomState(SEEDNO))

# %%
model4.fit(interactions=train_interactions4,item_features=item_features4,user_features=user_features4,epochs=20);

# %%
train_roc_auc4 = auc_score(model4,train_interactions4,item_features=item_features4,user_features=user_features4).mean()
test_roc_auc4 = auc_score(model4,test_interactions4,item_features=item_features4,user_features=user_features4).mean()
train_precision_lfm4 = lightfm_prec_at_k(model4, train_interactions4,item_features=item_features4,user_features=user_features4, k=K).mean()
test_precision_lfm4 = lightfm_prec_at_k(model4, test_interactions4,item_features=item_features4,user_features=user_features4, k=K).mean()
train_recall_lfm4 = lightfm_recall_at_k(model4, train_interactions4,item_features=item_features4,user_features=user_features4, k=K).mean()
test_recall_lfm4 = lightfm_recall_at_k(model4, test_interactions4,item_features=item_features4,user_features=user_features4, k=K).mean()
print("User feature type 4: Top 5 genres among the genres that the user likes")
print("(defined as top 5 genres of animes that the user has rated equal to or greater than their average rating)")
print("=====AUC=====")
print(f'Train AUC: {train_roc_auc4}')
print(f'Test AUC: {test_roc_auc4}')
print("=====Precision@K=====")
print(f'Train Precision: {train_precision_lfm4}')
print(f'Test Precision: {test_precision_lfm4}')
print("=====Recall@K=====")
print(f'Train Recall: {train_recall_lfm4}')
print(f'Test Recall: {test_recall_lfm4}')
# Out:
# User feature type 4: Top 5 genres among the genres that the user likes
# (defined as top 5 genres of animes that the user has rated equal to or greater than their average rating)
# =====AUC=====
# Train AUC: 0.9548159241676331
# Test AUC: 0.9498434662818909
# =====Precision@K=====
# Train Precision: 0.281594842672348
# Test Precision: 0.10039448738098145
# =====Recall@K=====
# Train Recall: 0.1172254678840192
# Test Recall: 0.103140321035574

# %%
uid_map4, ufeature_map4, iid_map4, ifeature_map4 = dataset4.mapping()

# %%
iid_map4_reverse = dict((value,key) for key,value in iid_map4.items())

# %% [markdown]
# ### Predict for new user

# %%
# predict for new user
user_feature_list = ['Comedy','Romance','Slice of Life']

# %%
new_user_features = format_newuser_input(ufeature_map4, user_feature_list)

# %%
n_users4, n_items4 = interactions4.shape

# %%
model4_pred = model4.predict(0, np.arange(n_items4), user_features=new_user_features) # Here 0 means pick the first row of the user_features sparse matrix

# %%
pred_dict4 = {'media_id':data4['media_id'].unique(),'pred':model4_pred}

# %%
pred_df4 = pd.DataFrame(pred_dict4)

# %%
pred_df4 = pd.merge(pred_df4,anime_id_map,on='media_id')

# %%
pred_df4.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id         pred                          title_romaji_x  \
# 58      20923  4196.525879                      Shokugeki no Souma
# 221     20954  4115.895020                          Koe no Katachi
# 52      20665  3187.632324                 Shigatsu wa Kimi no Uso
# 101     21087  3118.401855                           One Punch Man
# 199     21519  3014.661621                          Kimi no Na wa.
# 11      19815  2977.427734                         No Game No Life
# 3       11757  2720.343262                        Sword Art Online
# 18      20594  2480.673828                     Sword Art Online II
# 104     21202  2314.435547  Kono Subarashii Sekai ni Shukufuku wo!
# 24      15809  2121.204590                     Hataraku Maou-sama!
#
#                                        title_english_x  \
# 58                        Food Wars! Shokugeki no Soma
# 221                                     A Silent Voice
# 52                                   Your Lie in April
# 101                                      One-Punch Man
# 199                                         Your Name.
# 11                                    No Game, No Life
# 3                                     Sword Art Online
# 18                                 Sword Art Online II
# 104  KONOSUBA -God's blessing on this wonderful world!
# 24                          The Devil is a Part-Timer!
#
#                        relations_x                                   genres_x  \
# 58                  [21518, 21691]                            [Comedy, Ecchi]
# 221                           None            [Drama, Romance, Slice of Life]
# 52                         [21039]     [Drama, Music, Romance, Slice of Life]
# 101          [21416, 97668, 21386]     [Action, Comedy, Sci-Fi, Supernatural]
# 199                           None             [Drama, Romance, Supernatural]
# 11                  [20769, 21875]        [Adventure, Comedy, Ecchi, Fantasy]
# 3           [20021, 20594, 124140]      [Action, Adventure, Fantasy, Romance]
# 18   [20021, 21403, 100183, 11757]       [Action, Adventure, Fantasy, Sci-Fi]
# 104                 [21574, 21699]               [Adventure, Comedy, Fantasy]
# 24                        [130592]  [Comedy, Fantasy, Romance, Slice of Life]
#
#                              title_romaji_y  \
# 58                       Shokugeki no Souma
# 221                          Koe no Katachi
# 52                  Shigatsu wa Kimi no Uso
# 101                           One Punch Man
# 199                          Kimi no Na wa.
# 11                          No Game No Life
# 3                          Sword Art Online
# 18                      Sword Art Online II
# 104  Kono Subarashii Sekai ni Shukufuku wo!
# 24                      Hataraku Maou-sama!
#
#                                        title_english_y  \
# 58                        Food Wars! Shokugeki no Soma
# 221                                     A Silent Voice
# 52                                   Your Lie in April
# 101                                      One-Punch Man
# 199                                         Your Name.
# 11                                    No Game, No Life
# 3                                     Sword Art Online
# 18                                 Sword Art Online II
# 104  KONOSUBA -God's blessing on this wonderful world!
# 24                          The Devil is a Part-Timer!
#
#                        relations_y                                   genres_y
# 58                  [21518, 21691]                            [Comedy, Ecchi]
# 221                           None            [Drama, Romance, Slice of Life]
# 52                         [21039]     [Drama, Music, Romance, Slice of Life]
# 101          [21416, 97668, 21386]     [Action, Comedy, Sci-Fi, Supernatural]
# 199                           None             [Drama, Romance, Supernatural]
# 11                  [20769, 21875]        [Adventure, Comedy, Ecchi, Fantasy]
# 3           [20021, 20594, 124140]      [Action, Adventure, Fantasy, Romance]
# 18   [20021, 21403, 100183, 11757]       [Action, Adventure, Fantasy, Sci-Fi]
# 104                 [21574, 21699]               [Adventure, Comedy, Fantasy]
# 24                        [130592]  [Comedy, Fantasy, Romance, Slice of Life]

# %% [markdown]
# ### Predict for existing user

# %%
# user id 710080 is my own account
user_x = uid_map4[710080]
model4_pred_existing = model4.predict(user_x,np.arange(n_items4))

# %%
pred_dict4_existing = {'media_id':data4['media_id'].unique(),'pred':model4_pred_existing}

# %%
pred_df4_existing = pd.DataFrame(pred_dict4_existing)

# %%
pred_df4_existing = pd.merge(pred_df4_existing,anime_id_map,on='media_id')

# %%
pred_df4_existing.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id      pred                            title_romaji  \
# 58      20923  6.543212                      Shokugeki no Souma
# 221     20954  3.257215                          Koe no Katachi
# 66      12189  3.239570                                  Hyouka
# 454     21518  3.169772          Shokugeki no Souma: Ni no Sara
# 23     124080  2.582151                                Horimiya
# 52      20665  2.347939                 Shigatsu wa Kimi no Uso
# 199     21519  2.196276                          Kimi no Na wa.
# 104     21202  2.044642  Kono Subarashii Sekai ni Shukufuku wo!
# 11      19815  2.004920                         No Game No Life
# 69      21776  1.791389          Kobayashi-san Chi no Maidragon
#
#                                          title_english              relations  \
# 58                        Food Wars! Shokugeki no Soma         [21518, 21691]
# 221                                     A Silent Voice                   None
# 66                                              Hyouka                [13469]
# 454                        Food Wars! The Second Plate  [20923, 98702, 99255]
# 23                                            Horimiya                [14753]
# 52                                   Your Lie in April                [21039]
# 199                                         Your Name.                   None
# 104  KONOSUBA -God's blessing on this wonderful world!         [21574, 21699]
# 11                                    No Game, No Life         [20769, 21875]
# 69                        Miss Kobayashi's Dragon Maid         [98502, 98580]
#
#                                      genres
# 58                          [Comedy, Ecchi]
# 221         [Drama, Romance, Slice of Life]
# 66                 [Mystery, Slice of Life]
# 454                         [Comedy, Ecchi]
# 23         [Comedy, Romance, Slice of Life]
# 52   [Drama, Music, Romance, Slice of Life]
# 199          [Drama, Romance, Supernatural]
# 104            [Adventure, Comedy, Fantasy]
# 11      [Adventure, Comedy, Ecchi, Fantasy]
# 69         [Comedy, Fantasy, Slice of Life]

# %% [markdown]
# ### Predict similar items

# %%
# Predicting for Yahari Ore no Seishun Love Come ga Machigatteiru.
# Comedy, Drama, Romance, Slice of Life
item_x = iid_map4[14813]

# %%
similar_pred4 = similar_items(item_id=item_x, item_features=item_features4, model=model4,N=100)
similar_pred4['media_id'] = similar_pred4['itemID'].map(iid_map4_reverse)

# %%
similar_pred4 = pd.merge(similar_pred4,anime_id_map,on='media_id')

# %%
similar_pred4.sort_values('score',ascending=False).head(10)
# Out:
#    itemID  score  media_id                                       title_romaji  \
# 0     224    1.0    103572                               5-Toubun no Hanayome
# 1     515    1.0     21049                                             ReLIFE
# 2      65    1.0     14741                     Chuunibyou demo Koi ga Shitai!
# 3      63    1.0     14813  Yahari Ore no Seishun Love Come wa Machigatteiru.
# 4     451    1.0       853                             Ouran Koukou Host Club
# 5     455    1.0     20596                                       Ao Haru Ride
# 6     483    1.0     98291                                 Tsurezure Children
# 7      54    1.0      4224                                          Toradora!
# 8     721    1.0     18671                 Chuunibyou demo Koi ga Shitai! Ren
# 9     765    1.0    108489  Yahari Ore no Seishun Love Come wa Machigattei...
#
#                                       title_english  \
# 0                    The Quintessential Quintuplets
# 1                                            ReLIFE
# 2                  Love, Chunibyo & Other Delusions
# 3                     My Teen Romantic Comedy SNAFU
# 4                       Ouran High School Host Club
# 5                                  Blue Spring Ride
# 6                                Tsuredure Children
# 7                                         Toradora!
# 8  Love, Chunibyo & Other Delusions - Heart Throb -
# 9             My Teen Romantic Comedy SNAFU Climax!
#
#                       relations                                   genres
# 0                      [109261]  [Comedy, Drama, Romance, Slice of Life]
# 1                       [98635]  [Comedy, Drama, Romance, Slice of Life]
# 2  [16934, 15687, 15879, 19021]  [Comedy, Drama, Romance, Slice of Life]
# 3                [18753, 20698]  [Comedy, Drama, Romance, Slice of Life]
# 4                          None  [Comedy, Drama, Romance, Slice of Life]
# 5                [20900, 20837]  [Comedy, Drama, Romance, Slice of Life]
# 6                          None  [Comedy, Drama, Romance, Slice of Life]
# 7                 [6127, 11553]  [Comedy, Drama, Romance, Slice of Life]
# 8  [16934, 20582, 20777, 20889]  [Comedy, Drama, Romance, Slice of Life]
# 9               [20698, 128643]  [Comedy, Drama, Romance, Slice of Life]

# %% [markdown]
# ### Preliminary analysis for user feature type 4

# %% [markdown]
# Top 10 predictions for new and existing user have much less similarities compared to types 1-3, but they are still largely similar.
#
# The results of the similar item predictions also look extremely good. It seems the similar item predictions are extremely similar between the 4 types, but in different order.
#
# In terms of model scores, types 1-4 have similar AUC scores, but type 4 has the best recall.
#
# Between types 1-4, I would select type 4 due to the higher recall, as well as increase in variety of recommendations between new and existing users

# %% [markdown]
# ### User feature type 5: Top 3 genres among the genres that the user likes (defined as top 3 genres of animes that the user has rated equal to or greater than their 75th percentile rating)

# %%
data5 = data[['user_id','media_id','rating','genres','top_3_genres_75pct']]

# %%
all_anime_genres5 = sorted(list(set(itertools.chain.from_iterable(data5['genres']))))

# %%
all_liked_genres5 = sorted(list(set(itertools.chain.from_iterable(data5['top_3_genres_75pct']))))

# %%
dataset5 = Dataset()

# %%
dataset5.fit(data5['user_id'],data5['media_id'],user_features=all_liked_genres5,item_features=all_anime_genres5)

# %%
item_features5 = dataset5.build_item_features((x,y) for x,y in zip(data5['media_id'],data5['genres']))

# %%
user_features5 = dataset5.build_user_features((x,y) for x,y in zip(data5['user_id'],data5['top_3_genres_75pct']))

# %%
(interactions5, weights5) = dataset5.build_interactions(data5.iloc[:, 0:3].values)

# %%
train_interactions5, test_interactions5 = cross_validation.random_train_test_split(interactions5, 
                                                                                 test_percentage=TEST_PERCENTAGE, 
                                                                                 random_state = np.random.RandomState(SEEDNO))

# %%
model5 = LightFM(loss='warp', no_components = 10,
               learning_rate=.25,
               item_alpha=1e-6,
                random_state=np.random.RandomState(SEEDNO))

# %%
model5.fit(interactions=train_interactions5,item_features=item_features5,user_features=user_features5,epochs=20);

# %%
train_roc_auc5 = auc_score(model5,train_interactions5,item_features=item_features5,user_features=user_features5).mean()
test_roc_auc5 = auc_score(model5,test_interactions5,item_features=item_features5,user_features=user_features5).mean()
train_precision_lfm5 = lightfm_prec_at_k(model5, train_interactions5,item_features=item_features5,user_features=user_features5, k=K).mean()
test_precision_lfm5 = lightfm_prec_at_k(model5, test_interactions5,item_features=item_features5,user_features=user_features5, k=K).mean()
train_recall_lfm5 = lightfm_recall_at_k(model5, train_interactions5,item_features=item_features5,user_features=user_features5, k=K).mean()
test_recall_lfm5 = lightfm_recall_at_k(model5, test_interactions5,item_features=item_features5,user_features=user_features5, k=K).mean()
print("User feature type 5: Top 3 genres among the genres that the user likes")
print("(defined as top 3 genres of animes that the user has rated equal to or greater than their 75th percentile rating)")
print("=====AUC=====")
print(f'Train AUC: {train_roc_auc5}')
print(f'Test AUC: {test_roc_auc5}')
print("=====Precision@K=====")
print(f'Train Precision: {train_precision_lfm5}')
print(f'Test Precision: {test_precision_lfm5}')
print("=====Recall@K=====")
print(f'Train Recall: {train_recall_lfm5}')
print(f'Test Recall: {test_recall_lfm5}')
# Out:
# User feature type 5: Top 3 genres among the genres that the user likes
# (defined as top 3 genres of animes that the user has rated equal to or greater than their 75th percentile rating)
# =====AUC=====
# Train AUC: 0.9534348249435425
# Test AUC: 0.9484164118766785
# =====Precision@K=====
# Train Precision: 0.25572675466537476
# Test Precision: 0.0902518630027771
# =====Recall@K=====
# Train Recall: 0.09997262009890688
# Test Recall: 0.08649129588169902

# %%
uid_map5, ufeature_map5, iid_map5, ifeature_map5 = dataset5.mapping()

# %%
iid_map5_reverse = dict((value,key) for key,value in iid_map5.items())

# %% [markdown]
# ### Predict for new user

# %%
# predict for new user
user_feature_list = ['Comedy','Romance','Slice of Life']

# %%
new_user_features = format_newuser_input(ufeature_map5, user_feature_list)

# %%
n_users5, n_items5 = interactions5.shape

# %%
model5_pred = model5.predict(0, np.arange(n_items5), user_features=new_user_features) # Here 0 means pick the first row of the user_features sparse matrix

# %%
pred_dict5 = {'media_id':data5['media_id'].unique(),'pred':model5_pred}

# %%
pred_df5 = pd.DataFrame(pred_dict5)

# %%
pred_df5 = pd.merge(pred_df5,anime_id_map,on='media_id')

# %%
pred_df5.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id         pred                            title_romaji  \
# 221     20954  4851.352051                          Koe no Katachi
# 58      20923  4811.720215                      Shokugeki no Souma
# 52      20665  3903.775391                 Shigatsu wa Kimi no Uso
# 101     21087  3849.635498                           One Punch Man
# 11      19815  3698.025146                         No Game No Life
# 199     21519  3686.382080                          Kimi no Na wa.
# 3       11757  3354.629883                        Sword Art Online
# 18      20594  3217.090576                     Sword Art Online II
# 104     21202  3064.390625  Kono Subarashii Sekai ni Shukufuku wo!
# 228     11061  2971.944092                    HUNTER×HUNTER (2011)
#
#                                          title_english  \
# 221                                     A Silent Voice
# 58                        Food Wars! Shokugeki no Soma
# 52                                   Your Lie in April
# 101                                      One-Punch Man
# 11                                    No Game, No Life
# 199                                         Your Name.
# 3                                     Sword Art Online
# 18                                 Sword Art Online II
# 104  KONOSUBA -God's blessing on this wonderful world!
# 228                             Hunter x Hunter (2011)
#
#                               relations  \
# 221                                None
# 58                       [21518, 21691]
# 52                              [21039]
# 101               [21416, 97668, 21386]
# 11                       [20769, 21875]
# 199                                None
# 3                [20021, 20594, 124140]
# 18        [20021, 21403, 100183, 11757]
# 104                      [21574, 21699]
# 228  [13271, 136, 137, 138, 139, 19951]
#
#                                      genres
# 221         [Drama, Romance, Slice of Life]
# 58                          [Comedy, Ecchi]
# 52   [Drama, Music, Romance, Slice of Life]
# 101  [Action, Comedy, Sci-Fi, Supernatural]
# 11      [Adventure, Comedy, Ecchi, Fantasy]
# 199          [Drama, Romance, Supernatural]
# 3     [Action, Adventure, Fantasy, Romance]
# 18     [Action, Adventure, Fantasy, Sci-Fi]
# 104            [Adventure, Comedy, Fantasy]
# 228            [Action, Adventure, Fantasy]

# %% [markdown]
# ### Predict for existing user

# %%
# user id 710080 is my own account
user_x = uid_map5[710080]
model5_pred_existing = model5.predict(user_x,np.arange(n_items5))

# %%
pred_dict5_existing = {'media_id':data5['media_id'].unique(),'pred':model5_pred_existing}

# %%
pred_df5_existing = pd.DataFrame(pred_dict5_existing)

# %%
pred_df5_existing = pd.merge(pred_df5_existing,anime_id_map,on='media_id')

# %%
pred_df5_existing.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id      pred                            title_romaji  \
# 58      20923  1.423041                      Shokugeki no Souma
# 221     20954 -0.046106                          Koe no Katachi
# 52      20665 -0.937143                 Shigatsu wa Kimi no Uso
# 199     21519 -1.058600                          Kimi no Na wa.
# 11      19815 -1.173374                         No Game No Life
# 23     124080 -1.214637                                Horimiya
# 101     21087 -1.229956                           One Punch Man
# 66      12189 -1.272346                                  Hyouka
# 104     21202 -1.275169  Kono Subarashii Sekai ni Shukufuku wo!
# 454     21518 -1.316252          Shokugeki no Souma: Ni no Sara
#
#                                          title_english              relations  \
# 58                        Food Wars! Shokugeki no Soma         [21518, 21691]
# 221                                     A Silent Voice                   None
# 52                                   Your Lie in April                [21039]
# 199                                         Your Name.                   None
# 11                                    No Game, No Life         [20769, 21875]
# 23                                            Horimiya                [14753]
# 101                                      One-Punch Man  [21416, 97668, 21386]
# 66                                              Hyouka                [13469]
# 104  KONOSUBA -God's blessing on this wonderful world!         [21574, 21699]
# 454                        Food Wars! The Second Plate  [20923, 98702, 99255]
#
#                                      genres
# 58                          [Comedy, Ecchi]
# 221         [Drama, Romance, Slice of Life]
# 52   [Drama, Music, Romance, Slice of Life]
# 199          [Drama, Romance, Supernatural]
# 11      [Adventure, Comedy, Ecchi, Fantasy]
# 23         [Comedy, Romance, Slice of Life]
# 101  [Action, Comedy, Sci-Fi, Supernatural]
# 66                 [Mystery, Slice of Life]
# 104            [Adventure, Comedy, Fantasy]
# 454                         [Comedy, Ecchi]

# %% [markdown]
# ### Predict similar items

# %%
# Predicting for Yahari Ore no Seishun Love Come ga Machigatteiru.
# Comedy, Drama, Romance, Slice of Life
item_x = iid_map5[14813]

# %%
similar_pred5 = similar_items(item_id=item_x, item_features=item_features5, model=model5,N=100)
similar_pred5['media_id'] = similar_pred5['itemID'].map(iid_map5_reverse)

# %%
similar_pred5 = pd.merge(similar_pred5,anime_id_map,on='media_id')

# %%
similar_pred5.sort_values('score',ascending=False).head(10)
# Out:
#     itemID  score  media_id  \
# 0      451    1.0       853
# 2       54    1.0      4224
# 3      727    1.0     97766
# 4     1134    1.0    109261
# 5      515    1.0     21049
# 6      112    1.0     13759
# 7      455    1.0     20596
# 1       63    1.0     14813
# 10     765    1.0    108489
# 11     483    1.0     98291
#
#                                          title_romaji  \
# 0                              Ouran Koukou Host Club
# 2                                           Toradora!
# 3                                             Gamers!
# 4                              5-Toubun no Hanayome ∬
# 5                                              ReLIFE
# 6                          Sakurasou no Pet na Kanojo
# 7                                        Ao Haru Ride
# 1   Yahari Ore no Seishun Love Come wa Machigatteiru.
# 10  Yahari Ore no Seishun Love Come wa Machigattei...
# 11                                 Tsurezure Children
#
#                             title_english         relations  \
# 0             Ouran High School Host Club              None
# 2                               Toradora!     [6127, 11553]
# 3                                 GAMERS!              None
# 4        The Quintessential Quintuplets 2  [103572, 131520]
# 5                                  ReLIFE           [98635]
# 6               The Pet Girl of Sakurasou              None
# 7                        Blue Spring Ride    [20900, 20837]
# 1           My Teen Romantic Comedy SNAFU    [18753, 20698]
# 10  My Teen Romantic Comedy SNAFU Climax!   [20698, 128643]
# 11                     Tsuredure Children              None
#
#                                      genres
# 0   [Comedy, Drama, Romance, Slice of Life]
# 2   [Comedy, Drama, Romance, Slice of Life]
# 3   [Comedy, Drama, Romance, Slice of Life]
# 4   [Comedy, Drama, Romance, Slice of Life]
# 5   [Comedy, Drama, Romance, Slice of Life]
# 6   [Comedy, Drama, Romance, Slice of Life]
# 7   [Comedy, Drama, Romance, Slice of Life]
# 1   [Comedy, Drama, Romance, Slice of Life]
# 10  [Comedy, Drama, Romance, Slice of Life]
# 11  [Comedy, Drama, Romance, Slice of Life]

# %% [markdown]
# ### Preliminary analysis for user feature type 5

# %% [markdown]
# Comparing to type 4, top 10 predictions for new and existing user are back to having more similarities.
#
# The results of the similar item predictions also look extremely good. It seems the similar item predictions are extremely similar between the 5 types, but in different order.
#
# In terms of model scores, types 1-5 have similar AUC scores. Type 4 still has the best recall but type 5 has better recall than types 1-3.
#
# Between types 1-5, I would select type 4 due to the higher recall, as well as increase in variety of recommendations between new and existing users

# %% [markdown]
# ### User feature type 6: Top 5 genres among the genres that the user likes (defined as top 5 genres of animes that the user has rated equal to or greater than their 75th percentile rating)

# %%
data6 = data[['user_id','media_id','rating','genres','top_5_genres_75pct']]

# %%
all_anime_genres6 = sorted(list(set(itertools.chain.from_iterable(data6['genres']))))

# %%
all_liked_genres6 = sorted(list(set(itertools.chain.from_iterable(data6['top_5_genres_75pct']))))

# %%
dataset6 = Dataset()

# %%
dataset6.fit(data6['user_id'],data6['media_id'],user_features=all_liked_genres6,item_features=all_anime_genres6)

# %%
item_features6 = dataset6.build_item_features((x,y) for x,y in zip(data6['media_id'],data6['genres']))

# %%
user_features6 = dataset6.build_user_features((x,y) for x,y in zip(data6['user_id'],data6['top_5_genres_75pct']))

# %%
(interactions6, weights6) = dataset6.build_interactions(data6.iloc[:, 0:3].values)

# %%
train_interactions6, test_interactions6 = cross_validation.random_train_test_split(interactions6, 
                                                                                 test_percentage=TEST_PERCENTAGE, 
                                                                                 random_state = np.random.RandomState(SEEDNO))

# %%
model6 = LightFM(loss='warp', no_components = 10,
               learning_rate=.25,
               item_alpha=1e-6,
                random_state=np.random.RandomState(SEEDNO))

# %%
model6.fit(interactions=train_interactions6,item_features=item_features6,user_features=user_features6,epochs=20);

# %%
train_roc_auc6 = auc_score(model6,train_interactions6,item_features=item_features6,user_features=user_features6).mean()
test_roc_auc6 = auc_score(model6,test_interactions6,item_features=item_features6,user_features=user_features6).mean()
train_precision_lfm6 = lightfm_prec_at_k(model6, train_interactions6,item_features=item_features6,user_features=user_features6, k=K).mean()
test_precision_lfm6 = lightfm_prec_at_k(model6, test_interactions6,item_features=item_features6,user_features=user_features6, k=K).mean()
train_recall_lfm6 = lightfm_recall_at_k(model6, train_interactions6,item_features=item_features6,user_features=user_features6, k=K).mean()
test_recall_lfm6 = lightfm_recall_at_k(model6, test_interactions6,item_features=item_features6,user_features=user_features6, k=K).mean()
print("User feature type 6: Top 5 genres among the genres that the user likes")
print("(defined as top 5 genres of animes that the user has rated equal to or greater than their average rating)")
print("=====AUC=====")
print(f'Train AUC: {train_roc_auc6}')
print(f'Test AUC: {test_roc_auc6}')
print("=====Precision@K=====")
print(f'Train Precision: {train_precision_lfm6}')
print(f'Test Precision: {test_precision_lfm6}')
print("=====Recall@K=====")
print(f'Train Recall: {train_recall_lfm6}')
print(f'Test Recall: {test_recall_lfm6}')
# Out:
# User feature type 6: Top 5 genres among the genres that the user likes
# (defined as top 5 genres of animes that the user has rated equal to or greater than their average rating)
# =====AUC=====
# Train AUC: 0.9534088373184204
# Test AUC: 0.948606550693512
# =====Precision@K=====
# Train Precision: 0.24548037350177765
# Test Precision: 0.08721741288900375
# =====Recall@K=====
# Train Recall: 0.09267026219635398
# Test Recall: 0.08100045402382826

# %%
uid_map6, ufeature_map6, iid_map6, ifeature_map6 = dataset6.mapping()

# %%
iid_map6_reverse = dict((value,key) for key,value in iid_map6.items())

# %% [markdown]
# ### Predict for new user

# %%
# predict for new user
user_feature_list = ['Comedy','Romance','Slice of Life']

# %%
new_user_features = format_newuser_input(ufeature_map6, user_feature_list)

# %%
n_users6, n_items6 = interactions6.shape

# %%
model6_pred = model6.predict(0, np.arange(n_items6), user_features=new_user_features) # Here 0 means pick the first row of the user_features sparse matrix

# %%
pred_dict6 = {'media_id':data6['media_id'].unique(),'pred':model6_pred}

# %%
pred_df6 = pd.DataFrame(pred_dict6)

# %%
pred_df6 = pd.merge(pred_df6,anime_id_map,on='media_id')

# %%
pred_df6.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id         pred                            title_romaji  \
# 58      20923  4495.072754                      Shokugeki no Souma
# 221     20954  4393.568848                          Koe no Katachi
# 52      20665  3413.434082                 Shigatsu wa Kimi no Uso
# 101     21087  3335.565430                           One Punch Man
# 199     21519  3254.538574                          Kimi no Na wa.
# 11      19815  3218.475098                         No Game No Life
# 3       11757  2808.014404                        Sword Art Online
# 18      20594  2677.648682                     Sword Art Online II
# 104     21202  2596.048340  Kono Subarashii Sekai ni Shukufuku wo!
# 23     124080  2398.595703                                Horimiya
#
#                                          title_english  \
# 58                        Food Wars! Shokugeki no Soma
# 221                                     A Silent Voice
# 52                                   Your Lie in April
# 101                                      One-Punch Man
# 199                                         Your Name.
# 11                                    No Game, No Life
# 3                                     Sword Art Online
# 18                                 Sword Art Online II
# 104  KONOSUBA -God's blessing on this wonderful world!
# 23                                            Horimiya
#
#                          relations                                  genres
# 58                  [21518, 21691]                         [Comedy, Ecchi]
# 221                           None         [Drama, Romance, Slice of Life]
# 52                         [21039]  [Drama, Music, Romance, Slice of Life]
# 101          [21416, 97668, 21386]  [Action, Comedy, Sci-Fi, Supernatural]
# 199                           None          [Drama, Romance, Supernatural]
# 11                  [20769, 21875]     [Adventure, Comedy, Ecchi, Fantasy]
# 3           [20021, 20594, 124140]   [Action, Adventure, Fantasy, Romance]
# 18   [20021, 21403, 100183, 11757]    [Action, Adventure, Fantasy, Sci-Fi]
# 104                 [21574, 21699]            [Adventure, Comedy, Fantasy]
# 23                         [14753]        [Comedy, Romance, Slice of Life]

# %% [markdown]
# ### Predict for existing user

# %%
# user id 710080 is my own account
user_x = uid_map6[710080]
model6_pred_existing = model6.predict(user_x,np.arange(n_items6))

# %%
pred_dict6_existing = {'media_id':data6['media_id'].unique(),'pred':model6_pred_existing}

# %%
pred_df6_existing = pd.DataFrame(pred_dict6_existing)

# %%
pred_df6_existing = pd.merge(pred_df6_existing,anime_id_map,on='media_id')

# %%
pred_df6_existing.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id      pred                            title_romaji  \
# 58      20923  7.995938                      Shokugeki no Souma
# 221     20954  5.742288                          Koe no Katachi
# 52      20665  4.353853                 Shigatsu wa Kimi no Uso
# 199     21519  4.160835                          Kimi no Na wa.
# 11      19815  4.019316                         No Game No Life
# 101     21087  3.927083                           One Punch Man
# 23     124080  3.866499                                Horimiya
# 454     21518  3.750037          Shokugeki no Souma: Ni no Sara
# 104     21202  3.599964  Kono Subarashii Sekai ni Shukufuku wo!
# 18      20594  3.422680                     Sword Art Online II
#
#                                          title_english  \
# 58                        Food Wars! Shokugeki no Soma
# 221                                     A Silent Voice
# 52                                   Your Lie in April
# 199                                         Your Name.
# 11                                    No Game, No Life
# 101                                      One-Punch Man
# 23                                            Horimiya
# 454                        Food Wars! The Second Plate
# 104  KONOSUBA -God's blessing on this wonderful world!
# 18                                 Sword Art Online II
#
#                          relations                                  genres
# 58                  [21518, 21691]                         [Comedy, Ecchi]
# 221                           None         [Drama, Romance, Slice of Life]
# 52                         [21039]  [Drama, Music, Romance, Slice of Life]
# 199                           None          [Drama, Romance, Supernatural]
# 11                  [20769, 21875]     [Adventure, Comedy, Ecchi, Fantasy]
# 101          [21416, 97668, 21386]  [Action, Comedy, Sci-Fi, Supernatural]
# 23                         [14753]        [Comedy, Romance, Slice of Life]
# 454          [20923, 98702, 99255]                         [Comedy, Ecchi]
# 104                 [21574, 21699]            [Adventure, Comedy, Fantasy]
# 18   [20021, 21403, 100183, 11757]    [Action, Adventure, Fantasy, Sci-Fi]

# %% [markdown]
# ### Predict similar items

# %%
# Predicting for Yahari Ore no Seishun Love Come ga Machigatteiru.
# Comedy, Drama, Romance, Slice of Life
item_x = iid_map6[14813]

# %%
similar_pred6 = similar_items(item_id=item_x, item_features=item_features6, model=model6,N=100)
similar_pred6['media_id'] = similar_pred6['itemID'].map(iid_map6_reverse)

# %%
similar_pred6 = pd.merge(similar_pred6,anime_id_map,on='media_id')

# %%
similar_pred6.sort_values('score',ascending=False).head(10)
# Out:
#    itemID  score  media_id                                       title_romaji  \
# 0     515    1.0     21049                                             ReLIFE
# 1     451    1.0       853                             Ouran Koukou Host Club
# 2     721    1.0     18671                 Chuunibyou demo Koi ga Shitai! Ren
# 3      63    1.0     14813  Yahari Ore no Seishun Love Come wa Machigatteiru.
# 4     642    1.0     20698  Yahari Ore no Seishun Love Come wa Machigattei...
# 5     455    1.0     20596                                       Ao Haru Ride
# 6      54    1.0      4224                                          Toradora!
# 7      65    1.0     14741                     Chuunibyou demo Koi ga Shitai!
# 8     224    1.0    103572                               5-Toubun no Hanayome
# 9     765    1.0    108489  Yahari Ore no Seishun Love Come wa Machigattei...
#
#                                       title_english  \
# 0                                            ReLIFE
# 1                       Ouran High School Host Club
# 2  Love, Chunibyo & Other Delusions - Heart Throb -
# 3                     My Teen Romantic Comedy SNAFU
# 4                My Teen Romantic Comedy SNAFU TOO!
# 5                                  Blue Spring Ride
# 6                                         Toradora!
# 7                  Love, Chunibyo & Other Delusions
# 8                    The Quintessential Quintuplets
# 9             My Teen Romantic Comedy SNAFU Climax!
#
#                       relations                                   genres
# 0                       [98635]  [Comedy, Drama, Romance, Slice of Life]
# 1                          None  [Comedy, Drama, Romance, Slice of Life]
# 2  [16934, 20582, 20777, 20889]  [Comedy, Drama, Romance, Slice of Life]
# 3                [18753, 20698]  [Comedy, Drama, Romance, Slice of Life]
# 4        [14813, 21769, 108489]  [Comedy, Drama, Romance, Slice of Life]
# 5                [20900, 20837]  [Comedy, Drama, Romance, Slice of Life]
# 6                 [6127, 11553]  [Comedy, Drama, Romance, Slice of Life]
# 7  [16934, 15687, 15879, 19021]  [Comedy, Drama, Romance, Slice of Life]
# 8                      [109261]  [Comedy, Drama, Romance, Slice of Life]
# 9               [20698, 128643]  [Comedy, Drama, Romance, Slice of Life]

# %% [markdown]
# ### Preliminary analysis for user feature type 6

# %% [markdown]
# Top 10 predictions for new and existing user are largely similar.
#
# The results of the similar item predictions also look extremely good. It seems the similar item predictions are extremely similar between the 6 types, but in different order.
#
# In terms of model scores, types 1-6 have similar AUC scores, but type 4 has the best recall.
#
# Between types 1-6, I would select type 4 due to the higher recall, as well as increase in variety of recommendations between new and existing users

# %% [markdown]
# ## User type evaluation

# %% [markdown]
# ### Model scores

# %% [markdown]
# |        | Train AUC | Test AUC | Train Precision | Test Precision | Train Recall | Test Recall |
# |--------|-----------|----------|-----------------|----------------|--------------|-------------|
# | Type 1 | 0.953     | 0.949    | 0.219           | 0.078          | 0.071        | 0.066       |
# | Type 2 | 0.953     | 0.948    | 0.223           | 0.080          | 0.077        | 0.073       |
# | Type 3 | 0.954     | 0.949    | 0.238           | 0.084          | 0.097        | 0.083       |
# | Type 4 | 0.955     | 0.950    | 0.282           | 0.100          | 0.117        | 0.103       |
# | Type 5 | 0.953     | 0.948    | 0.256           | 0.090          | 0.100        | 0.086       |
# | Type 6 | 0.953     | 0.949    | 0.245           | 0.087          | 0.093        | 0.081       |

# %% [markdown]
# Types 1-6 have similar AUC scores, but Type 4 has the best precision and recall

# %% [markdown]
# ### New user predictions

# %%
pred_df1.columns = pred_df1.columns + "_1"
pred_df2.columns = pred_df2.columns + "_2"
pred_df3.columns = pred_df3.columns + "_3"
pred_df4.columns = pred_df4.columns + "_4"
pred_df5.columns = pred_df5.columns + "_5"
pred_df6.columns = pred_df6.columns + "_6"

# %%
new_user_preds = {'Type 1 preds':pred_df1.sort_values('pred_1',ascending = False).head(10)['title_romaji_1'].values,
                  'Type 2 preds':pred_df2.sort_values('pred_2',ascending = False).head(10)['title_romaji_2'].values,
                  'Type 3 preds':pred_df3.sort_values('pred_3',ascending = False).head(10)['title_romaji_3'].values,
                  'Type 4 preds':pred_df4.sort_values('pred_4',ascending = False).head(10)['title_romaji_4'].values,
                  'Type 5 preds':pred_df5.sort_values('pred_5',ascending = False).head(10)['title_romaji_5'].values,
                  'Type 6 preds':pred_df6.sort_values('pred_6',ascending = False).head(10)['title_romaji_6'].values}

# %%
new_user_preds = pd.DataFrame(new_user_preds)
new_user_preds
# Out:
#                              Type 1 preds  \
# 0                      Shokugeki no Souma
# 1                          Koe no Katachi
# 2                           One Punch Man
# 3                          Kimi no Na wa.
# 4                 Shigatsu wa Kimi no Uso
# 5                         No Game No Life
# 6                        Sword Art Online
# 7                     Sword Art Online II
# 8  Kono Subarashii Sekai ni Shukufuku wo!
# 9                    HUNTER×HUNTER (2011)
#
#                              Type 2 preds  \
# 0                      Shokugeki no Souma
# 1                          Koe no Katachi
# 2                          Kimi no Na wa.
# 3                           One Punch Man
# 4                 Shigatsu wa Kimi no Uso
# 5                         No Game No Life
# 6                        Sword Art Online
# 7                     Sword Art Online II
# 8  Kono Subarashii Sekai ni Shukufuku wo!
# 9                    HUNTER×HUNTER (2011)
#
#                              Type 3 preds  \
# 0                          Koe no Katachi
# 1                      Shokugeki no Souma
# 2                 Shigatsu wa Kimi no Uso
# 3                           One Punch Man
# 4                         No Game No Life
# 5                          Kimi no Na wa.
# 6                        Sword Art Online
# 7                     Sword Art Online II
# 8  Kono Subarashii Sekai ni Shukufuku wo!
# 9                     Hataraku Maou-sama!
#
#                              Type 4 preds  \
# 0                      Shokugeki no Souma
# 1                          Koe no Katachi
# 2                 Shigatsu wa Kimi no Uso
# 3                           One Punch Man
# 4                          Kimi no Na wa.
# 5                         No Game No Life
# 6                        Sword Art Online
# 7                     Sword Art Online II
# 8  Kono Subarashii Sekai ni Shukufuku wo!
# 9                     Hataraku Maou-sama!
#
#                              Type 5 preds  \
# 0                          Koe no Katachi
# 1                      Shokugeki no Souma
# 2                 Shigatsu wa Kimi no Uso
# 3                           One Punch Man
# 4                         No Game No Life
# 5                          Kimi no Na wa.
# 6                        Sword Art Online
# 7                     Sword Art Online II
# 8  Kono Subarashii Sekai ni Shukufuku wo!
# 9                    HUNTER×HUNTER (2011)
#
#                              Type 6 preds
# 0                      Shokugeki no Souma
# 1                          Koe no Katachi
# 2                 Shigatsu wa Kimi no Uso
# 3                           One Punch Man
# 4                          Kimi no Na wa.
# 5                         No Game No Life
# 6                        Sword Art Online
# 7                     Sword Art Online II
# 8  Kono Subarashii Sekai ni Shukufuku wo!
# 9                                Horimiya

# %% [markdown]
# For new user predictions, the top 9 predictions are all the same, but the top 5 varies in order. The 10th prediction varies slightly between the 6 types, recommending something that is not in the predictions of the other types.

# %% [markdown]
# ### Existing user predictions

# %%
pred_df1_existing.columns = pred_df1_existing.columns + "_1"
pred_df2_existing.columns = pred_df2_existing.columns + "_2"
pred_df3_existing.columns = pred_df3_existing.columns + "_3"
pred_df4_existing.columns = pred_df4_existing.columns + "_4"
pred_df5_existing.columns = pred_df5_existing.columns + "_5"
pred_df6_existing.columns = pred_df6_existing.columns + "_6"

# %%
existing_user_preds = {'Type 1 preds':pred_df1_existing.sort_values('pred_1',ascending = False).head(10)['title_romaji_1'].values,
                  'Type 2 preds':pred_df2_existing.sort_values('pred_2',ascending = False).head(10)['title_romaji_2'].values,
                  'Type 3 preds':pred_df3_existing.sort_values('pred_3',ascending = False).head(10)['title_romaji_3'].values,
                  'Type 4 preds':pred_df4_existing.sort_values('pred_4',ascending = False).head(10)['title_romaji_4'].values,
                  'Type 5 preds':pred_df5_existing.sort_values('pred_5',ascending = False).head(10)['title_romaji_5'].values,
                  'Type 6 preds':pred_df6_existing.sort_values('pred_6',ascending = False).head(10)['title_romaji_6'].values}

# %%
existing_user_preds = pd.DataFrame(existing_user_preds)
existing_user_preds
# Out:
#                              Type 1 preds  \
# 0                      Shokugeki no Souma
# 1                          Koe no Katachi
# 2                          Kimi no Na wa.
# 3          Shokugeki no Souma: Ni no Sara
# 4                 Shigatsu wa Kimi no Uso
# 5                           One Punch Man
# 6                         No Game No Life
# 7                                Horimiya
# 8  Kono Subarashii Sekai ni Shukufuku wo!
# 9                     Sword Art Online II
#
#                              Type 2 preds  \
# 0                      Shokugeki no Souma
# 1                          Koe no Katachi
# 2                          Kimi no Na wa.
# 3                 Shigatsu wa Kimi no Uso
# 4                         No Game No Life
# 5                           One Punch Man
# 6          Shokugeki no Souma: Ni no Sara
# 7                                Horimiya
# 8  Kono Subarashii Sekai ni Shukufuku wo!
# 9                     Sword Art Online II
#
#                              Type 3 preds  \
# 0                      Shokugeki no Souma
# 1                          Koe no Katachi
# 2                 Shigatsu wa Kimi no Uso
# 3                                  Hyouka
# 4                         No Game No Life
# 5                          Kimi no Na wa.
# 6                                Horimiya
# 7  Kono Subarashii Sekai ni Shukufuku wo!
# 8                           One Punch Man
# 9          Shokugeki no Souma: Ni no Sara
#
#                              Type 4 preds  \
# 0                      Shokugeki no Souma
# 1                          Koe no Katachi
# 2                                  Hyouka
# 3          Shokugeki no Souma: Ni no Sara
# 4                                Horimiya
# 5                 Shigatsu wa Kimi no Uso
# 6                          Kimi no Na wa.
# 7  Kono Subarashii Sekai ni Shukufuku wo!
# 8                         No Game No Life
# 9          Kobayashi-san Chi no Maidragon
#
#                              Type 5 preds  \
# 0                      Shokugeki no Souma
# 1                          Koe no Katachi
# 2                 Shigatsu wa Kimi no Uso
# 3                          Kimi no Na wa.
# 4                         No Game No Life
# 5                                Horimiya
# 6                           One Punch Man
# 7                                  Hyouka
# 8  Kono Subarashii Sekai ni Shukufuku wo!
# 9          Shokugeki no Souma: Ni no Sara
#
#                              Type 6 preds
# 0                      Shokugeki no Souma
# 1                          Koe no Katachi
# 2                 Shigatsu wa Kimi no Uso
# 3                          Kimi no Na wa.
# 4                         No Game No Life
# 5                           One Punch Man
# 6                                Horimiya
# 7          Shokugeki no Souma: Ni no Sara
# 8  Kono Subarashii Sekai ni Shukufuku wo!
# 9                     Sword Art Online II

# %% [markdown]
# For existing user predictions, there is much more variety than the new user predictions, however, they are still largely similar. Type 4 gives the most variety, as it recommends Hyouka which only types 3-5 recommended, and Kobayashi-san Chi no Maidragon which none of the other types recommended. Interestingly, type 4 does not recommend One Punch Man while the other 5 types do.
#
# As the user being used to churn the predictions is me, I would say all 6 types are decent predictions for me, as they contain animes that I have already watched and enjoyed, or animes that I know ae good and plan to watch. However, I would say that Type 4 is the best performing one, as it recommended Hyouka and Kobayashi-san Chi no Maidragon.

# %% [markdown]
# ### Similar item predictions

# %%
similar_pred1.columns = similar_pred1.columns + "_1"
similar_pred2.columns = similar_pred2.columns + "_2"
similar_pred3.columns = similar_pred3.columns + "_3"
similar_pred4.columns = similar_pred4.columns + "_4"
similar_pred5.columns = similar_pred5.columns + "_5"
similar_pred6.columns = similar_pred6.columns + "_6"

# %%
similar_item_preds = {'Type 1 preds':similar_pred1.sort_values('score_1',ascending = False).head(10)['title_romaji_1'].values,
                  'Type 2 preds':similar_pred2.sort_values('score_2',ascending = False).head(10)['title_romaji_2'].values,
                  'Type 3 preds':similar_pred3.sort_values('score_3',ascending = False).head(10)['title_romaji_3'].values,
                  'Type 4 preds':similar_pred4.sort_values('score_4',ascending = False).head(10)['title_romaji_4'].values,
                  'Type 5 preds':similar_pred5.sort_values('score_5',ascending = False).head(10)['title_romaji_5'].values,
                  'Type 6 preds':similar_pred6.sort_values('score_6',ascending = False).head(10)['title_romaji_6'].values}

# %%
similar_item_preds = pd.DataFrame(similar_item_preds)
similar_item_preds
# Out:
#                                         Type 1 preds  \
# 0                                          Toradora!
# 1                                     Kimi ni Todoke
# 2                 Chuunibyou demo Koi ga Shitai! Ren
# 3                             5-Toubun no Hanayome ∬
# 4  Yahari Ore no Seishun Love Come wa Machigatteiru.
# 5  Yahari Ore no Seishun Love Come wa Machigattei...
# 6                     Chuunibyou demo Koi ga Shitai!
# 7                             Ouran Koukou Host Club
# 8                                            Gamers!
# 9                               5-Toubun no Hanayome
#
#                                         Type 2 preds  \
# 0                                          Toradora!
# 1                                 Tsurezure Children
# 2                 Chuunibyou demo Koi ga Shitai! Ren
# 3                                       Ao Haru Ride
# 4                                             ReLIFE
# 5                             5-Toubun no Hanayome ∬
# 6                                            Gamers!
# 7  Yahari Ore no Seishun Love Come wa Machigattei...
# 8                                     Kimi ni Todoke
# 9                         Sakurasou no Pet na Kanojo
#
#                                         Type 3 preds  \
# 0  Yahari Ore no Seishun Love Come wa Machigattei...
# 1                               5-Toubun no Hanayome
# 2                                          Toradora!
# 3  Yahari Ore no Seishun Love Come wa Machigatteiru.
# 4                     Chuunibyou demo Koi ga Shitai!
# 5                                            Gamers!
# 6  Yahari Ore no Seishun Love Come wa Machigattei...
# 7                             Ouran Koukou Host Club
# 8                             5-Toubun no Hanayome ∬
# 9                         Sakurasou no Pet na Kanojo
#
#                                         Type 4 preds  \
# 0                               5-Toubun no Hanayome
# 1                                             ReLIFE
# 2                     Chuunibyou demo Koi ga Shitai!
# 3  Yahari Ore no Seishun Love Come wa Machigatteiru.
# 4                             Ouran Koukou Host Club
# 5                                       Ao Haru Ride
# 6                                 Tsurezure Children
# 7                                          Toradora!
# 8                 Chuunibyou demo Koi ga Shitai! Ren
# 9  Yahari Ore no Seishun Love Come wa Machigattei...
#
#                                         Type 5 preds  \
# 0                             Ouran Koukou Host Club
# 1                                          Toradora!
# 2                                            Gamers!
# 3                             5-Toubun no Hanayome ∬
# 4                                             ReLIFE
# 5                         Sakurasou no Pet na Kanojo
# 6                                       Ao Haru Ride
# 7  Yahari Ore no Seishun Love Come wa Machigatteiru.
# 8  Yahari Ore no Seishun Love Come wa Machigattei...
# 9                                 Tsurezure Children
#
#                                         Type 6 preds
# 0                                             ReLIFE
# 1                             Ouran Koukou Host Club
# 2                 Chuunibyou demo Koi ga Shitai! Ren
# 3  Yahari Ore no Seishun Love Come wa Machigatteiru.
# 4  Yahari Ore no Seishun Love Come wa Machigattei...
# 5                                       Ao Haru Ride
# 6                                          Toradora!
# 7                     Chuunibyou demo Koi ga Shitai!
# 8                               5-Toubun no Hanayome
# 9  Yahari Ore no Seishun Love Come wa Machigattei...

# %% [markdown]
# For similar item predictions, we got the model to recommend animes similar to [Yahari Ore no Seishun Love Come ga Machigatteiru.](https://anilist.co/anime/14813/Yahari-Ore-no-Seishun-Love-Come-wa-Machigatteiru). Overall, all 6 user types makes the model achieve excellent predictions, as all are romantic comedies. However, the model includes the input item in the output so we will need to be mindful of that when making the webapp.
#
# Some predictions are present in all 6 types. However, the order in each type is very different. Type 2 is the only model that did not include the input in the top 10 recommendations, and in terms of similarity of genres, all the predictions are good. Although, none of them (other than the sequel of the input anime) are really similar but that is not unexpected since the model is not given any additional information about the animes other than the genres and user ratings. From these results alone, all 6 types are viable.

# %% [markdown]
# ## Model tuning with selected user feature type

# %% [markdown]
# Given that all 6 types give similar AUC scores but type 4 has the highest recall, and the fact that type 4 gave the most satisfying predictions for existing users, we will proceed with user feature type 4: <br>
# Top 5 genres among the genres that the user likes (defined as top 5 genres of animes that the user has rated equal to or greater than their average rating)
#
# We will now tune the hyperparameters of the model to improve the score. We will tune the following hyperparameters: learning_rate, item_alpha, no_components, learning_schedule and no_epochs. As increasing the no_epochs will substantially increase the run time, we will tune the first 4 hyperparameters first, then tune no_epochs using the best 4 hyperparameters.

# %%
data_final = data[['user_id','media_id','rating','genres','top_5_genres_avg']]

# %%
all_anime_genres = sorted(list(set(itertools.chain.from_iterable(data_final['genres']))))

# %%
all_liked_genres = sorted(list(set(itertools.chain.from_iterable(data_final['top_5_genres_avg']))))

# %%
dataset = Dataset()

# %%
dataset.fit(data_final['user_id'],data_final['media_id'],user_features=all_liked_genres,item_features=all_anime_genres)

# %%
item_features = dataset.build_item_features((x,y) for x,y in zip(data_final['media_id'],data_final['genres']))

# %%
user_features = dataset.build_user_features((x,y) for x,y in zip(data_final['user_id'],data_final['top_5_genres_avg']))

# %%
(interactions, weights) = dataset.build_interactions(data_final.iloc[:, 0:3].values)

# %%
train_interactions, test_interactions = cross_validation.random_train_test_split(interactions, 
                                                                                 test_percentage=TEST_PERCENTAGE, 
                                                                                 random_state = np.random.RandomState(SEEDNO))

# %%
learning_rates = [.15,.25,.35]
item_alphas = [1e-6,1e-8,1e-10]
no_components = [10,20,50]
learning_schedules = ['adagrad','adadelta']

# %%
results = []
results_dict = {}
t0 = time.time()

for learning_rate in learning_rates:
    for item_alpha in item_alphas:
        for no_component in no_components:
            for learning_schedule in learning_schedules:
                t1 = time.time()
                results_dict = {'learning_rate':learning_rate,
                                'item_alpha':item_alpha,
                                'no_component':no_component,
                                'learning_schedule':learning_schedule,
                                'train_auc':.0,
                                'test_auc':.0,
                                'train_precision':.0,
                                'test_precision':.0,
                                'train_recall':.0,
                                'test_recall':.0,
                                'runtime':0}
                model = LightFM(loss='warp',
                               no_components = no_component,
                               learning_rate = learning_rate,
                               item_alpha = item_alpha,
                               learning_schedule=learning_schedule,
                               random_state = np.random.RandomState(SEEDNO))
                model.fit(interactions=  train_interactions,item_features = item_features,user_features=user_features,epochs = 10)
                results_dict['train_auc'] = auc_score(model,train_interactions,item_features=item_features,user_features=user_features).mean()
                results_dict['test_auc'] = auc_score(model,test_interactions,item_features=item_features,user_features=user_features).mean()
                results_dict['train_precision'] = lightfm_prec_at_k(model, train_interactions,item_features=item_features,user_features=user_features, k=K).mean()
                results_dict['test_precision'] = lightfm_prec_at_k(model, test_interactions,item_features=item_features,user_features=user_features, k=K).mean()
                results_dict['train_recall'] = lightfm_recall_at_k(model, train_interactions,item_features=item_features,user_features=user_features, k=K).mean()
                results_dict['test_recall'] = lightfm_recall_at_k(model, test_interactions,item_features=item_features,user_features=user_features, k=K).mean()
                t2 = time.time()
                results_dict['runtime'] = round(t2 - t1)

                results.append(results_dict)
                print(f"Fitted {results_dict}. Took {round(t2 - t1)} seconds.")
                print(f"Total time elapsed: {round(time.time() - t0)} seconds.")
                print("==========")
print("Completed")
# Out:
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-06, 'no_component': 10, 'learning_schedule': 'adagrad', 'train_auc': 0.95100766, 'test_auc': 0.9463143, 'train_precision': 0.21280977, 'test_precision': 0.07402519, 'train_recall': 0.07342505922590963, 'test_recall': 0.06721637021525063, 'runtime': 88}. Took 88 seconds.
# Total time elapsed: 88 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-06, 'no_component': 10, 'learning_schedule': 'adadelta', 'train_auc': 0.9501498, 'test_auc': 0.9458428, 'train_precision': 0.2533693, 'test_precision': 0.09098771, 'train_recall': 0.08314451057405499, 'test_recall': 0.07768569438050976, 'runtime': 125}. Took 125 seconds.
# Total time elapsed: 212 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-06, 'no_component': 20, 'learning_schedule': 'adagrad', 'train_auc': 0.95217055, 'test_auc': 0.94746685, 'train_precision': 0.2289001, 'test_precision': 0.080359586, 'train_recall': 0.0903910345491264, 'test_recall': 0.07806083861391849, 'runtime': 135}. Took 135 seconds.
# Total time elapsed: 347 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-06, 'no_component': 20, 'learning_schedule': 'adadelta', 'train_auc': 0.953329, 'test_auc': 0.94922364, 'train_precision': 0.2206064, 'test_precision': 0.07952511, 'train_recall': 0.08038924149607236, 'test_recall': 0.07115892997952217, 'runtime': 193}. Took 193 seconds.
# Total time elapsed: 540 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-06, 'no_component': 50, 'learning_schedule': 'adagrad', 'train_auc': 0.95323634, 'test_auc': 0.9483391, 'train_precision': 0.2507491, 'test_precision': 0.08826431, 'train_recall': 0.10631687054164743, 'test_recall': 0.09128466580427096, 'runtime': 265}. Took 265 seconds.
# Total time elapsed: 805 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-06, 'no_component': 50, 'learning_schedule': 'adadelta', 'train_auc': 0.95076793, 'test_auc': 0.9464934, 'train_precision': 0.26576015, 'test_precision': 0.094689734, 'train_recall': 0.10284201550343698, 'test_recall': 0.08945144744613909, 'runtime': 432}. Took 432 seconds.
# Total time elapsed: 1237 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-08, 'no_component': 10, 'learning_schedule': 'adagrad', 'train_auc': 0.9508927, 'test_auc': 0.9462054, 'train_precision': 0.21416602, 'test_precision': 0.07558034, 'train_recall': 0.07292814367588807, 'test_recall': 0.06804217311168965, 'runtime': 94}. Took 94 seconds.
# Total time elapsed: 1331 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-08, 'no_component': 10, 'learning_schedule': 'adadelta', 'train_auc': 0.95302916, 'test_auc': 0.9488498, 'train_precision': 0.2504296, 'test_precision': 0.08877257, 'train_recall': 0.08901936301496424, 'test_recall': 0.08067151134662504, 'runtime': 127}. Took 127 seconds.
# Total time elapsed: 1458 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-08, 'no_component': 20, 'learning_schedule': 'adagrad', 'train_auc': 0.95220387, 'test_auc': 0.94747496, 'train_precision': 0.22762905, 'test_precision': 0.080124415, 'train_recall': 0.0881280620607934, 'test_recall': 0.07653000953147633, 'runtime': 139}. Took 139 seconds.
# Total time elapsed: 1597 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-08, 'no_component': 20, 'learning_schedule': 'adadelta', 'train_auc': 0.9530682, 'test_auc': 0.9487188, 'train_precision': 0.25660726, 'test_precision': 0.09192839, 'train_recall': 0.11437799360333845, 'test_recall': 0.09615589698191286, 'runtime': 204}. Took 204 seconds.
# Total time elapsed: 1800 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-08, 'no_component': 50, 'learning_schedule': 'adagrad', 'train_auc': 0.95292336, 'test_auc': 0.9480396, 'train_precision': 0.24938579, 'test_precision': 0.08871188, 'train_recall': 0.10277599019981758, 'test_recall': 0.08979338348658913, 'runtime': 277}. Took 277 seconds.
# Total time elapsed: 2077 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-08, 'no_component': 50, 'learning_schedule': 'adadelta', 'train_auc': 0.94968045, 'test_auc': 0.9452604, 'train_precision': 0.2279912, 'test_precision': 0.08186164, 'train_recall': 0.09822794897746971, 'test_recall': 0.08369647116993219, 'runtime': 436}. Took 436 seconds.
# Total time elapsed: 2513 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-10, 'no_component': 10, 'learning_schedule': 'adagrad', 'train_auc': 0.9508949, 'test_auc': 0.9461944, 'train_precision': 0.20614216, 'test_precision': 0.07205281, 'train_recall': 0.07131591967440495, 'test_recall': 0.06521156700778033, 'runtime': 94}. Took 94 seconds.
# Total time elapsed: 2607 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-10, 'no_component': 10, 'learning_schedule': 'adadelta', 'train_auc': 0.95241493, 'test_auc': 0.94835615, 'train_precision': 0.2550806, 'test_precision': 0.090130486, 'train_recall': 0.09066002939875221, 'test_recall': 0.08253078590214619, 'runtime': 130}. Took 130 seconds.
# Total time elapsed: 2737 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-10, 'no_component': 20, 'learning_schedule': 'adagrad', 'train_auc': 0.95213795, 'test_auc': 0.94733, 'train_precision': 0.23968615, 'test_precision': 0.08436505, 'train_recall': 0.09693248758321565, 'test_recall': 0.08556558684097318, 'runtime': 139}. Took 139 seconds.
# Total time elapsed: 2876 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-10, 'no_component': 20, 'learning_schedule': 'adadelta', 'train_auc': 0.9521787, 'test_auc': 0.9476974, 'train_precision': 0.27242777, 'test_precision': 0.09817934, 'train_recall': 0.10134654496900763, 'test_recall': 0.09115894360768535, 'runtime': 204}. Took 204 seconds.
# Total time elapsed: 3080 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-10, 'no_component': 50, 'learning_schedule': 'adagrad', 'train_auc': 0.9533133, 'test_auc': 0.9484809, 'train_precision': 0.2513811, 'test_precision': 0.08902291, 'train_recall': 0.10381861889398063, 'test_recall': 0.090795119223434, 'runtime': 279}. Took 279 seconds.
# Total time elapsed: 3359 seconds.
# ==========
# Fitted {'learning_rate': 0.15, 'item_alpha': 1e-10, 'no_component': 50, 'learning_schedule': 'adadelta', 'train_auc': 0.9522739, 'test_auc': 0.9479609, 'train_precision': 0.25576225, 'test_precision': 0.09114702, 'train_recall': 0.10942405185711082, 'test_recall': 0.09333861194616139, 'runtime': 436}. Took 436 seconds.
# Total time elapsed: 3795 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-06, 'no_component': 10, 'learning_schedule': 'adagrad', 'train_auc': 0.9526835, 'test_auc': 0.9478652, 'train_precision': 0.24475609, 'test_precision': 0.086504325, 'train_recall': 0.09226141246431421, 'test_recall': 0.08312193526872456, 'runtime': 93}. Took 93 seconds.
# Total time elapsed: 3888 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-06, 'no_component': 10, 'learning_schedule': 'adadelta', 'train_auc': 0.9501498, 'test_auc': 0.9458428, 'train_precision': 0.2533693, 'test_precision': 0.09098771, 'train_recall': 0.08314451057405499, 'test_recall': 0.07768569438050976, 'runtime': 131}. Took 131 seconds.
# Total time elapsed: 4019 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-06, 'no_component': 20, 'learning_schedule': 'adagrad', 'train_auc': 0.9529609, 'test_auc': 0.94814926, 'train_precision': 0.251516, 'test_precision': 0.08905326, 'train_recall': 0.10278047588473227, 'test_recall': 0.09084856548186696, 'runtime': 137}. Took 137 seconds.
# Total time elapsed: 4155 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-06, 'no_component': 20, 'learning_schedule': 'adadelta', 'train_auc': 0.953329, 'test_auc': 0.94922364, 'train_precision': 0.2206064, 'test_precision': 0.07952511, 'train_recall': 0.08038924149607236, 'test_recall': 0.07115892997952217, 'runtime': 204}. Took 204 seconds.
# Total time elapsed: 4359 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-06, 'no_component': 50, 'learning_schedule': 'adagrad', 'train_auc': 0.95402396, 'test_auc': 0.9489061, 'train_precision': 0.2679756, 'test_precision': 0.0940525, 'train_recall': 0.11645499060729611, 'test_recall': 0.09714777104010923, 'runtime': 274}. Took 274 seconds.
# Total time elapsed: 4633 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-06, 'no_component': 50, 'learning_schedule': 'adadelta', 'train_auc': 0.95076793, 'test_auc': 0.9464934, 'train_precision': 0.26576015, 'test_precision': 0.094689734, 'train_recall': 0.10284201550343698, 'test_recall': 0.08945144744613909, 'runtime': 437}. Took 437 seconds.
# Total time elapsed: 5071 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-08, 'no_component': 10, 'learning_schedule': 'adagrad', 'train_auc': 0.9524579, 'test_auc': 0.9475547, 'train_precision': 0.23547539, 'test_precision': 0.083621606, 'train_recall': 0.08428458537068724, 'test_recall': 0.07754515815239847, 'runtime': 92}. Took 92 seconds.
# Total time elapsed: 5163 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-08, 'no_component': 10, 'learning_schedule': 'adadelta', 'train_auc': 0.95302916, 'test_auc': 0.9488498, 'train_precision': 0.2504296, 'test_precision': 0.08877257, 'train_recall': 0.08901936301496424, 'test_recall': 0.08067151134662504, 'runtime': 129}. Took 129 seconds.
# Total time elapsed: 5292 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-08, 'no_component': 20, 'learning_schedule': 'adagrad', 'train_auc': 0.9533329, 'test_auc': 0.9482773, 'train_precision': 0.25500247, 'test_precision': 0.089971185, 'train_recall': 0.1068325186812789, 'test_recall': 0.09258565163800911, 'runtime': 136}. Took 136 seconds.
# Total time elapsed: 5429 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-08, 'no_component': 20, 'learning_schedule': 'adadelta', 'train_auc': 0.9530682, 'test_auc': 0.9487188, 'train_precision': 0.25660726, 'test_precision': 0.09192839, 'train_recall': 0.11437799360333845, 'test_recall': 0.09615589698191286, 'runtime': 204}. Took 204 seconds.
# Total time elapsed: 5632 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-08, 'no_component': 50, 'learning_schedule': 'adagrad', 'train_auc': 0.9544202, 'test_auc': 0.9493533, 'train_precision': 0.25445575, 'test_precision': 0.09022152, 'train_recall': 0.10798430660842104, 'test_recall': 0.09021599211436045, 'runtime': 272}. Took 272 seconds.
# Total time elapsed: 5904 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-08, 'no_component': 50, 'learning_schedule': 'adadelta', 'train_auc': 0.94968045, 'test_auc': 0.9452604, 'train_precision': 0.2279912, 'test_precision': 0.08186164, 'train_recall': 0.09822794897746971, 'test_recall': 0.08369647116993219, 'runtime': 435}. Took 435 seconds.
# Total time elapsed: 6339 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-10, 'no_component': 10, 'learning_schedule': 'adagrad', 'train_auc': 0.9523431, 'test_auc': 0.9474519, 'train_precision': 0.23020664, 'test_precision': 0.08182371, 'train_recall': 0.08545378570567062, 'test_recall': 0.07837797233710664, 'runtime': 92}. Took 92 seconds.
# Total time elapsed: 6431 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-10, 'no_component': 10, 'learning_schedule': 'adadelta', 'train_auc': 0.95241493, 'test_auc': 0.94835615, 'train_precision': 0.2550806, 'test_precision': 0.090130486, 'train_recall': 0.09066002939875221, 'test_recall': 0.08253078590214619, 'runtime': 129}. Took 129 seconds.
# Total time elapsed: 6560 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-10, 'no_component': 20, 'learning_schedule': 'adagrad', 'train_auc': 0.95325524, 'test_auc': 0.9482681, 'train_precision': 0.25554925, 'test_precision': 0.0906691, 'train_recall': 0.1085148248628432, 'test_recall': 0.09392621495674529, 'runtime': 139}. Took 139 seconds.
# Total time elapsed: 6700 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-10, 'no_component': 20, 'learning_schedule': 'adadelta', 'train_auc': 0.9521787, 'test_auc': 0.9476974, 'train_precision': 0.27242777, 'test_precision': 0.09817934, 'train_recall': 0.10134654496900763, 'test_recall': 0.09115894360768535, 'runtime': 204}. Took 204 seconds.
# Total time elapsed: 6904 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-10, 'no_component': 50, 'learning_schedule': 'adagrad', 'train_auc': 0.95316756, 'test_auc': 0.94797194, 'train_precision': 0.25801322, 'test_precision': 0.091920815, 'train_recall': 0.10832461067755284, 'test_recall': 0.09277090661797285, 'runtime': 271}. Took 271 seconds.
# Total time elapsed: 7175 seconds.
# ==========
# Fitted {'learning_rate': 0.25, 'item_alpha': 1e-10, 'no_component': 50, 'learning_schedule': 'adadelta', 'train_auc': 0.9522739, 'test_auc': 0.9479609, 'train_precision': 0.25576225, 'test_precision': 0.09114702, 'train_recall': 0.10942405185711082, 'test_recall': 0.09333861194616139, 'runtime': 438}. Took 438 seconds.
# Total time elapsed: 7613 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-06, 'no_component': 10, 'learning_schedule': 'adagrad', 'train_auc': 0.9533989, 'test_auc': 0.9484972, 'train_precision': 0.26083222, 'test_precision': 0.09233805, 'train_recall': 0.10767637918238442, 'test_recall': 0.09189338571596428, 'runtime': 93}. Took 93 seconds.
# Total time elapsed: 7706 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-06, 'no_component': 10, 'learning_schedule': 'adadelta', 'train_auc': 0.9501498, 'test_auc': 0.9458428, 'train_precision': 0.2533693, 'test_precision': 0.09098771, 'train_recall': 0.08314451057405499, 'test_recall': 0.07768569438050976, 'runtime': 133}. Took 133 seconds.
# Total time elapsed: 7839 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-06, 'no_component': 20, 'learning_schedule': 'adagrad', 'train_auc': 0.95406926, 'test_auc': 0.9489947, 'train_precision': 0.26429027, 'test_precision': 0.09285389, 'train_recall': 0.11316656592014462, 'test_recall': 0.09647698477928532, 'runtime': 135}. Took 135 seconds.
# Total time elapsed: 7974 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-06, 'no_component': 20, 'learning_schedule': 'adadelta', 'train_auc': 0.953329, 'test_auc': 0.94922364, 'train_precision': 0.2206064, 'test_precision': 0.07952511, 'train_recall': 0.08038924149607236, 'test_recall': 0.07115892997952217, 'runtime': 204}. Took 204 seconds.
# Total time elapsed: 8178 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-06, 'no_component': 50, 'learning_schedule': 'adagrad', 'train_auc': 0.9545434, 'test_auc': 0.94925225, 'train_precision': 0.2821771, 'test_precision': 0.10091792, 'train_recall': 0.12009213852298505, 'test_recall': 0.10188772224542005, 'runtime': 271}. Took 271 seconds.
# Total time elapsed: 8450 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-06, 'no_component': 50, 'learning_schedule': 'adadelta', 'train_auc': 0.95076793, 'test_auc': 0.9464934, 'train_precision': 0.26576015, 'test_precision': 0.094689734, 'train_recall': 0.10284201550343698, 'test_recall': 0.08945144744613909, 'runtime': 456}. Took 456 seconds.
# Total time elapsed: 8906 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-08, 'no_component': 10, 'learning_schedule': 'adagrad', 'train_auc': 0.95346415, 'test_auc': 0.94833225, 'train_precision': 0.26127955, 'test_precision': 0.09248218, 'train_recall': 0.109623421689283, 'test_recall': 0.094470901448529, 'runtime': 91}. Took 91 seconds.
# Total time elapsed: 8996 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-08, 'no_component': 10, 'learning_schedule': 'adadelta', 'train_auc': 0.95302916, 'test_auc': 0.9488498, 'train_precision': 0.2504296, 'test_precision': 0.08877257, 'train_recall': 0.08901936301496424, 'test_recall': 0.08067151134662504, 'runtime': 129}. Took 129 seconds.
# Total time elapsed: 9125 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-08, 'no_component': 20, 'learning_schedule': 'adagrad', 'train_auc': 0.9536821, 'test_auc': 0.948635, 'train_precision': 0.25739545, 'test_precision': 0.09201184, 'train_recall': 0.10825823802012263, 'test_recall': 0.09385273389368971, 'runtime': 135}. Took 135 seconds.
# Total time elapsed: 9260 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-08, 'no_component': 20, 'learning_schedule': 'adadelta', 'train_auc': 0.9530682, 'test_auc': 0.9487188, 'train_precision': 0.25660726, 'test_precision': 0.09192839, 'train_recall': 0.11437799360333845, 'test_recall': 0.09615589698191286, 'runtime': 204}. Took 204 seconds.
# Total time elapsed: 9465 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-08, 'no_component': 50, 'learning_schedule': 'adagrad', 'train_auc': 0.9545067, 'test_auc': 0.94902897, 'train_precision': 0.26010793, 'test_precision': 0.09353665, 'train_recall': 0.1132319810621045, 'test_recall': 0.09687993377947907, 'runtime': 261}. Took 261 seconds.
# Total time elapsed: 9726 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-08, 'no_component': 50, 'learning_schedule': 'adadelta', 'train_auc': 0.94968045, 'test_auc': 0.9452604, 'train_precision': 0.2279912, 'test_precision': 0.08186164, 'train_recall': 0.09822794897746971, 'test_recall': 0.08369647116993219, 'runtime': 428}. Took 428 seconds.
# Total time elapsed: 10154 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-10, 'no_component': 10, 'learning_schedule': 'adagrad', 'train_auc': 0.9534922, 'test_auc': 0.94842666, 'train_precision': 0.26222396, 'test_precision': 0.09291458, 'train_recall': 0.1083573043196428, 'test_recall': 0.09320055227328371, 'runtime': 92}. Took 92 seconds.
# Total time elapsed: 10245 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-10, 'no_component': 10, 'learning_schedule': 'adadelta', 'train_auc': 0.95241493, 'test_auc': 0.94835615, 'train_precision': 0.2550806, 'test_precision': 0.090130486, 'train_recall': 0.09066002939875221, 'test_recall': 0.08253078590214619, 'runtime': 128}. Took 128 seconds.
# Total time elapsed: 10374 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-10, 'no_component': 20, 'learning_schedule': 'adagrad', 'train_auc': 0.9537658, 'test_auc': 0.94860995, 'train_precision': 0.24807924, 'test_precision': 0.08819603, 'train_recall': 0.10107921868027621, 'test_recall': 0.08744015916292269, 'runtime': 135}. Took 135 seconds.
# Total time elapsed: 10509 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-10, 'no_component': 20, 'learning_schedule': 'adadelta', 'train_auc': 0.9521787, 'test_auc': 0.9476974, 'train_precision': 0.27242777, 'test_precision': 0.09817934, 'train_recall': 0.10134654496900763, 'test_recall': 0.09115894360768535, 'runtime': 202}. Took 202 seconds.
# Total time elapsed: 10711 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-10, 'no_component': 50, 'learning_schedule': 'adagrad', 'train_auc': 0.9544618, 'test_auc': 0.9490933, 'train_precision': 0.26109493, 'test_precision': 0.0918677, 'train_recall': 0.10835780847717316, 'test_recall': 0.09113443331000176, 'runtime': 271}. Took 271 seconds.
# Total time elapsed: 10982 seconds.
# ==========
# Fitted {'learning_rate': 0.35, 'item_alpha': 1e-10, 'no_component': 50, 'learning_schedule': 'adadelta', 'train_auc': 0.9522739, 'test_auc': 0.9479609, 'train_precision': 0.25576225, 'test_precision': 0.09114702, 'train_recall': 0.10942405185711082, 'test_recall': 0.09333861194616139, 'runtime': 435}. Took 435 seconds.
# Total time elapsed: 11417 seconds.
# ==========
# Completed

# %%
results_df = pd.DataFrame(results)

# %%
results_df['test_auc_rank'] = results_df['test_auc'].rank(ascending=False)
results_df['test_precision_rank'] = results_df['test_precision'].rank(ascending=False)
results_df['test_recall_rank'] = results_df['test_recall'].rank(ascending=False)

# %%
results_df.sort_values('test_recall_rank')
# Out:
#     learning_rate    item_alpha  no_component learning_schedule  train_auc  \
# 40           0.35  1.000000e-06            50           adagrad   0.954543
# 22           0.25  1.000000e-06            50           adagrad   0.954024
# 46           0.35  1.000000e-08            50           adagrad   0.954507
# 38           0.35  1.000000e-06            20           adagrad   0.954069
# 45           0.35  1.000000e-08            20          adadelta   0.953068
# 9            0.15  1.000000e-08            20          adadelta   0.953068
# 27           0.25  1.000000e-08            20          adadelta   0.953068
# 42           0.35  1.000000e-08            10           adagrad   0.953464
# 32           0.25  1.000000e-10            20           adagrad   0.953255
# 44           0.35  1.000000e-08            20           adagrad   0.953682
# 53           0.35  1.000000e-10            50          adadelta   0.952274
# 35           0.25  1.000000e-10            50          adadelta   0.952274
# 17           0.15  1.000000e-10            50          adadelta   0.952274
# 48           0.35  1.000000e-10            10           adagrad   0.953492
# 34           0.25  1.000000e-10            50           adagrad   0.953168
# 26           0.25  1.000000e-08            20           adagrad   0.953333
# 36           0.35  1.000000e-06            10           adagrad   0.953399
# 4            0.15  1.000000e-06            50           adagrad   0.953236
# 51           0.35  1.000000e-10            20          adadelta   0.952179
# 15           0.15  1.000000e-10            20          adadelta   0.952179
# 33           0.25  1.000000e-10            20          adadelta   0.952179
# 52           0.35  1.000000e-10            50           adagrad   0.954462
# 20           0.25  1.000000e-06            20           adagrad   0.952961
# 16           0.15  1.000000e-10            50           adagrad   0.953313
# 28           0.25  1.000000e-08            50           adagrad   0.954420
# 10           0.15  1.000000e-08            50           adagrad   0.952923
# 23           0.25  1.000000e-06            50          adadelta   0.950768
# 41           0.35  1.000000e-06            50          adadelta   0.950768
# 5            0.15  1.000000e-06            50          adadelta   0.950768
# 50           0.35  1.000000e-10            20           adagrad   0.953766
# 14           0.15  1.000000e-10            20           adagrad   0.952138
# 11           0.15  1.000000e-08            50          adadelta   0.949680
# 47           0.35  1.000000e-08            50          adadelta   0.949680
# 29           0.25  1.000000e-08            50          adadelta   0.949680
# 18           0.25  1.000000e-06            10           adagrad   0.952684
# 13           0.15  1.000000e-10            10          adadelta   0.952415
# 49           0.35  1.000000e-10            10          adadelta   0.952415
# 31           0.25  1.000000e-10            10          adadelta   0.952415
# 7            0.15  1.000000e-08            10          adadelta   0.953029
# 25           0.25  1.000000e-08            10          adadelta   0.953029
# 43           0.35  1.000000e-08            10          adadelta   0.953029
# 30           0.25  1.000000e-10            10           adagrad   0.952343
# 2            0.15  1.000000e-06            20           adagrad   0.952171
# 1            0.15  1.000000e-06            10          adadelta   0.950150
# 19           0.25  1.000000e-06            10          adadelta   0.950150
# 37           0.35  1.000000e-06            10          adadelta   0.950150
# 24           0.25  1.000000e-08            10           adagrad   0.952458
# 8            0.15  1.000000e-08            20           adagrad   0.952204
# 39           0.35  1.000000e-06            20          adadelta   0.953329
# 21           0.25  1.000000e-06            20          adadelta   0.953329
# 3            0.15  1.000000e-06            20          adadelta   0.953329
# 6            0.15  1.000000e-08            10           adagrad   0.950893
# 0            0.15  1.000000e-06            10           adagrad   0.951008
# 12           0.15  1.000000e-10            10           adagrad   0.950895
#
#     test_auc  train_precision  test_precision  train_recall  test_recall  \
# 40  0.949252         0.282177        0.100918      0.120092     0.101888
# 22  0.948906         0.267976        0.094053      0.116455     0.097148
# 46  0.949029         0.260108        0.093537      0.113232     0.096880
# 38  0.948995         0.264290        0.092854      0.113167     0.096477
# 45  0.948719         0.256607        0.091928      0.114378     0.096156
# 9   0.948719         0.256607        0.091928      0.114378     0.096156
# 27  0.948719         0.256607        0.091928      0.114378     0.096156
# 42  0.948332         0.261280        0.092482      0.109623     0.094471
# 32  0.948268         0.255549        0.090669      0.108515     0.093926
# 44  0.948635         0.257395        0.092012      0.108258     0.093853
# 53  0.947961         0.255762        0.091147      0.109424     0.093339
# 35  0.947961         0.255762        0.091147      0.109424     0.093339
# 17  0.947961         0.255762        0.091147      0.109424     0.093339
# 48  0.948427         0.262224        0.092915      0.108357     0.093201
# 34  0.947972         0.258013        0.091921      0.108325     0.092771
# 26  0.948277         0.255002        0.089971      0.106833     0.092586
# 36  0.948497         0.260832        0.092338      0.107676     0.091893
# 4   0.948339         0.250749        0.088264      0.106317     0.091285
# 51  0.947697         0.272428        0.098179      0.101347     0.091159
# 15  0.947697         0.272428        0.098179      0.101347     0.091159
# 33  0.947697         0.272428        0.098179      0.101347     0.091159
# 52  0.949093         0.261095        0.091868      0.108358     0.091134
# 20  0.948149         0.251516        0.089053      0.102780     0.090849
# 16  0.948481         0.251381        0.089023      0.103819     0.090795
# 28  0.949353         0.254456        0.090222      0.107984     0.090216
# 10  0.948040         0.249386        0.088712      0.102776     0.089793
# 23  0.946493         0.265760        0.094690      0.102842     0.089451
# 41  0.946493         0.265760        0.094690      0.102842     0.089451
# 5   0.946493         0.265760        0.094690      0.102842     0.089451
# 50  0.948610         0.248079        0.088196      0.101079     0.087440
# 14  0.947330         0.239686        0.084365      0.096932     0.085566
# 11  0.945260         0.227991        0.081862      0.098228     0.083696
# 47  0.945260         0.227991        0.081862      0.098228     0.083696
# 29  0.945260         0.227991        0.081862      0.098228     0.083696
# 18  0.947865         0.244756        0.086504      0.092261     0.083122
# 13  0.948356         0.255081        0.090130      0.090660     0.082531
# 49  0.948356         0.255081        0.090130      0.090660     0.082531
# 31  0.948356         0.255081        0.090130      0.090660     0.082531
# 7   0.948850         0.250430        0.088773      0.089019     0.080672
# 25  0.948850         0.250430        0.088773      0.089019     0.080672
# 43  0.948850         0.250430        0.088773      0.089019     0.080672
# 30  0.947452         0.230207        0.081824      0.085454     0.078378
# 2   0.947467         0.228900        0.080360      0.090391     0.078061
# 1   0.945843         0.253369        0.090988      0.083145     0.077686
# 19  0.945843         0.253369        0.090988      0.083145     0.077686
# 37  0.945843         0.253369        0.090988      0.083145     0.077686
# 24  0.947555         0.235475        0.083622      0.084285     0.077545
# 8   0.947475         0.227629        0.080124      0.088128     0.076530
# 39  0.949224         0.220606        0.079525      0.080389     0.071159
# 21  0.949224         0.220606        0.079525      0.080389     0.071159
# 3   0.949224         0.220606        0.079525      0.080389     0.071159
# 6   0.946205         0.214166        0.075580      0.072928     0.068042
# 0   0.946314         0.212810        0.074025      0.073425     0.067216
# 12  0.946194         0.206142        0.072053      0.071316     0.065212
#
#     runtime  test_auc_rank  test_precision_rank  test_recall_rank
# 40      271            2.0                  1.0               1.0
# 22      274            9.0                  8.0               2.0
# 46      261            7.0                  9.0               3.0
# 38      135            8.0                 11.0               4.0
# 45      204           14.0                 16.0               6.0
# 9       204           14.0                 16.0               6.0
# 27      204           14.0                 16.0               6.0
# 42       91           25.0                 12.0               8.0
# 32      139           27.0                 26.0               9.0
# 44      135           16.0                 14.0              10.0
# 53      435           32.0                 21.0              12.0
# 35      438           32.0                 21.0              12.0
# 17      436           32.0                 21.0              12.0
# 48       92           20.0                 10.0              14.0
# 34      271           30.0                 18.0              15.0
# 26      136           26.0                 31.0              16.0
# 36       93           18.0                 13.0              17.0
# 4       265           24.0                 38.0              18.0
# 51      202           36.0                  3.0              20.0
# 15      204           36.0                  3.0              20.0
# 33      204           36.0                  3.0              20.0
# 52      271            6.0                 19.0              22.0
# 20      137           28.0                 32.0              23.0
# 16      279           19.0                 33.0              24.0
# 28      272            1.0                 27.0              25.0
# 10      277           29.0                 37.0              26.0
# 23      437           44.0                  6.0              28.0
# 41      456           44.0                  6.0              28.0
# 5       432           44.0                  6.0              28.0
# 50      135           17.0                 39.0              30.0
# 14      139           42.0                 41.0              31.0
# 11      436           53.0                 44.0              33.0
# 47      428           53.0                 44.0              33.0
# 29      435           53.0                 44.0              33.0
# 18       93           34.0                 40.0              35.0
# 13      130           22.0                 29.0              37.0
# 49      128           22.0                 29.0              37.0
# 31      129           22.0                 29.0              37.0
# 7       127           11.0                 35.0              40.0
# 25      129           11.0                 35.0              40.0
# 43      129           11.0                 35.0              40.0
# 30       92           41.0                 46.0              42.0
# 2       135           40.0                 47.0              43.0
# 1       125           50.0                 24.0              45.0
# 19      131           50.0                 24.0              45.0
# 37      133           50.0                 24.0              45.0
# 24       92           38.0                 42.0              47.0
# 8       139           39.0                 48.0              48.0
# 39      204            4.0                 50.0              50.0
# 21      204            4.0                 50.0              50.0
# 3       193            4.0                 50.0              50.0
# 6        94           47.0                 52.0              52.0
# 0        88           46.0                 53.0              53.0
# 12       94           48.0                 54.0              54.0

# %% [markdown]
# We will take the parameters of the model with the best recall: learning_rate = 0.35, item_alpha = 1e-6, no_components = 50, learning_schedule = adagrad.
#
# Next we will tune the number of epochs.

# %%
results = []
results_dict = {}
no_epochs = [10,20,60,100]
t0 = time.time()

for no_epoch in no_epochs:
    t1 = time.time()
    results_dict = {'no_epochs':no_epoch,
                    'train_auc':.0,
                    'test_auc':.0,
                    'train_precision':.0,
                    'test_precision':.0,
                    'train_recall':.0,
                    'test_recall':.0,
                    'runtime':0}
    model = LightFM(loss='warp',
                   no_components = 50,
                   learning_rate = .35,
                   item_alpha = 1e-6,
                   learning_schedule='adagrad',
                   random_state = np.random.RandomState(SEEDNO))
    model.fit(interactions=  train_interactions,item_features = item_features,user_features=user_features,epochs = no_epoch)
    results_dict['train_auc'] = auc_score(model,train_interactions,item_features=item_features,user_features=user_features).mean()
    results_dict['test_auc'] = auc_score(model,test_interactions,item_features=item_features,user_features=user_features).mean()
    results_dict['train_precision'] = lightfm_prec_at_k(model, train_interactions,item_features=item_features,user_features=user_features, k=K).mean()
    results_dict['test_precision'] = lightfm_prec_at_k(model, test_interactions,item_features=item_features,user_features=user_features, k=K).mean()
    results_dict['train_recall'] = lightfm_recall_at_k(model, train_interactions,item_features=item_features,user_features=user_features, k=K).mean()
    results_dict['test_recall'] = lightfm_recall_at_k(model, test_interactions,item_features=item_features,user_features=user_features, k=K).mean()
    t2 = time.time()
    results_dict['runtime'] = round(t2 - t1)
    results.append(results_dict)
    print(f"Fitted {results_dict}. Took {round(t2-t1)} seconds.")
    print(f"Total time elapsed: {round(time.time()-t0)} seconds.")
    print("==========")
print("Completed")
# Out:
# Fitted {'no_epochs': 10, 'train_auc': 0.9545434, 'test_auc': 0.94925225, 'train_precision': 0.2821771, 'test_precision': 0.10091792, 'train_recall': 0.12009213852298505, 'test_recall': 0.10188772224542005, 'runtime': 257}. Took 257 seconds.
# Total time elapsed: 257 seconds.
# ==========
# Fitted {'no_epochs': 20, 'train_auc': 0.9561822, 'test_auc': 0.95052236, 'train_precision': 0.28527302, 'test_precision': 0.10167653, 'train_recall': 0.11922310437088121, 'test_recall': 0.10113011971781795, 'runtime': 416}. Took 416 seconds.
# Total time elapsed: 673 seconds.
# ==========
# Fitted {'no_epochs': 60, 'train_auc': 0.95873404, 'test_auc': 0.95196784, 'train_precision': 0.3397998, 'test_precision': 0.121643156, 'train_recall': 0.13790965131970803, 'test_recall': 0.11950063231451379, 'runtime': 980}. Took 980 seconds.
# Total time elapsed: 1653 seconds.
# ==========
# Fitted {'no_epochs': 100, 'train_auc': 0.9591967, 'test_auc': 0.95199686, 'train_precision': 0.34031808, 'test_precision': 0.12146109, 'train_recall': 0.13894763956562906, 'test_recall': 0.12081629680099919, 'runtime': 1538}. Took 1538 seconds.
# Total time elapsed: 3191 seconds.
# ==========
# Completed

# %%
results_epoch_df = pd.DataFrame(results)

# %%
results_epoch_df['test_auc_rank'] = results_epoch_df['test_auc'].rank(ascending=False)
results_epoch_df['test_precision_rank'] = results_epoch_df['test_precision'].rank(ascending=False)
results_epoch_df['test_recall_rank'] = results_epoch_df['test_recall'].rank(ascending=False)

# %%
results_epoch_df.sort_values('test_recall_rank')
# Out:
#    no_epochs  train_auc  test_auc  train_precision  test_precision  \
# 3        100   0.959197  0.951997         0.340318        0.121461
# 2         60   0.958734  0.951968         0.339800        0.121643
# 0         10   0.954543  0.949252         0.282177        0.100918
# 1         20   0.956182  0.950522         0.285273        0.101677
#
#    train_recall  test_recall  runtime  test_auc_rank  test_precision_rank  \
# 3      0.138948     0.120816     1538            1.0                  2.0
# 2      0.137910     0.119501      980            2.0                  1.0
# 0      0.120092     0.101888      257            4.0                  4.0
# 1      0.119223     0.101130      416            3.0                  3.0
#
#    test_recall_rank
# 3               1.0
# 2               2.0
# 0               3.0
# 1               4.0

# %% [markdown]
# While the model scores improved with higher epochs, the runtime is substantially longer. Since the improvement in scores is not substantially better, we will go with 60 epochs.

# %%
model = LightFM(loss='warp', no_components = 50,
               learning_rate=.35,
               item_alpha=1e-6,
                random_state=np.random.RandomState(SEEDNO))

# %%
model.fit(interactions=train_interactions,item_features=item_features,user_features=user_features,epochs=60);

# %%
uid_map, ufeature_map, iid_map, ifeature_map = dataset.mapping()

# %% [markdown]
# ## Model Evaluation

# %%
train_roc_auc = auc_score(model,train_interactions,item_features=item_features,user_features=user_features).mean()
test_roc_auc = auc_score(model,test_interactions,item_features=item_features,user_features=user_features).mean()
train_precision_lfm = lightfm_prec_at_k(model, train_interactions,item_features=item_features,user_features=user_features, k=K).mean()
test_precision_lfm = lightfm_prec_at_k(model, test_interactions,item_features=item_features,user_features=user_features, k=K).mean()
train_recall_lfm = lightfm_recall_at_k(model, train_interactions,item_features=item_features,user_features=user_features, k=K).mean()
test_recall_lfm = lightfm_recall_at_k(model, test_interactions,item_features=item_features,user_features=user_features, k=K).mean()
print("=====AUC=====")
print(f'Train AUC: {train_roc_auc}')
print(f'Test AUC: {test_roc_auc}')
print("=====Precision@K=====")
print(f'Train Precision: {train_precision_lfm}')
print(f'Test Precision: {test_precision_lfm}')
print("=====Recall@K=====")
print(f'Train Recall: {train_recall_lfm}')
print(f'Test Recall: {test_recall_lfm}')
# Out:
# =====AUC=====
# Train AUC: 0.9587340354919434
# Test AUC: 0.9519678354263306
# =====Precision@K=====
# Train Precision: 0.33979979157447815
# Test Precision: 0.12164315581321716
# =====Recall@K=====
# Train Recall: 0.13790965131970803
# Test Recall: 0.11950063231451379

# %% [markdown]
# A test AUC of 0.952 means that there is a 95.2% probability that a randomly chosen relevant item has a higher score than a randomly chosen irrelevant item.
#
# A test precision@k of 0.122 at k = 10 means 12.2% of the recommended items in the top-10 set are relevant.
#
# A test recall@k of 0.120 at k = 10 means 12.0% of relevant items are found in to the top-10 recommendations.
#
# The model is performing fairly well as a recommender.

# %% [markdown]
# ### Model Predictions

# %% [markdown]
# #### Predict for new user

# %%
# predict for new user
user_feature_list = ['Comedy','Romance','Slice of Life']

# %%
new_user_features = format_newuser_input(ufeature_map, user_feature_list)

# %%
n_users, n_items = interactions.shape

# %%
model_pred = model.predict(0, np.arange(n_items), user_features=new_user_features) # Here 0 means pick the first row of the user_features sparse matrix

# %%
pred_dict = {'media_id':data['media_id'].unique(),'pred':model_pred}

# %%
pred_df = pd.DataFrame(pred_dict)

# %%
pred_df = pd.merge(pred_df,anime_db[['media_id','title_romaji','title_english','averageScore','genres']],on='media_id')

# %%
pred_df.sort_values('pred',ascending=False).head(10)
# Out:
#      media_id          pred  \
# 101     21087  20204.013672
# 221     20954  19922.732422
# 11      19815  17458.646484
# 3       11757  16540.271484
# 52      20665  15044.250000
# 199     21519  14915.349609
# 50      16498  12584.092773
# 18      20594  12056.784180
# 1       21459  11505.833008
# 14     101921  11477.990234
#
#                                           title_romaji  \
# 101                                      One Punch Man
# 221                                     Koe no Katachi
# 11                                     No Game No Life
# 3                                     Sword Art Online
# 52                             Shigatsu wa Kimi no Uso
# 199                                     Kimi no Na wa.
# 50                                  Shingeki no Kyojin
# 18                                 Sword Art Online II
# 1                                Boku no Hero Academia
# 14   Kaguya-sama wa Kokurasetai: Tensaitachi no Ren...
#
#                 title_english  averageScore  \
# 101             One-Punch Man          83.0
# 221            A Silent Voice          88.0
# 11           No Game, No Life          78.0
# 3            Sword Art Online          69.0
# 52          Your Lie in April          84.0
# 199                Your Name.          86.0
# 50            Attack on Titan          85.0
# 18        Sword Art Online II          65.0
# 1            My Hero Academia          78.0
# 14   Kaguya-sama: Love is War          83.0
#
#                                             genres
# 101           Action, Comedy, Sci-Fi, Supernatural
# 221                  Drama, Romance, Slice of Life
# 11               Adventure, Comedy, Ecchi, Fantasy
# 3              Action, Adventure, Fantasy, Romance
# 52            Drama, Music, Romance, Slice of Life
# 199                   Drama, Romance, Supernatural
# 50                 Action, Drama, Fantasy, Mystery
# 18              Action, Adventure, Fantasy, Sci-Fi
# 1                        Action, Adventure, Comedy
# 14   Comedy, Psychological, Romance, Slice of Life

# %% [markdown]
# #### Predict for existing user

# %%
# user id 710080 is my own account
user_x = uid_map[710080]
model_pred_existing = model.predict(user_x,np.arange(n_items))

# %%
pred_dict_existing = {'media_id':data['media_id'].unique(),'pred':model_pred_existing}

# %%
pred_df_existing = pd.DataFrame(pred_dict_existing)

# %%
pred_df_existing = pd.merge(pred_df_existing,anime_db[['media_id','title_romaji','title_english','averageScore']],on='media_id')

# %%
pred_df_existing.sort_values('pred',ascending=False).head(10)
# Out:
#       media_id      pred                                       title_romaji  \
# 1796     10155 -5.627423                                           Dog Days
# 1332     21361 -5.757196                     GRANBLUE FANTASY The Animation
# 1578     21319 -5.830634                        Ao no Kanata no Four Rhythm
# 2487     18195 -5.911045                           Little Busters!: Refrain
# 801      20991 -5.918883                                   Hidan no Aria AA
# 866      20774 -5.940100                Kuusen Madoushi Kouhosei no Kyoukan
# 541      20031 -6.064839                                            D-Frag!
# 2429     18893 -6.213651                  Aoki Hagane no Arpeggio: Ars Nova
# 2740     16444 -6.890656  Mondaiji-tachi ga Isekai kara Kuru Sou Desu yo...
# 66       12189 -7.045213                                             Hyouka
#
#                                           title_english  averageScore
# 1796                                           Dog Days          65.0
# 1332                    Granblue Fantasy: The Animation          64.0
# 1578                AOKANA: Four Rhythm Across the Blue          63.0
# 2487                            Little Busters! Refrain          80.0
# 801                            Aria the Scarlet Ammo AA          58.0
# 866                                 Sky Wizards Academy          58.0
# 541                                             D-Frag!          73.0
# 2429                             Arpeggio of Blue Steel          70.0
# 2740  Problem Children Are Coming From Another World...          69.0
# 66                                               Hyouka          79.0

# %% [markdown]
# #### Predict similar items

# %%
# Predicting for Yahari Ore no Seishun Love Come ga Machigatteiru.
# Comedy, Drama, Romance, Slice of Life
item_x = iid_map[14813]

# %%
similar_pred = similar_items(item_id=item_x, item_features=item_features, model=model,N=100)
similar_pred['media_id'] = similar_pred['itemID'].map(iid_map_reverse)

# %%
similar_pred = pd.merge(similar_pred,anime_db[['media_id','title_romaji','title_english','averageScore']],on='media_id')

# %%
similar_pred.sort_values('score',ascending=False).head(10)
# Out:
#    itemID     score  media_id  \
# 0      63  1.000000     14813
# 1     642  1.000000     20698
# 2     224  1.000000    103572
# 3      54  1.000000      4224
# 4     112  1.000000     13759
# 5     451  1.000000       853
# 6     515  0.999999     21049
# 7     455  0.999999     20596
# 8     727  0.999999     97766
# 9     483  0.999999     98291
#
#                                         title_romaji  \
# 0  Yahari Ore no Seishun Love Come wa Machigatteiru.
# 1  Yahari Ore no Seishun Love Come wa Machigattei...
# 2                               5-Toubun no Hanayome
# 3                                          Toradora!
# 4                         Sakurasou no Pet na Kanojo
# 5                             Ouran Koukou Host Club
# 6                                             ReLIFE
# 7                                       Ao Haru Ride
# 8                                            Gamers!
# 9                                 Tsurezure Children
#
#                         title_english  averageScore
# 0       My Teen Romantic Comedy SNAFU          78.0
# 1  My Teen Romantic Comedy SNAFU TOO!          81.0
# 2      The Quintessential Quintuplets          76.0
# 3                           Toradora!          79.0
# 4           The Pet Girl of Sakurasou          79.0
# 5         Ouran High School Host Club          81.0
# 6                              ReLIFE          78.0
# 7                    Blue Spring Ride          75.0
# 8                             GAMERS!          66.0
# 9                  Tsuredure Children          75.0

# %% [markdown]
# ## Conclusion & Recommendations

# %% [markdown]
# The LightFM model, when given user and item features, performs really well as compared to the baseline model (which did not have any user or item features).
#
# In recommending animes for new users, it seems the model is predicting popular animes which may or may not be relevant to the user input. E.g. "Romance" is part of the user input, but "Romance" only appears in 5 out of the 10 recommendations. Further to that, there are recommendations that do not even include one of the genres in the user input, e.g. Shingeki no Kyojin and Sword Art Online II does not have "Comedy", "Romance", nor "Slice of Life" genres. There is however, 1 recommendation that hits all user inputs, Kaguya-sama ga Kokurasetai. This means that 1 out of 10 recommendations are relevant, which coincides with the model's precision@k score of 12.2%.
#
# In recommending animes for existing users or similar animes, the model is performing as desired, as the top 10 recommendations contain animes that are not available in Netflix at this moment.
#
# Overall, the model is performing decently and the issue with recommending animes for new users might be attributed to a cold start problem, seeing how recommendations for existing users are working as desired. There may be merit in applying an additional filter to remove irrelevant recommendations based on user input, such as excluding animes that does not match any of the genres or does not match with all genres. On that note, it might be useful to allow the user to select if they want the recommendations to contain all or at least one of the genres they have selected.

# %% [markdown]
# ## Exports

# %% [markdown]
# Data items required for predictions:<br>
# - model
# - item_features
# - uid_map
# - iid_map
# - iid_map_reverse
# - ufeature_map
# - n_items
# - anime data
# - data['media_id'].unique()

# %%
# pickle model
pickle.dump(model, open('../model.pkl', 'wb'))

# %%
iid_map_reverse = dict((value,key) for key,value in iid_map.items())

# %%
n_users, n_items = interactions.shape

# %%
# Combining remaining required data items into 1 dictionary for pickle
data_items_for_predictions = {'item_features' : item_features,
                             'uid_map':uid_map,
                             'iid_map':iid_map,
                             'iid_map_reverse':iid_map_reverse,
                             'ufeature_map':ufeature_map,
                             'n_items':n_items,
                             'unique_media_id':data['media_id'].unique()}

# %%
pickle.dump(data_items_for_predictions, open('../data/data_items_for_predictions.pkl', 'wb'))

# %%
anime_db = pd.read_pickle("../data/anime_db_cleaned.pkl")

# %%
anime_db_export = anime_db[['id','description','genres','startDate','endDate','duration','averageScore',
                            'siteUrl','title_romaji','title_english','coverImage_large','coverImage_medium']]

# %%
anime_db_export['genres'] = anime_db_export['genres'].apply(lambda x: ", ".join(x))
# Out:
# <ipython-input-309-515537901631>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_db_export['genres'] = anime_db_export['genres'].apply(lambda x: ", ".join(x))

# %%
anime_db_export.rename(columns={'id':'media_id'},inplace=True)
# Out:
# C:\Users\Internet\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
anime_db_export.to_pickle("../data/anime_db_export.pkl")
