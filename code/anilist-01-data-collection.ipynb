# %% [markdown]
# # Anime Recommender System

# %%
import pandas as pd
import numpy as np
import requests
import time
from tqdm import tqdm

# %%
#%%time

query = '''
query($page: Int, $perPage: Int){
    Page(page: $page, perPage: $perPage) {
    pageInfo{
      total
      currentPage
      lastPage
      hasNextPage
      perPage
    }
    media(type:ANIME){
      id
      title {
        romaji
        english
      }
      status
      genres
      format
      description
      startDate {
        year
        month
        day
      }
      endDate {
        year
        month
        day
      }
      episodes
      description
      season
      seasonYear
      duration
      coverImage {
        large
        medium
      }
      averageScore
      meanScore
      popularity
      relations {
        edges {
            node {
                id
                type
            }
            relationType
        }
        nodes {
          id
          title {
            romaji
            english
          }
        }
      }
      siteUrl
    }
  }
}
'''

url = 'https://graphql.anilist.co'
api_output_anime = []
api_output_anime_18only = []
page = 1
atLastPage = False

while not atLastPage:
#for i in range(5):
    variables = {
        'page': page,
        'perPage': 50,
    }
    
    time.sleep(0.667)
    response = requests.post(url, json={'query': query, 'variables': variables})
    data = response.json()
    
    for anime in data['data']['Page']['media']:
        start_year = ""
        start_month = ""
        start_day = ""
        end_year = ""
        end_month = ""
        end_day = ""
        
        start_year = f"{anime['startDate']['year']}" if anime['startDate']['year'] is not None and anime['startDate']['year'] >= 1900 else ""
        start_month = f"{anime['startDate']['month']:02d}" if anime['startDate']['month'] is not None and anime['startDate']['month'] <= 12 else ""
        start_day = f"{anime['startDate']['day']:02d}" if anime['startDate']['day'] is not None and anime['startDate']['day'] <= 31 else ""
        end_year = f"{anime['endDate']['year']}" if anime['endDate']['year'] is not None and anime['endDate']['year'] >= 1900 else ""
        end_month = f"{anime['endDate']['month']:02d}" if anime['endDate']['month'] is not None and anime['endDate']['month'] <= 12  else ""
        end_day = f"{anime['endDate']['day']:02d}" if anime['endDate']['day'] is not None and anime['endDate']['day'] <= 31 else ""

        anime['startDate'] = f"{start_year}-{start_month}-{start_day}" if len(f"{start_year}-{start_month}-{start_day}") == 10 else None
        anime['endDate'] = f"{end_year}-{end_month}-{end_day}" if len(f"{end_year}-{end_month}-{end_day}") == 10 else None            
        
        anime['title_romaji'] = anime['title']['romaji']
        anime['title_english'] = anime['title']['english']
        anime['coverImage_large'] = anime['coverImage']['large']
        anime['coverImage_medium'] = anime['coverImage']['medium']
    
        relation_list = []
        #for relation in anime['relations']['nodes']:
        #    relation_list.append(str(relation['id']))
        for relation in anime['relations']['edges']:
            if relation['relationType'] != "CHARACTER" and relation['relationType'] != "OTHER" and relation['node']['type'] == "ANIME":
                relation_list.append(str(relation['node']['id']))
        
        anime['relations'] = ", ".join(relation_list)
        
        anime['genres'] = ", ".join(anime['genres'])
        anime.pop('coverImage')
        anime.pop('title')
        
        # separating 18+ titles into another dataframe to allow user to include 18+ titles if desired
        if "Hentai" in anime['genres']:
            api_output_anime_18only.append(anime)
        else:
            api_output_anime.append(anime)
        
    print(f"Page {page}, total collated: {len(api_output_anime)} anime titles (excludes 18+), {len(api_output_anime_18only)} anime titles (18+)")
    
    if data['data']['Page']['pageInfo']['hasNextPage'] == True:
        page += 1
    else:
        atLastPage = True
        
print("Completed")
# Out:
# Page 1, total collated: 50 anime titles (excludes 18+), 0 anime titles (18+)
# Page 2, total collated: 100 anime titles (excludes 18+), 0 anime titles (18+)
# Page 3, total collated: 150 anime titles (excludes 18+), 0 anime titles (18+)
# Page 4, total collated: 192 anime titles (excludes 18+), 8 anime titles (18+)
# Page 5, total collated: 242 anime titles (excludes 18+), 8 anime titles (18+)
# Page 6, total collated: 290 anime titles (excludes 18+), 10 anime titles (18+)
# Page 7, total collated: 339 anime titles (excludes 18+), 11 anime titles (18+)
# Page 8, total collated: 389 anime titles (excludes 18+), 11 anime titles (18+)
# Page 9, total collated: 439 anime titles (excludes 18+), 11 anime titles (18+)
# Page 10, total collated: 489 anime titles (excludes 18+), 11 anime titles (18+)
# Page 11, total collated: 539 anime titles (excludes 18+), 11 anime titles (18+)
# Page 12, total collated: 589 anime titles (excludes 18+), 11 anime titles (18+)
# Page 13, total collated: 637 anime titles (excludes 18+), 13 anime titles (18+)
# Page 14, total collated: 683 anime titles (excludes 18+), 17 anime titles (18+)
# Page 15, total collated: 729 anime titles (excludes 18+), 21 anime titles (18+)
# Page 16, total collated: 779 anime titles (excludes 18+), 21 anime titles (18+)
# Page 17, total collated: 829 anime titles (excludes 18+), 21 anime titles (18+)
# Page 18, total collated: 877 anime titles (excludes 18+), 23 anime titles (18+)
# Page 19, total collated: 926 anime titles (excludes 18+), 24 anime titles (18+)
# Page 20, total collated: 976 anime titles (excludes 18+), 24 anime titles (18+)
# Page 21, total collated: 1025 anime titles (excludes 18+), 25 anime titles (18+)
# Page 22, total collated: 1075 anime titles (excludes 18+), 25 anime titles (18+)
# Page 23, total collated: 1124 anime titles (excludes 18+), 26 anime titles (18+)
# Page 24, total collated: 1168 anime titles (excludes 18+), 32 anime titles (18+)
# Page 25, total collated: 1212 anime titles (excludes 18+), 38 anime titles (18+)
# Page 26, total collated: 1249 anime titles (excludes 18+), 51 anime titles (18+)
# Page 27, total collated: 1299 anime titles (excludes 18+), 51 anime titles (18+)
# Page 28, total collated: 1344 anime titles (excludes 18+), 56 anime titles (18+)
# Page 29, total collated: 1392 anime titles (excludes 18+), 58 anime titles (18+)
# Page 30, total collated: 1436 anime titles (excludes 18+), 64 anime titles (18+)
# Page 31, total collated: 1485 anime titles (excludes 18+), 65 anime titles (18+)
# Page 32, total collated: 1534 anime titles (excludes 18+), 66 anime titles (18+)
# Page 33, total collated: 1572 anime titles (excludes 18+), 78 anime titles (18+)
# Page 34, total collated: 1621 anime titles (excludes 18+), 79 anime titles (18+)
# Page 35, total collated: 1669 anime titles (excludes 18+), 81 anime titles (18+)
# Page 36, total collated: 1719 anime titles (excludes 18+), 81 anime titles (18+)
# Page 37, total collated: 1767 anime titles (excludes 18+), 83 anime titles (18+)
# Page 38, total collated: 1816 anime titles (excludes 18+), 84 anime titles (18+)
# Page 39, total collated: 1859 anime titles (excludes 18+), 91 anime titles (18+)
# Page 40, total collated: 1899 anime titles (excludes 18+), 101 anime titles (18+)
# Page 41, total collated: 1946 anime titles (excludes 18+), 104 anime titles (18+)
# Page 42, total collated: 1993 anime titles (excludes 18+), 107 anime titles (18+)
# Page 43, total collated: 2019 anime titles (excludes 18+), 131 anime titles (18+)
# Page 44, total collated: 2050 anime titles (excludes 18+), 150 anime titles (18+)
# Page 45, total collated: 2082 anime titles (excludes 18+), 168 anime titles (18+)
# Page 46, total collated: 2126 anime titles (excludes 18+), 174 anime titles (18+)
# Page 47, total collated: 2168 anime titles (excludes 18+), 182 anime titles (18+)
# Page 48, total collated: 2216 anime titles (excludes 18+), 184 anime titles (18+)
# Page 49, total collated: 2266 anime titles (excludes 18+), 184 anime titles (18+)
# Page 50, total collated: 2314 anime titles (excludes 18+), 186 anime titles (18+)
# Page 51, total collated: 2364 anime titles (excludes 18+), 186 anime titles (18+)
# Page 52, total collated: 2410 anime titles (excludes 18+), 190 anime titles (18+)
# Page 53, total collated: 2438 anime titles (excludes 18+), 212 anime titles (18+)
# Page 54, total collated: 2475 anime titles (excludes 18+), 225 anime titles (18+)
# Page 55, total collated: 2518 anime titles (excludes 18+), 232 anime titles (18+)
# Page 56, total collated: 2555 anime titles (excludes 18+), 245 anime titles (18+)
# Page 57, total collated: 2595 anime titles (excludes 18+), 255 anime titles (18+)
# Page 58, total collated: 2641 anime titles (excludes 18+), 259 anime titles (18+)
# Page 59, total collated: 2682 anime titles (excludes 18+), 268 anime titles (18+)
# Page 60, total collated: 2716 anime titles (excludes 18+), 284 anime titles (18+)
# Page 61, total collated: 2758 anime titles (excludes 18+), 292 anime titles (18+)
# Page 62, total collated: 2793 anime titles (excludes 18+), 307 anime titles (18+)
# Page 63, total collated: 2820 anime titles (excludes 18+), 330 anime titles (18+)
# Page 64, total collated: 2859 anime titles (excludes 18+), 341 anime titles (18+)
# Page 65, total collated: 2899 anime titles (excludes 18+), 351 anime titles (18+)
# Page 66, total collated: 2942 anime titles (excludes 18+), 358 anime titles (18+)
# Page 67, total collated: 2986 anime titles (excludes 18+), 364 anime titles (18+)
# Page 68, total collated: 3015 anime titles (excludes 18+), 385 anime titles (18+)
# Page 69, total collated: 3047 anime titles (excludes 18+), 403 anime titles (18+)
# Page 70, total collated: 3095 anime titles (excludes 18+), 405 anime titles (18+)
# Page 71, total collated: 3141 anime titles (excludes 18+), 409 anime titles (18+)
# Page 72, total collated: 3173 anime titles (excludes 18+), 427 anime titles (18+)
# Page 73, total collated: 3218 anime titles (excludes 18+), 432 anime titles (18+)
# Page 74, total collated: 3249 anime titles (excludes 18+), 451 anime titles (18+)
# Page 75, total collated: 3282 anime titles (excludes 18+), 468 anime titles (18+)
# Page 76, total collated: 3316 anime titles (excludes 18+), 484 anime titles (18+)
# Page 77, total collated: 3343 anime titles (excludes 18+), 507 anime titles (18+)
# Page 78, total collated: 3392 anime titles (excludes 18+), 508 anime titles (18+)
# Page 79, total collated: 3437 anime titles (excludes 18+), 513 anime titles (18+)
# Page 80, total collated: 3476 anime titles (excludes 18+), 524 anime titles (18+)
# Page 81, total collated: 3516 anime titles (excludes 18+), 534 anime titles (18+)
# Page 82, total collated: 3556 anime titles (excludes 18+), 544 anime titles (18+)
# Page 83, total collated: 3593 anime titles (excludes 18+), 557 anime titles (18+)
# Page 84, total collated: 3606 anime titles (excludes 18+), 594 anime titles (18+)
# Page 85, total collated: 3631 anime titles (excludes 18+), 619 anime titles (18+)
# Page 86, total collated: 3675 anime titles (excludes 18+), 625 anime titles (18+)
# Page 87, total collated: 3724 anime titles (excludes 18+), 626 anime titles (18+)
# Page 88, total collated: 3771 anime titles (excludes 18+), 629 anime titles (18+)
# Page 89, total collated: 3816 anime titles (excludes 18+), 634 anime titles (18+)
# Page 90, total collated: 3863 anime titles (excludes 18+), 637 anime titles (18+)
# Page 91, total collated: 3909 anime titles (excludes 18+), 641 anime titles (18+)
# Page 92, total collated: 3956 anime titles (excludes 18+), 644 anime titles (18+)
# Page 93, total collated: 4002 anime titles (excludes 18+), 648 anime titles (18+)
# Page 94, total collated: 4044 anime titles (excludes 18+), 656 anime titles (18+)
# Page 95, total collated: 4094 anime titles (excludes 18+), 656 anime titles (18+)
# Page 96, total collated: 4140 anime titles (excludes 18+), 660 anime titles (18+)
# Page 97, total collated: 4189 anime titles (excludes 18+), 661 anime titles (18+)
# Page 98, total collated: 4234 anime titles (excludes 18+), 666 anime titles (18+)
# Page 99, total collated: 4276 anime titles (excludes 18+), 674 anime titles (18+)
# Page 100, total collated: 4321 anime titles (excludes 18+), 679 anime titles (18+)
# Page 101, total collated: 4367 anime titles (excludes 18+), 683 anime titles (18+)
# Page 102, total collated: 4413 anime titles (excludes 18+), 687 anime titles (18+)
# Page 103, total collated: 4460 anime titles (excludes 18+), 690 anime titles (18+)
# Page 104, total collated: 4506 anime titles (excludes 18+), 694 anime titles (18+)
# Page 105, total collated: 4554 anime titles (excludes 18+), 696 anime titles (18+)
# Page 106, total collated: 4597 anime titles (excludes 18+), 703 anime titles (18+)
# Page 107, total collated: 4647 anime titles (excludes 18+), 703 anime titles (18+)
# Page 108, total collated: 4695 anime titles (excludes 18+), 705 anime titles (18+)
# Page 109, total collated: 4740 anime titles (excludes 18+), 710 anime titles (18+)
# Page 110, total collated: 4790 anime titles (excludes 18+), 710 anime titles (18+)
# Page 111, total collated: 4838 anime titles (excludes 18+), 712 anime titles (18+)
# Page 112, total collated: 4884 anime titles (excludes 18+), 716 anime titles (18+)
# Page 113, total collated: 4931 anime titles (excludes 18+), 719 anime titles (18+)
# Page 114, total collated: 4964 anime titles (excludes 18+), 736 anime titles (18+)
# Page 115, total collated: 5007 anime titles (excludes 18+), 743 anime titles (18+)
# Page 116, total collated: 5053 anime titles (excludes 18+), 747 anime titles (18+)
# Page 117, total collated: 5098 anime titles (excludes 18+), 752 anime titles (18+)
# Page 118, total collated: 5144 anime titles (excludes 18+), 756 anime titles (18+)
# Page 119, total collated: 5191 anime titles (excludes 18+), 759 anime titles (18+)
# Page 120, total collated: 5239 anime titles (excludes 18+), 761 anime titles (18+)
# Page 121, total collated: 5286 anime titles (excludes 18+), 764 anime titles (18+)
# Page 122, total collated: 5335 anime titles (excludes 18+), 765 anime titles (18+)
# Page 123, total collated: 5379 anime titles (excludes 18+), 771 anime titles (18+)
# Page 124, total collated: 5417 anime titles (excludes 18+), 783 anime titles (18+)
# Page 125, total collated: 5461 anime titles (excludes 18+), 789 anime titles (18+)
# Page 126, total collated: 5506 anime titles (excludes 18+), 794 anime titles (18+)
# Page 127, total collated: 5551 anime titles (excludes 18+), 799 anime titles (18+)
# Page 128, total collated: 5598 anime titles (excludes 18+), 802 anime titles (18+)
# Page 129, total collated: 5644 anime titles (excludes 18+), 806 anime titles (18+)
# Page 130, total collated: 5688 anime titles (excludes 18+), 812 anime titles (18+)
# Page 131, total collated: 5737 anime titles (excludes 18+), 813 anime titles (18+)
# Page 132, total collated: 5779 anime titles (excludes 18+), 821 anime titles (18+)
# Page 133, total collated: 5822 anime titles (excludes 18+), 828 anime titles (18+)
# Page 134, total collated: 5869 anime titles (excludes 18+), 831 anime titles (18+)
# Page 135, total collated: 5916 anime titles (excludes 18+), 834 anime titles (18+)
# Page 136, total collated: 5966 anime titles (excludes 18+), 834 anime titles (18+)
# Page 137, total collated: 6007 anime titles (excludes 18+), 843 anime titles (18+)
# Page 138, total collated: 6053 anime titles (excludes 18+), 847 anime titles (18+)
# Page 139, total collated: 6101 anime titles (excludes 18+), 849 anime titles (18+)
# Page 140, total collated: 6147 anime titles (excludes 18+), 853 anime titles (18+)
# Page 141, total collated: 6193 anime titles (excludes 18+), 857 anime titles (18+)
# Page 142, total collated: 6237 anime titles (excludes 18+), 863 anime titles (18+)
# Page 143, total collated: 6281 anime titles (excludes 18+), 869 anime titles (18+)
# Page 144, total collated: 6327 anime titles (excludes 18+), 873 anime titles (18+)
# Page 145, total collated: 6373 anime titles (excludes 18+), 877 anime titles (18+)
# Page 146, total collated: 6418 anime titles (excludes 18+), 882 anime titles (18+)
# Page 147, total collated: 6464 anime titles (excludes 18+), 886 anime titles (18+)
# Page 148, total collated: 6511 anime titles (excludes 18+), 889 anime titles (18+)
# Page 149, total collated: 6558 anime titles (excludes 18+), 892 anime titles (18+)
# Page 150, total collated: 6608 anime titles (excludes 18+), 892 anime titles (18+)
# Page 151, total collated: 6656 anime titles (excludes 18+), 894 anime titles (18+)
# Page 152, total collated: 6704 anime titles (excludes 18+), 896 anime titles (18+)
# Page 153, total collated: 6749 anime titles (excludes 18+), 901 anime titles (18+)
# Page 154, total collated: 6797 anime titles (excludes 18+), 903 anime titles (18+)
# Page 155, total collated: 6843 anime titles (excludes 18+), 907 anime titles (18+)
# Page 156, total collated: 6890 anime titles (excludes 18+), 910 anime titles (18+)
# Page 157, total collated: 6935 anime titles (excludes 18+), 915 anime titles (18+)
# Page 158, total collated: 6979 anime titles (excludes 18+), 921 anime titles (18+)
# Page 159, total collated: 7025 anime titles (excludes 18+), 925 anime titles (18+)
# Page 160, total collated: 7074 anime titles (excludes 18+), 926 anime titles (18+)
# Page 161, total collated: 7122 anime titles (excludes 18+), 928 anime titles (18+)
# Page 162, total collated: 7165 anime titles (excludes 18+), 935 anime titles (18+)
# Page 163, total collated: 7214 anime titles (excludes 18+), 936 anime titles (18+)
# Page 164, total collated: 7263 anime titles (excludes 18+), 937 anime titles (18+)
# Page 165, total collated: 7310 anime titles (excludes 18+), 940 anime titles (18+)
# Page 166, total collated: 7360 anime titles (excludes 18+), 940 anime titles (18+)
# Page 167, total collated: 7410 anime titles (excludes 18+), 940 anime titles (18+)
# Page 168, total collated: 7460 anime titles (excludes 18+), 940 anime titles (18+)
# Page 169, total collated: 7510 anime titles (excludes 18+), 940 anime titles (18+)
# Page 170, total collated: 7560 anime titles (excludes 18+), 940 anime titles (18+)
# Page 171, total collated: 7609 anime titles (excludes 18+), 941 anime titles (18+)
# Page 172, total collated: 7659 anime titles (excludes 18+), 941 anime titles (18+)
# Page 173, total collated: 7706 anime titles (excludes 18+), 944 anime titles (18+)
# Page 174, total collated: 7754 anime titles (excludes 18+), 946 anime titles (18+)
# Page 175, total collated: 7804 anime titles (excludes 18+), 946 anime titles (18+)
# Page 176, total collated: 7850 anime titles (excludes 18+), 950 anime titles (18+)
# Page 177, total collated: 7887 anime titles (excludes 18+), 963 anime titles (18+)
# Page 178, total collated: 7916 anime titles (excludes 18+), 984 anime titles (18+)
# Page 179, total collated: 7948 anime titles (excludes 18+), 1002 anime titles (18+)
# Page 180, total collated: 7990 anime titles (excludes 18+), 1010 anime titles (18+)
# Page 181, total collated: 8037 anime titles (excludes 18+), 1013 anime titles (18+)
# Page 182, total collated: 8085 anime titles (excludes 18+), 1015 anime titles (18+)
# Page 183, total collated: 8126 anime titles (excludes 18+), 1024 anime titles (18+)
# Page 184, total collated: 8173 anime titles (excludes 18+), 1027 anime titles (18+)
# Page 185, total collated: 8214 anime titles (excludes 18+), 1036 anime titles (18+)
# Page 186, total collated: 8236 anime titles (excludes 18+), 1064 anime titles (18+)
# Page 187, total collated: 8275 anime titles (excludes 18+), 1075 anime titles (18+)
# Page 188, total collated: 8311 anime titles (excludes 18+), 1089 anime titles (18+)
# Page 189, total collated: 8359 anime titles (excludes 18+), 1091 anime titles (18+)
# Page 190, total collated: 8405 anime titles (excludes 18+), 1095 anime titles (18+)
# Page 191, total collated: 8451 anime titles (excludes 18+), 1099 anime titles (18+)
# Page 192, total collated: 8496 anime titles (excludes 18+), 1104 anime titles (18+)
# Page 193, total collated: 8541 anime titles (excludes 18+), 1109 anime titles (18+)
# Page 194, total collated: 8587 anime titles (excludes 18+), 1113 anime titles (18+)
# Page 195, total collated: 8629 anime titles (excludes 18+), 1121 anime titles (18+)
# Page 196, total collated: 8672 anime titles (excludes 18+), 1128 anime titles (18+)
# Page 197, total collated: 8716 anime titles (excludes 18+), 1134 anime titles (18+)
# Page 198, total collated: 8759 anime titles (excludes 18+), 1141 anime titles (18+)
# Page 199, total collated: 8804 anime titles (excludes 18+), 1146 anime titles (18+)
# Page 200, total collated: 8851 anime titles (excludes 18+), 1149 anime titles (18+)
# Page 201, total collated: 8899 anime titles (excludes 18+), 1151 anime titles (18+)
# Page 202, total collated: 8944 anime titles (excludes 18+), 1156 anime titles (18+)
# Page 203, total collated: 8989 anime titles (excludes 18+), 1161 anime titles (18+)
# Page 204, total collated: 9033 anime titles (excludes 18+), 1167 anime titles (18+)
# Page 205, total collated: 9081 anime titles (excludes 18+), 1169 anime titles (18+)
# Page 206, total collated: 9121 anime titles (excludes 18+), 1179 anime titles (18+)
# Page 207, total collated: 9168 anime titles (excludes 18+), 1182 anime titles (18+)
# Page 208, total collated: 9212 anime titles (excludes 18+), 1188 anime titles (18+)
# Page 209, total collated: 9256 anime titles (excludes 18+), 1194 anime titles (18+)
# Page 210, total collated: 9300 anime titles (excludes 18+), 1200 anime titles (18+)
# Page 211, total collated: 9347 anime titles (excludes 18+), 1203 anime titles (18+)
# Page 212, total collated: 9394 anime titles (excludes 18+), 1206 anime titles (18+)
# Page 213, total collated: 9443 anime titles (excludes 18+), 1207 anime titles (18+)
# Page 214, total collated: 9489 anime titles (excludes 18+), 1211 anime titles (18+)
# Page 215, total collated: 9536 anime titles (excludes 18+), 1214 anime titles (18+)
# Page 216, total collated: 9586 anime titles (excludes 18+), 1214 anime titles (18+)
# Page 217, total collated: 9635 anime titles (excludes 18+), 1215 anime titles (18+)
# Page 218, total collated: 9685 anime titles (excludes 18+), 1215 anime titles (18+)
# Page 219, total collated: 9735 anime titles (excludes 18+), 1215 anime titles (18+)
# Page 220, total collated: 9785 anime titles (excludes 18+), 1215 anime titles (18+)
# Page 221, total collated: 9835 anime titles (excludes 18+), 1215 anime titles (18+)
# Page 222, total collated: 9885 anime titles (excludes 18+), 1215 anime titles (18+)
# Page 223, total collated: 9935 anime titles (excludes 18+), 1215 anime titles (18+)
# Page 224, total collated: 9985 anime titles (excludes 18+), 1215 anime titles (18+)
# Page 225, total collated: 10035 anime titles (excludes 18+), 1215 anime titles (18+)
# Page 226, total collated: 10080 anime titles (excludes 18+), 1220 anime titles (18+)
# Page 227, total collated: 10129 anime titles (excludes 18+), 1221 anime titles (18+)
# Page 228, total collated: 10178 anime titles (excludes 18+), 1222 anime titles (18+)
# Page 229, total collated: 10228 anime titles (excludes 18+), 1222 anime titles (18+)
# Page 230, total collated: 10278 anime titles (excludes 18+), 1222 anime titles (18+)
# Page 231, total collated: 10328 anime titles (excludes 18+), 1222 anime titles (18+)
# Page 232, total collated: 10376 anime titles (excludes 18+), 1224 anime titles (18+)
# Page 233, total collated: 10426 anime titles (excludes 18+), 1224 anime titles (18+)
# Page 234, total collated: 10475 anime titles (excludes 18+), 1225 anime titles (18+)
# Page 235, total collated: 10525 anime titles (excludes 18+), 1225 anime titles (18+)
# Page 236, total collated: 10570 anime titles (excludes 18+), 1230 anime titles (18+)
# Page 237, total collated: 10618 anime titles (excludes 18+), 1232 anime titles (18+)
# Page 238, total collated: 10668 anime titles (excludes 18+), 1232 anime titles (18+)
# Page 239, total collated: 10716 anime titles (excludes 18+), 1234 anime titles (18+)
# Page 240, total collated: 10765 anime titles (excludes 18+), 1235 anime titles (18+)
# Page 241, total collated: 10815 anime titles (excludes 18+), 1235 anime titles (18+)
# Page 242, total collated: 10855 anime titles (excludes 18+), 1245 anime titles (18+)
# Page 243, total collated: 10902 anime titles (excludes 18+), 1248 anime titles (18+)
# Page 244, total collated: 10946 anime titles (excludes 18+), 1254 anime titles (18+)
# Page 245, total collated: 10995 anime titles (excludes 18+), 1255 anime titles (18+)
# Page 246, total collated: 11038 anime titles (excludes 18+), 1262 anime titles (18+)
# Page 247, total collated: 11088 anime titles (excludes 18+), 1262 anime titles (18+)
# Page 248, total collated: 11136 anime titles (excludes 18+), 1264 anime titles (18+)
# Page 249, total collated: 11184 anime titles (excludes 18+), 1266 anime titles (18+)
# Page 250, total collated: 11226 anime titles (excludes 18+), 1274 anime titles (18+)
# Page 251, total collated: 11275 anime titles (excludes 18+), 1275 anime titles (18+)
# Page 252, total collated: 11324 anime titles (excludes 18+), 1276 anime titles (18+)
# Page 253, total collated: 11373 anime titles (excludes 18+), 1277 anime titles (18+)
# Page 254, total collated: 11417 anime titles (excludes 18+), 1283 anime titles (18+)
# Page 255, total collated: 11466 anime titles (excludes 18+), 1284 anime titles (18+)
# Page 256, total collated: 11516 anime titles (excludes 18+), 1284 anime titles (18+)
# Page 257, total collated: 11563 anime titles (excludes 18+), 1287 anime titles (18+)
# Page 258, total collated: 11611 anime titles (excludes 18+), 1289 anime titles (18+)
# Page 259, total collated: 11657 anime titles (excludes 18+), 1293 anime titles (18+)
# Page 260, total collated: 11706 anime titles (excludes 18+), 1294 anime titles (18+)
# Page 261, total collated: 11756 anime titles (excludes 18+), 1294 anime titles (18+)
# Page 262, total collated: 11801 anime titles (excludes 18+), 1299 anime titles (18+)
# Page 263, total collated: 11848 anime titles (excludes 18+), 1302 anime titles (18+)
# Page 264, total collated: 11897 anime titles (excludes 18+), 1303 anime titles (18+)
# Page 265, total collated: 11944 anime titles (excludes 18+), 1306 anime titles (18+)
# Page 266, total collated: 11993 anime titles (excludes 18+), 1307 anime titles (18+)
# Page 267, total collated: 12041 anime titles (excludes 18+), 1309 anime titles (18+)
# Page 268, total collated: 12091 anime titles (excludes 18+), 1309 anime titles (18+)
# Page 269, total collated: 12141 anime titles (excludes 18+), 1309 anime titles (18+)
# Page 270, total collated: 12186 anime titles (excludes 18+), 1314 anime titles (18+)
# Page 271, total collated: 12233 anime titles (excludes 18+), 1317 anime titles (18+)
# Page 272, total collated: 12281 anime titles (excludes 18+), 1319 anime titles (18+)
# Page 273, total collated: 12330 anime titles (excludes 18+), 1320 anime titles (18+)
# Page 274, total collated: 12378 anime titles (excludes 18+), 1322 anime titles (18+)
# Page 275, total collated: 12425 anime titles (excludes 18+), 1325 anime titles (18+)
# Page 276, total collated: 12474 anime titles (excludes 18+), 1326 anime titles (18+)
# Page 277, total collated: 12524 anime titles (excludes 18+), 1326 anime titles (18+)
# Page 278, total collated: 12571 anime titles (excludes 18+), 1329 anime titles (18+)
# Page 279, total collated: 12620 anime titles (excludes 18+), 1330 anime titles (18+)
# Page 280, total collated: 12668 anime titles (excludes 18+), 1332 anime titles (18+)
# Page 281, total collated: 12714 anime titles (excludes 18+), 1336 anime titles (18+)
# Page 282, total collated: 12761 anime titles (excludes 18+), 1339 anime titles (18+)
# Page 283, total collated: 12810 anime titles (excludes 18+), 1340 anime titles (18+)
# Page 284, total collated: 12859 anime titles (excludes 18+), 1341 anime titles (18+)
# Page 285, total collated: 12908 anime titles (excludes 18+), 1342 anime titles (18+)
# Page 286, total collated: 12958 anime titles (excludes 18+), 1342 anime titles (18+)
# Page 287, total collated: 13008 anime titles (excludes 18+), 1342 anime titles (18+)
# Page 288, total collated: 13058 anime titles (excludes 18+), 1342 anime titles (18+)
# Page 289, total collated: 13105 anime titles (excludes 18+), 1345 anime titles (18+)
# Page 290, total collated: 13155 anime titles (excludes 18+), 1345 anime titles (18+)
# Page 291, total collated: 13202 anime titles (excludes 18+), 1348 anime titles (18+)
# Page 292, total collated: 13252 anime titles (excludes 18+), 1348 anime titles (18+)
# Page 293, total collated: 13298 anime titles (excludes 18+), 1352 anime titles (18+)
# Page 294, total collated: 13347 anime titles (excludes 18+), 1353 anime titles (18+)
# Page 295, total collated: 13395 anime titles (excludes 18+), 1355 anime titles (18+)
# Page 296, total collated: 13440 anime titles (excludes 18+), 1360 anime titles (18+)
# Page 297, total collated: 13487 anime titles (excludes 18+), 1363 anime titles (18+)
# Page 298, total collated: 13536 anime titles (excludes 18+), 1364 anime titles (18+)
# Page 299, total collated: 13584 anime titles (excludes 18+), 1366 anime titles (18+)
# Page 300, total collated: 13633 anime titles (excludes 18+), 1367 anime titles (18+)
# Page 301, total collated: 13682 anime titles (excludes 18+), 1368 anime titles (18+)
# Page 302, total collated: 13732 anime titles (excludes 18+), 1368 anime titles (18+)
# Page 303, total collated: 13781 anime titles (excludes 18+), 1369 anime titles (18+)
# Page 304, total collated: 13828 anime titles (excludes 18+), 1372 anime titles (18+)
# Page 305, total collated: 13877 anime titles (excludes 18+), 1373 anime titles (18+)
# Page 306, total collated: 13927 anime titles (excludes 18+), 1373 anime titles (18+)
# Page 307, total collated: 13977 anime titles (excludes 18+), 1373 anime titles (18+)
# Page 308, total collated: 14027 anime titles (excludes 18+), 1373 anime titles (18+)
# Page 309, total collated: 14071 anime titles (excludes 18+), 1379 anime titles (18+)
# Page 310, total collated: 14121 anime titles (excludes 18+), 1379 anime titles (18+)
# Page 311, total collated: 14166 anime titles (excludes 18+), 1384 anime titles (18+)
# Page 312, total collated: 14216 anime titles (excludes 18+), 1384 anime titles (18+)
# Page 313, total collated: 14266 anime titles (excludes 18+), 1384 anime titles (18+)
# Page 314, total collated: 14315 anime titles (excludes 18+), 1385 anime titles (18+)
# Page 315, total collated: 14363 anime titles (excludes 18+), 1387 anime titles (18+)
# Page 316, total collated: 14413 anime titles (excludes 18+), 1387 anime titles (18+)
# Page 317, total collated: 14463 anime titles (excludes 18+), 1387 anime titles (18+)
# Page 318, total collated: 14511 anime titles (excludes 18+), 1389 anime titles (18+)
# Page 319, total collated: 14557 anime titles (excludes 18+), 1393 anime titles (18+)
# Page 320, total collated: 14605 anime titles (excludes 18+), 1395 anime titles (18+)
# Page 321, total collated: 14652 anime titles (excludes 18+), 1398 anime titles (18+)
# Page 322, total collated: 14701 anime titles (excludes 18+), 1399 anime titles (18+)
# Page 323, total collated: 14750 anime titles (excludes 18+), 1400 anime titles (18+)
# Page 324, total collated: 14800 anime titles (excludes 18+), 1400 anime titles (18+)
# Page 325, total collated: 14847 anime titles (excludes 18+), 1403 anime titles (18+)
# Page 326, total collated: 14894 anime titles (excludes 18+), 1406 anime titles (18+)
# Page 327, total collated: 14943 anime titles (excludes 18+), 1407 anime titles (18+)
# Page 328, total collated: 14993 anime titles (excludes 18+), 1407 anime titles (18+)
# Page 329, total collated: 15043 anime titles (excludes 18+), 1407 anime titles (18+)
# Page 330, total collated: 15091 anime titles (excludes 18+), 1409 anime titles (18+)
# Page 331, total collated: 15139 anime titles (excludes 18+), 1411 anime titles (18+)
# Page 332, total collated: 15189 anime titles (excludes 18+), 1411 anime titles (18+)
# Page 333, total collated: 15237 anime titles (excludes 18+), 1413 anime titles (18+)
# Page 334, total collated: 15285 anime titles (excludes 18+), 1415 anime titles (18+)
# Page 335, total collated: 15335 anime titles (excludes 18+), 1415 anime titles (18+)
# Page 336, total collated: 15383 anime titles (excludes 18+), 1417 anime titles (18+)
# Page 337, total collated: 15432 anime titles (excludes 18+), 1418 anime titles (18+)
# Page 338, total collated: 15482 anime titles (excludes 18+), 1418 anime titles (18+)
# Page 339, total collated: 15528 anime titles (excludes 18+), 1422 anime titles (18+)
# Page 340, total collated: 15577 anime titles (excludes 18+), 1423 anime titles (18+)
# Page 341, total collated: 15624 anime titles (excludes 18+), 1426 anime titles (18+)
# Page 342, total collated: 15674 anime titles (excludes 18+), 1426 anime titles (18+)
# Page 343, total collated: 15722 anime titles (excludes 18+), 1428 anime titles (18+)
# Page 344, total collated: 15769 anime titles (excludes 18+), 1431 anime titles (18+)
# Page 345, total collated: 15819 anime titles (excludes 18+), 1431 anime titles (18+)
# Page 346, total collated: 15869 anime titles (excludes 18+), 1431 anime titles (18+)
# Page 347, total collated: 15919 anime titles (excludes 18+), 1431 anime titles (18+)
# Page 348, total collated: 15954 anime titles (excludes 18+), 1432 anime titles (18+)
# Completed

# %%
anime_db = pd.DataFrame(api_output_anime)
print(anime_db.shape)
anime_db.head()
# Out:
# (15954, 20)
#    id    status                                    genres format  \
# 0   1  FINISHED          Action, Adventure, Drama, Sci-Fi     TV
# 1   5  FINISHED            Action, Drama, Mystery, Sci-Fi  MOVIE
# 2   6  FINISHED  Action, Adventure, Comedy, Drama, Sci-Fi     TV
# 3   7  FINISHED      Action, Drama, Mystery, Supernatural     TV
# 4   8  FINISHED          Adventure, Fantasy, Supernatural     TV
#
#                                          description   startDate     endDate  \
# 0  Enter a world in the distant future, where Bou...  1998-04-03  1999-04-24
# 1  As the Cowboy Bebop crew travels the stars, th...  2001-09-01  2001-09-01
# 2  Vash the Stampede is a wanted man with a habit...  1998-04-01  1998-09-30
# 3  Robin Sena is a powerful craft user drafted in...  2002-07-02  2002-12-24
# 4  It is the dark century and the people are suff...  2004-09-30  2005-09-29
#
#    episodes  season  seasonYear  duration  averageScore  meanScore  \
# 0      26.0  SPRING      1998.0      24.0          86.0       86.0
# 1       1.0  SUMMER      2001.0     115.0          82.0       82.0
# 2      26.0  SPRING      1998.0      24.0          79.0       79.0
# 3      26.0  SUMMER      2002.0      25.0          68.0       68.0
# 4      52.0    FALL      2004.0      23.0          62.0       64.0
#
#    popularity       relations                     siteUrl  \
# 0      249940  5, 17205, 4037  https://anilist.co/anime/1
# 1       47081               1  https://anilist.co/anime/5
# 2       81725            4106  https://anilist.co/anime/6
# 3       11850                  https://anilist.co/anime/7
# 4        1683            1123  https://anilist.co/anime/8
#
#                       title_romaji  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           TRIGUN
# 3               Witch Hunter ROBIN
# 4                   Bouken Ou Beet
#
#                                        title_english  \
# 0                                       Cowboy Bebop
# 1  Cowboy Bebop: The Movie - Knockin' on Heaven's...
# 2                                             Trigun
# 3                                 Witch Hunter ROBIN
# 4                             Beet the Vandel Buster
#
#                                     coverImage_large  \
# 0  https://s4.anilist.co/file/anilistcdn/media/an...
# 1  https://s4.anilist.co/file/anilistcdn/media/an...
# 2  https://s4.anilist.co/file/anilistcdn/media/an...
# 3  https://s4.anilist.co/file/anilistcdn/media/an...
# 4  https://s4.anilist.co/file/anilistcdn/media/an...
#
#                                    coverImage_medium
# 0  https://s4.anilist.co/file/anilistcdn/media/an...
# 1  https://s4.anilist.co/file/anilistcdn/media/an...
# 2  https://s4.anilist.co/file/anilistcdn/media/an...
# 3  https://s4.anilist.co/file/anilistcdn/media/an...
# 4  https://s4.anilist.co/file/anilistcdn/media/an...

# %%
anime_db_18 = pd.DataFrame(api_output_anime_18only)
print(anime_db_18.shape)
anime_db_18.head()
# Out:
# (1432, 20)
#     id    status                                 genres format  \
# 0  188  FINISHED  Comedy, Hentai, Mystery, Supernatural    OVA
# 1  203  FINISHED             Adventure, Fantasy, Hentai    OVA
# 2  211  FINISHED                                 Hentai    OVA
# 3  213  FINISHED                Comedy, Hentai, Romance    OVA
# 4  214  FINISHED         Comedy, Drama, Hentai, Romance    OVA
#
#                                          description   startDate     endDate  \
# 0  Masquerade is the story surrounding the Hiraga...  1998-09-25  1999-03-25
# 1  Based on the erotic game by Elf.<br>\n<br>\nTh...  1999-08-25  2000-11-25
# 2  Episode 1:<br>\n"There is no need for relation...  2001-09-25  2001-12-21
# 3  Yusuke Kinoshita is forced by his father to wo...  1997-10-24  1998-04-24
# 4  Yususke (from the first Pia Carrot series) ret...  1998-10-23  1999-04-23
#
#    episodes  season  seasonYear  duration  averageScore  meanScore  \
# 0       4.0    FALL      1998.0      30.0          51.0       54.0
# 1       5.0  SUMMER      1999.0      30.0          57.0       59.0
# 2       2.0    FALL      2001.0      30.0          52.0       55.0
# 3       3.0    FALL      1997.0      29.0          48.0       51.0
# 4       3.0    FALL      1998.0      30.0          47.0       50.0
#
#    popularity     relations                       siteUrl  \
# 0         448          4561  https://anilist.co/anime/188
# 1         954  2185, 125574  https://anilist.co/anime/203
# 2         483                https://anilist.co/anime/211
# 3         451      214, 215  https://anilist.co/anime/213
# 4         324      213, 215  https://anilist.co/anime/214
#
#                title_romaji            title_english  \
# 0             Gosenzo San'e               Masquerade
# 1               Words Worth                     None
# 2                 Pure Mail                     None
# 3    Pia Carrot e Youkoso!!    Welcome to Pia Carrot
# 4  Pia Carrot e Youkoso!! 2  Welcome To Pia Carrot 2
#
#                                     coverImage_large  \
# 0  https://s4.anilist.co/file/anilistcdn/media/an...
# 1  https://s4.anilist.co/file/anilistcdn/media/an...
# 2  https://s4.anilist.co/file/anilistcdn/media/an...
# 3  https://s4.anilist.co/file/anilistcdn/media/an...
# 4  https://s4.anilist.co/file/anilistcdn/media/an...
#
#                                    coverImage_medium
# 0  https://s4.anilist.co/file/anilistcdn/media/an...
# 1  https://s4.anilist.co/file/anilistcdn/media/an...
# 2  https://s4.anilist.co/file/anilistcdn/media/an...
# 3  https://s4.anilist.co/file/anilistcdn/media/an...
# 4  https://s4.anilist.co/file/anilistcdn/media/an...

# %%
anime_db.to_csv("../data/anime_db.csv",index=False,encoding="utf-8")
anime_db_18.to_csv("../data/anime_db_18.csv",index=False,encoding="utf-8")

# %%
# %%time

query = '''
query ($page: Int, $perPage: Int) {
    Page (page: $page, perPage: $perPage) {
        pageInfo {
            total
            currentPage
            lastPage
            hasNextPage
            perPage
        }
        users{
            id
            name
            mediaListOptions {
                scoreFormat
            }
            statistics {
                anime {
                    count
                    scores {
                        score
                        mediaIds
                    }
                    
                }
            }
            siteUrl
        }
    }
}
'''

url = 'https://graphql.anilist.co'
api_output_users = []
api_output_users_dict = {'userId':[], 'mediaId':[],'rating':[]}
atLastPage = False
page_numbers = list(range(1,30001))
pages = list(np.random.choice(page_numbers,size=1000,replace=False))
point_10 = [6,7,8,9]
point_5 = [1,2,3,4]

# to include my own anilist account in the output
if 12841 not in pages:
    pages.pop(999)
    pages = [12841] + pages
else:
    # to move the page with my own anilist account to the front
    # as i will be terminating the loop once i have 10_000 users
    pages.remove(12841)
    pages = [12841] + pages
    
#max page as of 10 Feb 2022 is 30582
#while not atLastPage:
#pages = [5,6]
#pages = list(range(1,51))
for page in tqdm(pages):
#for i in range(5):
    variables = {
        'page': int(page),
        'perPage': 50,
    }
    multiplier = 1
    time.sleep(0.667)
    
    response = requests.post(url, json={'query': query, 'variables': variables})
    data = response.json()
    
    for user in data['data']['Page']['users']:
        user_scores = []
        multiplier = 1
        point_5_flag = False
        point_10_flag = False
        
        user['score_format'] = user['mediaListOptions']['scoreFormat']
        
        # exclude users that did not rate any anime, or are on a 3-point scale
        # The 3 point scale in AniList is equivalent to rating the anime with a smiley face, neutral face or sad face
        # Difficult to quantify the faces so we will exclude it in the data collection 
        if len(user['statistics']['anime']['scores']) == 0 or user['score_format'] == "POINT_3":
            continue
        
        if user['statistics']['anime']['count']<10:
            continue
            
        for scores in user['statistics']['anime']['scores']:
            user_scores.append(scores['score'])
        
        for score in user_scores:
            if score <= 10:
                if score in point_5:
                    point_5_flag = True
                if score in point_10:
                    point_10_flag = True
        
        if point_10_flag:
            multiplier = 10
        elif point_5_flag and not point_10_flag:
            multiplier = 20
                    
        
        if multiplier > 1:
            for scores in user['statistics']['anime']['scores']:
                scores['score'] *= multiplier

        # The 5 point scale in AniList is on a scale of 1 to 5, integers only
        ##if user['score_format'] == "POINT_5":
            # scaling the score by 20 so that the maximum score is 100
            # to have every user's scores on the same scale
            ##for score in user['statistics']['anime']['scores']:
                ##if score['score'] * 20 <= 100 :
                    ##score['score'] *= 20
                    
        # The 10 point scale in Anilist is on a scale of 1 to 10, integers only
        #if user['score_format'] == "POINT_10":
            # scaling the score by 10 so that the maximum score is 100
            # to have every user's scores on the same scale
         #   for score in user['statistics']['anime']['scores']:
         #       score['score'] *= 10
        
        # generating the data in the format taken in by recommender
        for scores in user['statistics']['anime']['scores']:
            for mediaId in scores['mediaIds']:
                api_output_users_dict['userId'].append(user['id'])
                api_output_users_dict['mediaId'].append(mediaId)
                api_output_users_dict['rating'].append(scores['score'])
                
        user['statistics'] = user['statistics']['anime']['scores']
        user.pop('mediaListOptions')
        #user.pop('statistics')
        api_output_users.append(user)
    
    #if len(api_output_users)>= 10000:
    #    print(f"Completed. Collated {len(api_output_users)} users")
    #    break
# Out:
# 100%|██████████| 1000/1000 [40:59<00:00,  2.46s/it]
# Wall time: 40min 59s

# %%
users_db_lightfm = pd.DataFrame(api_output_users_dict)
print(users_db_lightfm.shape)
users_db_lightfm.head()
# Out:
# (937799, 3)
#    userId  mediaId  rating
# 0  710080     1535      70
# 1  710080    21459      70
# 2  710080   113415      70
# 3  710080    11757      70
# 4  710080     5114      70

# %%
users_db_lightfm.to_csv("../data/user_list_lightfm.csv",index=False,encoding="utf-8")

# %%
user_db = pd.DataFrame(api_output_users)

# %%
user_db.to_pickle("../data/user_db.pkl")

# %%
def split_scores(stat_row):
    scores_dict = {}
    for item in stat_row:
        for media_id in item['mediaIds']:
            scores_dict[media_id] = item['score']
    
    return scores_dict

# %%
#user_db['statistics'] = user_db['statistics'].apply(lambda x: x['anime']['scores'])
user_db['statistics'] = user_db['statistics'].apply(split_scores)
user_db = user_db.join(pd.json_normalize(user_db['statistics']))
user_db = user_db.drop(columns=['statistics'])

# %%
print(user_db.shape)
user_db.head()
# Out:
# (14358, 9032)
#        id            name                         siteUrl      score_format  \
# 0  710080    idkhowtoplay  https://anilist.co/user/710080  POINT_10_DECIMAL
# 1  710090          minteu  https://anilist.co/user/710090  POINT_10_DECIMAL
# 2  710095      Jeremiah27  https://anilist.co/user/710095  POINT_10_DECIMAL
# 3  710096  offworldshadow  https://anilist.co/user/710096  POINT_10_DECIMAL
# 4  710098   mathiassassin  https://anilist.co/user/710098         POINT_100
#
#    1535  21459  113415  11757  5114  20958  ...  12141  6492  6000  314  1966  \
# 0  70.0   70.0    70.0   70.0  70.0   70.0  ...    NaN   NaN   NaN  NaN   NaN
# 1   NaN    NaN   100.0    NaN   NaN    NaN  ...    NaN   NaN   NaN  NaN   NaN
# 2  90.0    NaN     NaN    NaN   NaN    NaN  ...    NaN   NaN   NaN  NaN   NaN
# 3   NaN   70.0     NaN    NaN   NaN    NaN  ...    NaN   NaN   NaN  NaN   NaN
# 4  95.0   80.0    95.0    NaN  95.0   90.0  ...    NaN   NaN   NaN  NaN   NaN
#
#    8993  109931  7305  6885  16718
# 0   NaN     NaN   NaN   NaN    NaN
# 1   NaN     NaN   NaN   NaN    NaN
# 2   NaN     NaN   NaN   NaN    NaN
# 3   NaN     NaN   NaN   NaN    NaN
# 4   NaN     NaN   NaN   NaN    NaN
#
# [5 rows x 9032 columns]

# %%
user_db.to_csv("../data/user_list.csv",index=False,encoding="utf-8")

# %%
def save_progress(user_list,num):
    df = pd.DataFrame(user_list)
    df['statistics'] = df['statistics'].apply(split_scores)
    df = df.join(pd.json_normalize(df['statistics']))
    df = df.drop(columns=['statistics'])
    df.to_csv(f"../data/user_list_{num}.csv")
    print(f"user_list_{num}.csv saved")

# %%
def split_scores(stat_row):
    scores_dict = {}
    for item in stat_row:
        for media_id in item['mediaIds']:
            scores_dict[media_id] = item['score']
    
    return scores_dict

# %%
# %%time

query = '''
query ($page: Int, $perPage: Int) {
    Page (page: $page, perPage: $perPage) {
        pageInfo {
            total
            currentPage
            lastPage
            hasNextPage
            perPage
        }
        users{
            id
            name
            mediaListOptions {
                scoreFormat
            }
            statistics {
                anime {
                    scores {
                        score
                        mediaIds
                    }
                    
                }
            }
            siteUrl
        }
    }
}
'''

url = 'https://graphql.anilist.co'
api_output_users_full = []
atLastPage = False
page = 1
num = 0
is_retry = False
retries = 0
#max page as of 10 Feb 2022 is 30582
#max page as of 27 Feb 2022 is 30956

while not atLastPage:
    variables = {
        'page': page,
        'perPage': 50,
    }
    
    if is_retry:
        print(f"API response code {response.status_code}: retrying attempt #{retries}")
    
    if retries % 10:
        print("Retried {retries} times, pausing 30 seconds before trying again")
        time.sleep(30)
    elif retries > 50:
        raise ValueError("Retried more than 50 times")
    
    time.sleep(0.667)
    response = requests.post(url, json={'query': query, 'variables': variables})
    
    if response.status_code == 200:
        retries = 0
        is_retry = False
        data = response.json()

        #print(data)

        for user in data['data']['Page']['users']:
            ratings_count = 0
            user['score_format'] = user['mediaListOptions']['scoreFormat']

            # exclude users that did not rate any anime, or are on a 3-point scale
            # The 3 point scale in AniList is equivalent to rating the anime with a smiley face, neutral face or sad face
            # Difficult to quantify the faces so we will exclude it in the data collection 
            if len(user['statistics']['anime']['scores']) == 0 or user['score_format'] == "POINT_3":
                continue
            
            for score in user['statistics']['anime']['scores']:
            ratings_count += len(user['statistics']['anime']['scores']['mediaIds'])
        
            if ratings_count < 10:
                continue
            
            # The 10 point scale in Anilist is on a scale of 1 to 10, integers only
            if user['score_format'] == "POINT_10":
                # scaling the score by 10 so that the maximum score is 100
                # to have every user's scores on the same scale
                for score in user['statistics']['anime']['scores']:
                    score['score'] *= 10
            # The 5 point scale in AniList is on a scale of 1 to 5, integers only
            elif user['score_format'] == "POINT_5":
                # scaling the score by 20 so that the maximum score is 100
                # to have every user's scores on the same scale
                for score in user['statistics']['anime']['scores']:
                    score['score'] *= 20

            user['statistics'] = user['statistics']['anime']['scores']
            user.pop('mediaListOptions')
            #user.pop('statistics')
            api_output_users_full.append(user)

        #api_output_anime.extend(data['data']['Page']['media'])
        print(f"Users page {page}, total collated: {len(api_output_users_full)} users")
        
        if page % 6500 == 0:
            num += 1
            save_progress(api_output_users_full,num)
            api_output_users_full = []
        
        if data['data']['Page']['pageInfo']['hasNextPage'] == True:
            page += 1
        else:
            atLastPage = True
    else:
        is_retry = True
        retries += 1

print("Data collection of users completed")
# Out:
# Users page 1, total collated: 12 users
# Users page 2, total collated: 23 users
# Users page 3, total collated: 34 users
# Users page 4, total collated: 44 users
# Users page 5, total collated: 51 users
# Users page 6, total collated: 56 users
# Users page 7, total collated: 63 users
# Users page 8, total collated: 73 users
# Users page 9, total collated: 87 users
# Users page 10, total collated: 95 users
# Users page 11, total collated: 101 users
# Users page 12, total collated: 106 users
# Users page 13, total collated: 110 users
# Users page 14, total collated: 116 users
# Users page 15, total collated: 122 users
# Users page 16, total collated: 130 users
# Users page 17, total collated: 136 users
# Users page 18, total collated: 143 users
# Users page 19, total collated: 151 users
# Users page 20, total collated: 158 users
# Users page 21, total collated: 164 users
# Users page 22, total collated: 172 users
# Users page 23, total collated: 180 users
# Users page 24, total collated: 184 users
# Users page 25, total collated: 193 users
# Users page 26, total collated: 199 users
# Users page 27, total collated: 208 users
# Users page 28, total collated: 214 users
# Users page 29, total collated: 223 users
# Users page 30, total collated: 231 users
# Users page 31, total collated: 238 users
# Users page 32, total collated: 247 users
# Users page 33, total collated: 251 users
# Users page 34, total collated: 263 users
# Users page 35, total collated: 274 users
# Users page 36, total collated: 286 users
# Users page 37, total collated: 295 users
# Users page 38, total collated: 300 users
# Users page 39, total collated: 305 users
# Users page 40, total collated: 314 users
# Users page 41, total collated: 323 users
# Users page 42, total collated: 326 users
# Users page 43, total collated: 332 users
# Users page 44, total collated: 338 users
# Users page 45, total collated: 346 users
# Users page 46, total collated: 358 users
# Users page 47, total collated: 365 users
# Users page 48, total collated: 370 users
# Users page 49, total collated: 379 users
# Users page 50, total collated: 389 users
# Users page 51, total collated: 398 users
# Users page 52, total collated: 404 users
# Users page 53, total collated: 415 users
# Users page 54, total collated: 422 users
# Users page 55, total collated: 431 users
# Users page 56, total collated: 437 users
# Users page 57, total collated: 446 users
# Users page 58, total collated: 449 users
# Users page 59, total collated: 458 users
# Users page 60, total collated: 464 users
# Users page 61, total collated: 475 users
# Users page 62, total collated: 479 users
# Users page 63, total collated: 487 users
# Users page 64, total collated: 493 users
# Users page 65, total collated: 500 users
# Users page 66, total collated: 509 users
# Users page 67, total collated: 515 users
# Users page 68, total collated: 526 users
# Users page 69, total collated: 533 users
# Users page 70, total collated: 540 users
# Users page 71, total collated: 545 users
# Users page 72, total collated: 553 users
# Users page 73, total collated: 559 users
# Users page 74, total collated: 568 users
# Users page 75, total collated: 574 users
# Users page 76, total collated: 581 users
# Users page 77, total collated: 585 users
# Users page 78, total collated: 594 users
# Users page 79, total collated: 600 users
# Users page 80, total collated: 605 users
# Users page 81, total collated: 613 users
# Users page 82, total collated: 621 users
# Users page 83, total collated: 627 users
# Users page 84, total collated: 633 users
# Users page 85, total collated: 641 users
# Users page 86, total collated: 652 users
# Users page 87, total collated: 661 users
# Users page 88, total collated: 671 users
# Users page 89, total collated: 675 users
# Users page 90, total collated: 682 users
# Users page 91, total collated: 693 users
# Users page 92, total collated: 697 users
# Users page 93, total collated: 704 users
# Users page 94, total collated: 711 users
# Users page 95, total collated: 719 users
# Users page 96, total collated: 724 users
# Users page 97, total collated: 731 users
# Users page 98, total collated: 739 users
# Users page 99, total collated: 740 users
# Users page 100, total collated: 745 users
# Users page 101, total collated: 750 users
# Users page 102, total collated: 754 users
# Users page 103, total collated: 755 users
# Users page 104, total collated: 758 users
# Users page 105, total collated: 763 users
# Users page 106, total collated: 767 users
# Users page 107, total collated: 771 users
# Users page 108, total collated: 777 users
# Users page 109, total collated: 781 users
# Users page 110, total collated: 784 users
# Users page 111, total collated: 789 users
# Users page 112, total collated: 790 users
# Users page 113, total collated: 794 users
# Users page 114, total collated: 802 users
# Users page 115, total collated: 804 users
# Users page 116, total collated: 810 users
# Users page 117, total collated: 813 users
# Users page 118, total collated: 821 users
# Users page 119, total collated: 829 users
# Users page 120, total collated: 837 users
# Users page 121, total collated: 846 users
# Users page 122, total collated: 851 users
# Users page 123, total collated: 856 users
# Users page 124, total collated: 863 users
# Users page 125, total collated: 871 users
# Users page 126, total collated: 873 users
# Users page 127, total collated: 879 users
# Users page 128, total collated: 886 users
# Users page 129, total collated: 891 users
# Users page 130, total collated: 894 users
# Users page 131, total collated: 898 users
# Users page 132, total collated: 906 users
# Users page 133, total collated: 916 users
# Users page 134, total collated: 924 users
# Users page 135, total collated: 932 users
# Users page 136, total collated: 942 users
# Users page 137, total collated: 949 users
# Users page 138, total collated: 957 users
# Users page 139, total collated: 966 users
# Users page 140, total collated: 971 users
# Users page 141, total collated: 981 users
# Users page 142, total collated: 989 users
# Users page 143, total collated: 994 users
# Users page 144, total collated: 1001 users
# Users page 145, total collated: 1006 users
# Users page 146, total collated: 1013 users
# Users page 147, total collated: 1018 users
# Users page 148, total collated: 1019 users
# Users page 149, total collated: 1020 users
# Users page 150, total collated: 1026 users
# Users page 151, total collated: 1032 users
# Users page 152, total collated: 1037 users
# Users page 153, total collated: 1041 users
# Users page 154, total collated: 1046 users
# Users page 155, total collated: 1051 users
# Users page 156, total collated: 1058 users
# Users page 157, total collated: 1060 users
# Users page 158, total collated: 1072 users
# Users page 159, total collated: 1084 users
# Users page 160, total collated: 1094 users
# Users page 161, total collated: 1101 users
# Users page 162, total collated: 1109 users
# Users page 163, total collated: 1112 users
# Users page 164, total collated: 1117 users
# Users page 165, total collated: 1119 users
# Users page 166, total collated: 1126 users
# Users page 167, total collated: 1129 users
# Users page 168, total collated: 1132 users
# Users page 169, total collated: 1139 users
# Users page 170, total collated: 1142 users
# Users page 171, total collated: 1145 users
# Users page 172, total collated: 1150 users
# Users page 173, total collated: 1157 users
# Users page 174, total collated: 1166 users
# Users page 175, total collated: 1168 users
# Users page 176, total collated: 1171 users
# Users page 177, total collated: 1179 users
# Users page 178, total collated: 1182 users
# Users page 179, total collated: 1190 users
# Users page 180, total collated: 1197 users
# Users page 181, total collated: 1202 users
# Users page 182, total collated: 1207 users
# Users page 183, total collated: 1209 users
# Users page 184, total collated: 1217 users
# Users page 185, total collated: 1218 users
# Users page 186, total collated: 1223 users
# Users page 187, total collated: 1223 users
# Users page 188, total collated: 1224 users
# Users page 189, total collated: 1230 users
# Users page 190, total collated: 1231 users
# Users page 191, total collated: 1231 users
# Users page 192, total collated: 1238 users
# Users page 193, total collated: 1248 users
# Users page 194, total collated: 1250 users
# Users page 195, total collated: 1251 users
# Users page 196, total collated: 1255 users
# Users page 197, total collated: 1260 users
# Users page 198, total collated: 1260 users
# Users page 199, total collated: 1261 users
# Users page 200, total collated: 1265 users
# Users page 201, total collated: 1272 users
# Users page 202, total collated: 1278 users
# Users page 203, total collated: 1283 users
# Users page 204, total collated: 1287 users
# Users page 205, total collated: 1287 users
# Users page 206, total collated: 1288 users
# Users page 207, total collated: 1293 users
# Users page 208, total collated: 1296 users
# Users page 209, total collated: 1297 users
# Users page 210, total collated: 1306 users
# Users page 211, total collated: 1309 users
# Users page 212, total collated: 1311 users
# Users page 213, total collated: 1317 users
# Users page 214, total collated: 1318 users
# Users page 215, total collated: 1322 users
# Users page 216, total collated: 1332 users
# Users page 217, total collated: 1334 users
# Users page 218, total collated: 1340 users
# Users page 219, total collated: 1343 users
# Users page 220, total collated: 1350 users
# Users page 221, total collated: 1358 users
# Users page 222, total collated: 1361 users
# Users page 223, total collated: 1367 users
# Users page 224, total collated: 1373 users
# Users page 225, total collated: 1380 users
# Users page 226, total collated: 1386 users
# Users page 227, total collated: 1396 users
# Users page 228, total collated: 1404 users
# Users page 229, total collated: 1412 users
# Users page 230, total collated: 1418 users
# Users page 231, total collated: 1423 users
# Users page 232, total collated: 1429 users
# Users page 233, total collated: 1436 users
# Users page 234, total collated: 1439 users
# Users page 235, total collated: 1444 users
# Users page 236, total collated: 1449 users
# Users page 237, total collated: 1456 users
# Users page 238, total collated: 1463 users
# Users page 239, total collated: 1471 users
# Users page 240, total collated: 1473 users
# Users page 241, total collated: 1482 users
# Users page 242, total collated: 1488 users
# Users page 243, total collated: 1493 users
# Users page 244, total collated: 1496 users
# Users page 245, total collated: 1505 users
# Users page 246, total collated: 1514 users
# Users page 247, total collated: 1520 users
# Users page 248, total collated: 1524 users
# Users page 249, total collated: 1532 users
# Users page 250, total collated: 1539 users
# Users page 251, total collated: 1547 users
# Users page 252, total collated: 1553 users
# Users page 253, total collated: 1562 users
# Users page 254, total collated: 1565 users
# Users page 255, total collated: 1569 users
# Users page 256, total collated: 1574 users
# Users page 257, total collated: 1582 users
# Users page 258, total collated: 1590 users
# Users page 259, total collated: 1595 users
# Users page 260, total collated: 1598 users
# Users page 261, total collated: 1606 users
# Users page 262, total collated: 1612 users
# Users page 263, total collated: 1620 users
# Users page 264, total collated: 1626 users
# Users page 265, total collated: 1631 users
# Users page 266, total collated: 1638 users
# Users page 267, total collated: 1644 users
# Users page 268, total collated: 1652 users
# Users page 269, total collated: 1654 users
# Users page 270, total collated: 1661 users
# Users page 271, total collated: 1672 users
# Users page 272, total collated: 1678 users
# Users page 273, total collated: 1682 users
# Users page 274, total collated: 1685 users
# Users page 275, total collated: 1691 users
# Users page 276, total collated: 1698 users
# Users page 277, total collated: 1704 users
# Users page 278, total collated: 1710 users
# Users page 279, total collated: 1721 users
# Users page 280, total collated: 1727 users
# Users page 281, total collated: 1737 users
# Users page 282, total collated: 1744 users
# Users page 283, total collated: 1750 users
# Users page 284, total collated: 1758 users
# Users page 285, total collated: 1761 users
# Users page 286, total collated: 1770 users
# Users page 287, total collated: 1776 users
# Users page 288, total collated: 1781 users
# Users page 289, total collated: 1788 users
# Users page 290, total collated: 1795 users
# Users page 291, total collated: 1801 users
# Users page 292, total collated: 1805 users
# Users page 293, total collated: 1812 users
# Users page 294, total collated: 1815 users
# Users page 295, total collated: 1821 users
# Users page 296, total collated: 1828 users
# Users page 297, total collated: 1832 users
# Users page 298, total collated: 1840 users
# Users page 299, total collated: 1845 users
# Users page 300, total collated: 1850 users
# Users page 301, total collated: 1853 users
# Users page 302, total collated: 1857 users
# Users page 303, total collated: 1864 users
# Users page 304, total collated: 1871 users
# Users page 305, total collated: 1876 users
# Users page 306, total collated: 1884 users
# Users page 307, total collated: 1893 users
# Users page 308, total collated: 1898 users
# Users page 309, total collated: 1903 users
# Users page 310, total collated: 1908 users
# Users page 311, total collated: 1913 users
# Users page 312, total collated: 1920 users
# Users page 313, total collated: 1926 users
# Users page 314, total collated: 1931 users
# Users page 315, total collated: 1931 users
# Users page 316, total collated: 1938 users
# Users page 317, total collated: 1943 users
# Users page 318, total collated: 1947 users
# Users page 319, total collated: 1952 users
# Users page 320, total collated: 1956 users
# Users page 321, total collated: 1959 users
# Users page 322, total collated: 1968 users
# Users page 323, total collated: 1977 users
# Users page 324, total collated: 1987 users
# Users page 325, total collated: 1988 users
# Users page 326, total collated: 1998 users
# Users page 327, total collated: 2004 users
# Users page 328, total collated: 2011 users
# Users page 329, total collated: 2016 users
# Users page 330, total collated: 2022 users
# Users page 331, total collated: 2029 users
# Users page 332, total collated: 2034 users
# Users page 333, total collated: 2038 users
# Users page 334, total collated: 2043 users
# Users page 335, total collated: 2047 users
# Users page 336, total collated: 2051 users
# Users page 337, total collated: 2054 users
# Users page 338, total collated: 2059 users
# Users page 339, total collated: 2063 users
# Users page 340, total collated: 2069 users
# Users page 341, total collated: 2078 users
# Users page 342, total collated: 2081 users
# Users page 343, total collated: 2092 users
# Users page 344, total collated: 2096 users
# Users page 345, total collated: 2101 users
# Users page 346, total collated: 2105 users
# Users page 347, total collated: 2112 users
# Users page 348, total collated: 2117 users
# Users page 349, total collated: 2120 users
# Users page 350, total collated: 2126 users
# Users page 351, total collated: 2131 users
# Users page 352, total collated: 2135 users
# Users page 353, total collated: 2140 users
# Users page 354, total collated: 2148 users
# Users page 355, total collated: 2152 users
# Users page 356, total collated: 2162 users
# Users page 357, total collated: 2164 users
# Users page 358, total collated: 2169 users
# Users page 359, total collated: 2173 users
# Users page 360, total collated: 2175 users
# Users page 361, total collated: 2178 users
# Users page 362, total collated: 2184 users
# Users page 363, total collated: 2187 users
# Users page 364, total collated: 2188 users
# Users page 365, total collated: 2197 users
# Users page 366, total collated: 2202 users
# Users page 367, total collated: 2214 users
# Users page 368, total collated: 2220 users
# Users page 369, total collated: 2228 users
# Users page 370, total collated: 2231 users
# Users page 371, total collated: 2237 users
# Users page 372, total collated: 2242 users
# Users page 373, total collated: 2248 users
# Users page 374, total collated: 2255 users
# Users page 375, total collated: 2261 users
# Users page 376, total collated: 2269 users
# Users page 377, total collated: 2276 users
# Users page 378, total collated: 2283 users
# Users page 379, total collated: 2287 users
# Users page 380, total collated: 2293 users
# Users page 381, total collated: 2301 users
# Users page 382, total collated: 2305 users
# Users page 383, total collated: 2311 users
# Users page 384, total collated: 2319 users
# Users page 385, total collated: 2325 users
# Users page 386, total collated: 2332 users
# Users page 387, total collated: 2338 users
# Users page 388, total collated: 2345 users
# Users page 389, total collated: 2354 users
# Users page 390, total collated: 2361 users
# Users page 391, total collated: 2366 users
# Users page 392, total collated: 2371 users
# Users page 393, total collated: 2375 users
# Users page 394, total collated: 2379 users
# Users page 395, total collated: 2384 users
# Users page 396, total collated: 2391 users
# Users page 397, total collated: 2398 users
# Users page 398, total collated: 2402 users
# Users page 399, total collated: 2408 users
# Users page 400, total collated: 2414 users
# Users page 401, total collated: 2421 users
# Users page 402, total collated: 2428 users
# Users page 403, total collated: 2435 users
# Users page 404, total collated: 2439 users
# Users page 405, total collated: 2443 users
# Users page 406, total collated: 2445 users
# Users page 407, total collated: 2455 users
# Users page 408, total collated: 2460 users
# Users page 409, total collated: 2462 users
# Users page 410, total collated: 2467 users
# Users page 411, total collated: 2469 users
# Users page 412, total collated: 2479 users
# Users page 413, total collated: 2484 users
# Users page 414, total collated: 2491 users
# Users page 415, total collated: 2493 users
# Users page 416, total collated: 2501 users
# Users page 417, total collated: 2508 users
# Users page 418, total collated: 2518 users
# Users page 419, total collated: 2525 users
# Users page 420, total collated: 2528 users
# Users page 421, total collated: 2537 users
# Users page 422, total collated: 2540 users
# Users page 423, total collated: 2543 users
# Users page 424, total collated: 2549 users
# Users page 425, total collated: 2557 users
# Users page 426, total collated: 2564 users
# Users page 427, total collated: 2571 users
# Users page 428, total collated: 2581 users
# Users page 429, total collated: 2590 users
# Users page 430, total collated: 2596 users
# Users page 431, total collated: 2605 users
# Users page 432, total collated: 2610 users
# Users page 433, total collated: 2618 users
# Users page 434, total collated: 2624 users
# Users page 435, total collated: 2627 users
# Users page 436, total collated: 2635 users
# Users page 437, total collated: 2642 users
# Users page 438, total collated: 2655 users
# Users page 439, total collated: 2660 users
# Users page 440, total collated: 2667 users
# Users page 441, total collated: 2671 users
# Users page 442, total collated: 2679 users
# Users page 443, total collated: 2683 users
# Users page 444, total collated: 2689 users
# Users page 445, total collated: 2696 users
# Users page 446, total collated: 2701 users
# Users page 447, total collated: 2706 users
# Users page 448, total collated: 2711 users
# Users page 449, total collated: 2718 users
# Users page 450, total collated: 2724 users
# Users page 451, total collated: 2730 users
# Users page 452, total collated: 2734 users
# Users page 453, total collated: 2740 users
# Users page 454, total collated: 2746 users
# Users page 455, total collated: 2750 users
# Users page 456, total collated: 2760 users
# Users page 457, total collated: 2768 users
# Users page 458, total collated: 2773 users
# Users page 459, total collated: 2775 users
# Users page 460, total collated: 2780 users
# Users page 461, total collated: 2781 users
# Users page 462, total collated: 2783 users
# Users page 463, total collated: 2787 users
# Users page 464, total collated: 2792 users
# Users page 465, total collated: 2797 users
# Users page 466, total collated: 2800 users
# Users page 467, total collated: 2807 users
# Users page 468, total collated: 2815 users
# Users page 469, total collated: 2820 users
# Users page 470, total collated: 2824 users
# Users page 471, total collated: 2826 users
# Users page 472, total collated: 2830 users
# Users page 473, total collated: 2836 users
# Users page 474, total collated: 2839 users
# Users page 475, total collated: 2845 users
# Users page 476, total collated: 2850 users
# Users page 477, total collated: 2856 users
# Users page 478, total collated: 2863 users
# Users page 479, total collated: 2868 users
# Users page 480, total collated: 2878 users
# Users page 481, total collated: 2883 users
# Users page 482, total collated: 2890 users
# Users page 483, total collated: 2897 users
# Users page 484, total collated: 2902 users
# Users page 485, total collated: 2910 users
# Users page 486, total collated: 2916 users
# Users page 487, total collated: 2924 users
# Users page 488, total collated: 2926 users
# Users page 489, total collated: 2927 users
# Users page 490, total collated: 2929 users
# Users page 491, total collated: 2938 users
# Users page 492, total collated: 2945 users
# Users page 493, total collated: 2952 users
# Users page 494, total collated: 2956 users
# Users page 495, total collated: 2960 users
# Users page 496, total collated: 2964 users
# Users page 497, total collated: 2967 users
# Users page 498, total collated: 2970 users
# Users page 499, total collated: 2975 users
# Users page 500, total collated: 2979 users
# Users page 501, total collated: 2983 users
# Users page 502, total collated: 2985 users
# Users page 503, total collated: 2992 users
# Users page 504, total collated: 2997 users
# Users page 505, total collated: 3006 users
# Users page 506, total collated: 3012 users
# Users page 507, total collated: 3020 users
# Users page 508, total collated: 3023 users
# Users page 509, total collated: 3026 users
# Users page 510, total collated: 3032 users
# Users page 511, total collated: 3037 users
# Users page 512, total collated: 3046 users
# Users page 513, total collated: 3050 users
# Users page 514, total collated: 3057 users
# Users page 515, total collated: 3062 users
# Users page 516, total collated: 3064 users
# Users page 517, total collated: 3068 users
# Users page 518, total collated: 3074 users
# Users page 519, total collated: 3076 users
# Users page 520, total collated: 3082 users
# Users page 521, total collated: 3087 users
# Users page 522, total collated: 3095 users
# Users page 523, total collated: 3100 users
# Users page 524, total collated: 3102 users
# Users page 525, total collated: 3110 users
# Users page 526, total collated: 3112 users
# Users page 527, total collated: 3121 users
# Users page 528, total collated: 3125 users
# Users page 529, total collated: 3128 users
# Users page 530, total collated: 3132 users
# Users page 531, total collated: 3138 users
# Users page 532, total collated: 3143 users
# Users page 533, total collated: 3147 users
# Users page 534, total collated: 3163 users
# Users page 535, total collated: 3169 users
# Users page 536, total collated: 3174 users
# Users page 537, total collated: 3181 users
# Users page 538, total collated: 3186 users
# Users page 539, total collated: 3192 users
# Users page 540, total collated: 3200 users
# Users page 541, total collated: 3202 users
# Users page 542, total collated: 3211 users
# Users page 543, total collated: 3218 users
# Users page 544, total collated: 3221 users
# Users page 545, total collated: 3226 users
# Users page 546, total collated: 3232 users
# Users page 547, total collated: 3239 users
# Users page 548, total collated: 3246 users
# Users page 549, total collated: 3255 users
# Users page 550, total collated: 3262 users
# Users page 551, total collated: 3275 users
# Users page 552, total collated: 3282 users
# Users page 553, total collated: 3286 users
# Users page 554, total collated: 3295 users
# Users page 555, total collated: 3302 users
# Users page 556, total collated: 3307 users
# Users page 557, total collated: 3313 users
# Users page 558, total collated: 3318 users
# Users page 559, total collated: 3326 users
# Users page 560, total collated: 3331 users
# Users page 561, total collated: 3336 users
# Users page 562, total collated: 3347 users
# Users page 563, total collated: 3352 users
# Users page 564, total collated: 3357 users
# Users page 565, total collated: 3362 users
# Users page 566, total collated: 3370 users
# Users page 567, total collated: 3372 users
# Users page 568, total collated: 3379 users
# Users page 569, total collated: 3385 users
# Users page 570, total collated: 3388 users
# Users page 571, total collated: 3399 users
# Users page 572, total collated: 3407 users
# Users page 573, total collated: 3412 users
# Users page 574, total collated: 3418 users
# Users page 575, total collated: 3427 users
# Users page 576, total collated: 3430 users
# Users page 577, total collated: 3433 users
# Users page 578, total collated: 3438 users
# Users page 579, total collated: 3443 users
# Users page 580, total collated: 3447 users
# Users page 581, total collated: 3453 users
# Users page 582, total collated: 3459 users
# Users page 583, total collated: 3465 users
# Users page 584, total collated: 3469 users
# Users page 585, total collated: 3474 users
# Users page 586, total collated: 3481 users
# Users page 587, total collated: 3485 users
# Users page 588, total collated: 3488 users
# Users page 589, total collated: 3492 users
# Users page 590, total collated: 3497 users
# Users page 591, total collated: 3502 users
# Users page 592, total collated: 3510 users
# Users page 593, total collated: 3513 users
# Users page 594, total collated: 3518 users
# Users page 595, total collated: 3522 users
# Users page 596, total collated: 3525 users
# Users page 597, total collated: 3532 users
# Users page 598, total collated: 3536 users
# Users page 599, total collated: 3543 users
# Users page 600, total collated: 3547 users
# Users page 601, total collated: 3553 users
# Users page 602, total collated: 3558 users
# Users page 603, total collated: 3562 users
# Users page 604, total collated: 3571 users
# Users page 605, total collated: 3573 users
# Users page 606, total collated: 3580 users
# Users page 607, total collated: 3584 users
# Users page 608, total collated: 3588 users
# Users page 609, total collated: 3592 users
# Users page 610, total collated: 3600 users
# Users page 611, total collated: 3608 users
# Users page 612, total collated: 3610 users
# Users page 613, total collated: 3615 users
# Users page 614, total collated: 3619 users
# Users page 615, total collated: 3629 users
# Users page 616, total collated: 3630 users
# Users page 617, total collated: 3637 users
# Users page 618, total collated: 3644 users
# Users page 619, total collated: 3652 users
# Users page 620, total collated: 3659 users
# Users page 621, total collated: 3664 users
# Users page 622, total collated: 3672 users
# Users page 623, total collated: 3674 users
# Users page 624, total collated: 3684 users
# Users page 625, total collated: 3689 users
# Users page 626, total collated: 3693 users
# Users page 627, total collated: 3700 users
# Users page 628, total collated: 3706 users
# Users page 629, total collated: 3716 users
# Users page 630, total collated: 3717 users
# Users page 631, total collated: 3720 users
# Users page 632, total collated: 3725 users
# Users page 633, total collated: 3730 users
# Users page 634, total collated: 3737 users
# Users page 635, total collated: 3741 users
# Users page 636, total collated: 3745 users
# Users page 637, total collated: 3751 users
# Users page 638, total collated: 3756 users
# Users page 639, total collated: 3763 users
# Users page 640, total collated: 3768 users
# Users page 641, total collated: 3776 users
# Users page 642, total collated: 3781 users
# Users page 643, total collated: 3785 users
# Users page 644, total collated: 3791 users
# Users page 645, total collated: 3797 users
# Users page 646, total collated: 3800 users
# Users page 647, total collated: 3803 users
# Users page 648, total collated: 3813 users
# Users page 649, total collated: 3818 users
# Users page 650, total collated: 3825 users
# Users page 651, total collated: 3829 users
# Users page 652, total collated: 3835 users
# Users page 653, total collated: 3840 users
# Users page 654, total collated: 3842 users
# Users page 655, total collated: 3846 users
# Users page 656, total collated: 3853 users
# Users page 657, total collated: 3861 users
# Users page 658, total collated: 3865 users
# Users page 659, total collated: 3873 users
# Users page 660, total collated: 3876 users
# Users page 661, total collated: 3881 users
# Users page 662, total collated: 3888 users
# Users page 663, total collated: 3892 users
# Users page 664, total collated: 3898 users
# Users page 665, total collated: 3905 users
# Users page 666, total collated: 3910 users
# Users page 667, total collated: 3918 users
# Users page 668, total collated: 3925 users
# Users page 669, total collated: 3931 users
# Users page 670, total collated: 3939 users
# Users page 671, total collated: 3944 users
# Users page 672, total collated: 3948 users
# Users page 673, total collated: 3953 users
# Users page 674, total collated: 3959 users
# Users page 675, total collated: 3965 users
# Users page 676, total collated: 3967 users
# Users page 677, total collated: 3972 users
# Users page 678, total collated: 3981 users
# Users page 679, total collated: 3986 users
# Users page 680, total collated: 3989 users
# Users page 681, total collated: 3992 users
# Users page 682, total collated: 3997 users
# Users page 683, total collated: 4002 users
# Users page 684, total collated: 4004 users
# Users page 685, total collated: 4008 users
# Users page 686, total collated: 4013 users
# Users page 687, total collated: 4014 users
# Users page 688, total collated: 4020 users
# Users page 689, total collated: 4025 users
# Users page 690, total collated: 4026 users
# Users page 691, total collated: 4032 users
# Users page 692, total collated: 4039 users
# Users page 693, total collated: 4042 users
# Users page 694, total collated: 4050 users
# Users page 695, total collated: 4054 users
# Users page 696, total collated: 4059 users
# Users page 697, total collated: 4066 users
# Users page 698, total collated: 4069 users
# Users page 699, total collated: 4073 users
# Users page 700, total collated: 4075 users
# Users page 701, total collated: 4080 users
# Users page 702, total collated: 4084 users
# Users page 703, total collated: 4090 users
# Users page 704, total collated: 4095 users
# Users page 705, total collated: 4099 users
# Users page 706, total collated: 4102 users
# Users page 707, total collated: 4113 users
# Users page 708, total collated: 4117 users
# Users page 709, total collated: 4121 users
# Users page 710, total collated: 4127 users
# Users page 711, total collated: 4134 users
# Users page 712, total collated: 4139 users
# Users page 713, total collated: 4149 users
# Users page 714, total collated: 4154 users
# Users page 715, total collated: 4158 users
# Users page 716, total collated: 4166 users
# Users page 717, total collated: 4173 users
# Users page 718, total collated: 4175 users
# Users page 719, total collated: 4181 users
# Users page 720, total collated: 4192 users
# Users page 721, total collated: 4196 users
# Users page 722, total collated: 4203 users
# Users page 723, total collated: 4207 users
# Users page 724, total collated: 4212 users
# Users page 725, total collated: 4218 users
# Users page 726, total collated: 4222 users
# Users page 727, total collated: 4229 users
# Users page 728, total collated: 4230 users
# Users page 729, total collated: 4233 users
# Users page 730, total collated: 4238 users
# Users page 731, total collated: 4242 users
# Users page 732, total collated: 4247 users
# Users page 733, total collated: 4252 users
# Users page 734, total collated: 4260 users
# Users page 735, total collated: 4262 users
# Users page 736, total collated: 4266 users
# Users page 737, total collated: 4273 users
# Users page 738, total collated: 4276 users
# Users page 739, total collated: 4281 users
# Users page 740, total collated: 4285 users
# Users page 741, total collated: 4290 users
# Users page 742, total collated: 4294 users
# Users page 743, total collated: 4300 users
# Users page 744, total collated: 4300 users
# Users page 745, total collated: 4302 users
# Users page 746, total collated: 4313 users
# Users page 747, total collated: 4319 users
# Users page 748, total collated: 4327 users
# Users page 749, total collated: 4333 users
# Users page 750, total collated: 4339 users
# Users page 751, total collated: 4346 users
# Users page 752, total collated: 4350 users
# Users page 753, total collated: 4353 users
# Users page 754, total collated: 4358 users
# Users page 755, total collated: 4363 users
# Users page 756, total collated: 4371 users
# Users page 757, total collated: 4377 users
# Users page 758, total collated: 4385 users
# Users page 759, total collated: 4391 users
# Users page 760, total collated: 4398 users
# Users page 761, total collated: 4405 users
# Users page 762, total collated: 4409 users
# Users page 763, total collated: 4418 users
# Users page 764, total collated: 4422 users
# Users page 765, total collated: 4427 users
# Users page 766, total collated: 4437 users
# Users page 767, total collated: 4442 users
# Users page 768, total collated: 4445 users
# Users page 769, total collated: 4457 users
# Users page 770, total collated: 4463 users
# Users page 771, total collated: 4468 users
# Users page 772, total collated: 4472 users
# Users page 773, total collated: 4481 users
# Users page 774, total collated: 4483 users
# Users page 775, total collated: 4489 users
# Users page 776, total collated: 4492 users
# Users page 777, total collated: 4501 users
# Users page 778, total collated: 4503 users
# Users page 779, total collated: 4509 users
# Users page 780, total collated: 4516 users
# Users page 781, total collated: 4524 users
# Users page 782, total collated: 4529 users
# Users page 783, total collated: 4536 users
# Users page 784, total collated: 4542 users
# Users page 785, total collated: 4547 users
# Users page 786, total collated: 4557 users
# Users page 787, total collated: 4560 users
# Users page 788, total collated: 4565 users
# Users page 789, total collated: 4567 users
# Users page 790, total collated: 4573 users
# Users page 791, total collated: 4577 users
# Users page 792, total collated: 4582 users
# Users page 793, total collated: 4591 users
# Users page 794, total collated: 4601 users
# Users page 795, total collated: 4608 users
# Users page 796, total collated: 4615 users
# Users page 797, total collated: 4622 users
# Users page 798, total collated: 4629 users
# Users page 799, total collated: 4636 users
# Users page 800, total collated: 4644 users
# Users page 801, total collated: 4648 users
# Users page 802, total collated: 4654 users
# Users page 803, total collated: 4657 users
# Users page 804, total collated: 4660 users
# Users page 805, total collated: 4663 users
# Users page 806, total collated: 4668 users
# Users page 807, total collated: 4675 users
# Users page 808, total collated: 4680 users
# Users page 809, total collated: 4685 users
# Users page 810, total collated: 4692 users
# Users page 811, total collated: 4697 users
# Users page 812, total collated: 4702 users
# Users page 813, total collated: 4706 users
# Users page 814, total collated: 4709 users
# Users page 815, total collated: 4714 users
# Users page 816, total collated: 4725 users
# Users page 817, total collated: 4730 users
# Users page 818, total collated: 4737 users
# Users page 819, total collated: 4747 users
# Users page 820, total collated: 4754 users
# Users page 821, total collated: 4757 users
# Users page 822, total collated: 4762 users
# Users page 823, total collated: 4768 users
# Users page 824, total collated: 4772 users
# Users page 825, total collated: 4779 users
# Users page 826, total collated: 4783 users
# Users page 827, total collated: 4790 users
# Users page 828, total collated: 4793 users
# Users page 829, total collated: 4801 users
# Users page 830, total collated: 4804 users
# Users page 831, total collated: 4808 users
# Users page 832, total collated: 4814 users
# Users page 833, total collated: 4818 users
# Users page 834, total collated: 4822 users
# Users page 835, total collated: 4827 users
# Users page 836, total collated: 4829 users
# Users page 837, total collated: 4832 users
# Users page 838, total collated: 4834 users
# Users page 839, total collated: 4835 users
# Users page 840, total collated: 4844 users
# Users page 841, total collated: 4848 users
# Users page 842, total collated: 4851 users
# Users page 843, total collated: 4855 users
# Users page 844, total collated: 4860 users
# Users page 845, total collated: 4864 users
# Users page 846, total collated: 4869 users
# Users page 847, total collated: 4877 users
# Users page 848, total collated: 4887 users
# Users page 849, total collated: 4889 users
# Users page 850, total collated: 4897 users
# Users page 851, total collated: 4901 users
# Users page 852, total collated: 4906 users
# Users page 853, total collated: 4915 users
# Users page 854, total collated: 4923 users
# Users page 855, total collated: 4929 users
# Users page 856, total collated: 4935 users
# Users page 857, total collated: 4939 users
# Users page 858, total collated: 4944 users
# Users page 859, total collated: 4951 users
# Users page 860, total collated: 4955 users
# Users page 861, total collated: 4958 users
# Users page 862, total collated: 4963 users
# Users page 863, total collated: 4968 users
# Users page 864, total collated: 4973 users
# Users page 865, total collated: 4977 users
# Users page 866, total collated: 4979 users
# Users page 867, total collated: 4982 users
# Users page 868, total collated: 4985 users
# Users page 869, total collated: 4988 users
# Users page 870, total collated: 4994 users
# Users page 871, total collated: 4998 users
# Users page 872, total collated: 5001 users
# Users page 873, total collated: 5009 users
# Users page 874, total collated: 5014 users
# Users page 875, total collated: 5019 users
# Users page 876, total collated: 5022 users
# Users page 877, total collated: 5028 users
# Users page 878, total collated: 5032 users
# Users page 879, total collated: 5042 users
# Users page 880, total collated: 5045 users
# Users page 881, total collated: 5054 users
# Users page 882, total collated: 5061 users
# Users page 883, total collated: 5067 users
# Users page 884, total collated: 5072 users
# Users page 885, total collated: 5079 users
# Users page 886, total collated: 5085 users
# Users page 887, total collated: 5091 users
# Users page 888, total collated: 5099 users
# Users page 889, total collated: 5106 users
# Users page 890, total collated: 5114 users
# Users page 891, total collated: 5117 users
# Users page 892, total collated: 5122 users
# Users page 893, total collated: 5124 users
# Users page 894, total collated: 5130 users
# Users page 895, total collated: 5135 users
# Users page 896, total collated: 5138 users
# Users page 897, total collated: 5144 users
# Users page 898, total collated: 5153 users
# Users page 899, total collated: 5158 users
# Users page 900, total collated: 5163 users
# Users page 901, total collated: 5165 users
# Users page 902, total collated: 5169 users
# Users page 903, total collated: 5176 users
# Users page 904, total collated: 5180 users
# Users page 905, total collated: 5184 users
# Users page 906, total collated: 5190 users
# Users page 907, total collated: 5194 users
# Users page 908, total collated: 5200 users
# Users page 909, total collated: 5206 users
# Users page 910, total collated: 5209 users
# Users page 911, total collated: 5216 users
# Users page 912, total collated: 5220 users
# Users page 913, total collated: 5226 users
# Users page 914, total collated: 5231 users
# Users page 915, total collated: 5233 users
# Users page 916, total collated: 5240 users
# Users page 917, total collated: 5245 users
# Users page 918, total collated: 5253 users
# Users page 919, total collated: 5262 users
# Users page 920, total collated: 5268 users
# Users page 921, total collated: 5271 users
# Users page 922, total collated: 5274 users
# Users page 923, total collated: 5280 users
# Users page 924, total collated: 5282 users
# Users page 925, total collated: 5286 users
# Users page 926, total collated: 5291 users
# Users page 927, total collated: 5293 users
# Users page 928, total collated: 5299 users
# Users page 929, total collated: 5302 users
# Users page 930, total collated: 5311 users
# Users page 931, total collated: 5316 users
# Users page 932, total collated: 5321 users
# Users page 933, total collated: 5331 users
# Users page 934, total collated: 5342 users
# Users page 935, total collated: 5350 users
# Users page 936, total collated: 5357 users
# Users page 937, total collated: 5365 users
# Users page 938, total collated: 5367 users
# Users page 939, total collated: 5374 users
# Users page 940, total collated: 5384 users
# Users page 941, total collated: 5391 users
# Users page 942, total collated: 5396 users
# Users page 943, total collated: 5399 users
# Users page 944, total collated: 5404 users
# Users page 945, total collated: 5406 users
# Users page 946, total collated: 5413 users
# Users page 947, total collated: 5419 users
# Users page 948, total collated: 5426 users
# Users page 949, total collated: 5431 users
# Users page 950, total collated: 5434 users
# Users page 951, total collated: 5438 users
# Users page 952, total collated: 5442 users
# Users page 953, total collated: 5446 users
# Users page 954, total collated: 5451 users
# Users page 955, total collated: 5457 users
# Users page 956, total collated: 5463 users
# Users page 957, total collated: 5467 users
# Users page 958, total collated: 5473 users
# Users page 959, total collated: 5478 users
# Users page 960, total collated: 5484 users
# Users page 961, total collated: 5489 users
# Users page 962, total collated: 5498 users
# Users page 963, total collated: 5508 users
# Users page 964, total collated: 5513 users
# Users page 965, total collated: 5516 users
# Users page 966, total collated: 5526 users
# Users page 967, total collated: 5532 users
# Users page 968, total collated: 5538 users
# Users page 969, total collated: 5546 users
# Users page 970, total collated: 5550 users
# Users page 971, total collated: 5558 users
# Users page 972, total collated: 5566 users
# Users page 973, total collated: 5570 users
# Users page 974, total collated: 5578 users
# Users page 975, total collated: 5581 users
# Users page 976, total collated: 5588 users
# Users page 977, total collated: 5592 users
# Users page 978, total collated: 5598 users
# Users page 979, total collated: 5608 users
# Users page 980, total collated: 5613 users
# Users page 981, total collated: 5615 users
# Users page 982, total collated: 5619 users
# Users page 983, total collated: 5623 users
# Users page 984, total collated: 5628 users
# Users page 985, total collated: 5631 users
# Users page 986, total collated: 5637 users
# Users page 987, total collated: 5644 users
# Users page 988, total collated: 5649 users
# Users page 989, total collated: 5651 users
# Users page 990, total collated: 5655 users
# Users page 991, total collated: 5661 users
# Users page 992, total collated: 5665 users
# Users page 993, total collated: 5668 users
# Users page 994, total collated: 5669 users
# Users page 995, total collated: 5671 users
# Users page 996, total collated: 5674 users
# Users page 997, total collated: 5678 users
# Users page 998, total collated: 5681 users
# Users page 999, total collated: 5684 users
# Users page 1000, total collated: 5690 users
# Users page 1001, total collated: 5697 users
# Users page 1002, total collated: 5704 users
# Users page 1003, total collated: 5709 users
# Users page 1004, total collated: 5712 users
# Users page 1005, total collated: 5715 users
# Users page 1006, total collated: 5719 users
# Users page 1007, total collated: 5722 users
# Users page 1008, total collated: 5723 users
# Users page 1009, total collated: 5727 users
# Users page 1010, total collated: 5730 users
# Users page 1011, total collated: 5734 users
# Users page 1012, total collated: 5736 users
# Users page 1013, total collated: 5740 users
# Users page 1014, total collated: 5747 users
# Users page 1015, total collated: 5755 users
# Users page 1016, total collated: 5760 users
# Users page 1017, total collated: 5766 users
# Users page 1018, total collated: 5774 users
# Users page 1019, total collated: 5777 users
# Users page 1020, total collated: 5779 users
# Users page 1021, total collated: 5781 users
# Users page 1022, total collated: 5786 users
# Users page 1023, total collated: 5789 users
# Users page 1024, total collated: 5797 users
# Users page 1025, total collated: 5799 users
# Users page 1026, total collated: 5805 users
# Users page 1027, total collated: 5807 users
# Users page 1028, total collated: 5810 users
# Users page 1029, total collated: 5815 users
# Users page 1030, total collated: 5817 users
# Users page 1031, total collated: 5823 users
# Users page 1032, total collated: 5828 users
# Users page 1033, total collated: 5837 users
# Users page 1034, total collated: 5844 users
# Users page 1035, total collated: 5846 users
# Users page 1036, total collated: 5849 users
# Users page 1037, total collated: 5851 users
# Users page 1038, total collated: 5854 users
# Users page 1039, total collated: 5855 users
# Users page 1040, total collated: 5863 users
# Users page 1041, total collated: 5869 users
# Users page 1042, total collated: 5873 users
# Users page 1043, total collated: 5878 users
# Users page 1044, total collated: 5881 users
# Users page 1045, total collated: 5885 users
# Users page 1046, total collated: 5889 users
# Users page 1047, total collated: 5895 users
# Users page 1048, total collated: 5898 users
# Users page 1049, total collated: 5904 users
# Users page 1050, total collated: 5908 users
# Users page 1051, total collated: 5912 users
# Users page 1052, total collated: 5917 users
# Users page 1053, total collated: 5921 users
# Users page 1054, total collated: 5927 users
# Users page 1055, total collated: 5928 users
# Users page 1056, total collated: 5930 users
# Users page 1057, total collated: 5933 users
# Users page 1058, total collated: 5937 users
# Users page 1059, total collated: 5940 users
# Users page 1060, total collated: 5941 users
# Users page 1061, total collated: 5945 users
# Users page 1062, total collated: 5953 users
# Users page 1063, total collated: 5957 users
# Users page 1064, total collated: 5959 users
# Users page 1065, total collated: 5964 users
# Users page 1066, total collated: 5969 users
# Users page 1067, total collated: 5973 users
# Users page 1068, total collated: 5975 users
# Users page 1069, total collated: 5976 users
# Users page 1070, total collated: 5980 users
# Users page 1071, total collated: 5984 users
# Users page 1072, total collated: 5988 users
# Users page 1073, total collated: 5990 users
# Users page 1074, total collated: 5999 users
# Users page 1075, total collated: 6005 users
# Users page 1076, total collated: 6009 users
# Users page 1077, total collated: 6013 users
# Users page 1078, total collated: 6022 users
# Users page 1079, total collated: 6032 users
# Users page 1080, total collated: 6034 users
# Users page 1081, total collated: 6037 users
# Users page 1082, total collated: 6044 users
# Users page 1083, total collated: 6045 users
# Users page 1084, total collated: 6048 users
# Users page 1085, total collated: 6051 users
# Users page 1086, total collated: 6055 users
# Users page 1087, total collated: 6059 users
# Users page 1088, total collated: 6062 users
# Users page 1089, total collated: 6065 users
# Users page 1090, total collated: 6067 users
# Users page 1091, total collated: 6070 users
# Users page 1092, total collated: 6076 users
# Users page 1093, total collated: 6080 users
# Users page 1094, total collated: 6082 users
# Users page 1095, total collated: 6087 users
# Users page 1096, total collated: 6091 users
# Users page 1097, total collated: 6095 users
# Users page 1098, total collated: 6100 users
# Users page 1099, total collated: 6105 users
# Users page 1100, total collated: 6107 users
# Users page 1101, total collated: 6111 users
# Users page 1102, total collated: 6113 users
# Users page 1103, total collated: 6116 users
# Users page 1104, total collated: 6119 users
# Users page 1105, total collated: 6124 users
# Users page 1106, total collated: 6126 users
# Users page 1107, total collated: 6131 users
# Users page 1108, total collated: 6133 users
# Users page 1109, total collated: 6134 users
# Users page 1110, total collated: 6139 users
# Users page 1111, total collated: 6142 users
# Users page 1112, total collated: 6148 users
# Users page 1113, total collated: 6152 users
# Users page 1114, total collated: 6160 users
# Users page 1115, total collated: 6167 users
# Users page 1116, total collated: 6172 users
# Users page 1117, total collated: 6174 users
# Users page 1118, total collated: 6177 users
# Users page 1119, total collated: 6180 users
# ...
# Users page 12661, total collated: 131189 users
# Users page 12662, total collated: 131205 users
# Users page 12663, total collated: 131216 users
# Users page 12664, total collated: 131229 users
# Users page 12665, total collated: 131244 users
# Users page 12666, total collated: 131254 users
# Users page 12667, total collated: 131266 users
# Users page 12668, total collated: 131284 users
# Users page 12669, total collated: 131299 users
# Users page 12670, total collated: 131316 users
# Users page 12671, total collated: 131327 users
# Users page 12672, total collated: 131341 users
# Users page 12673, total collated: 131356 users
# Users page 12674, total collated: 131373 users
# Users page 12675, total collated: 131388 users
# Users page 12676, total collated: 131400 users
# Users page 12677, total collated: 131414 users
# Users page 12678, total collated: 131430 users
# Users page 12679, total collated: 131446 users
# Users page 12680, total collated: 131454 users
# Users page 12681, total collated: 131471 users
# Users page 12682, total collated: 131482 users
# Users page 12683, total collated: 131495 users
# Users page 12684, total collated: 131509 users
# Users page 12685, total collated: 131524 users
# Users page 12686, total collated: 131538 users
# Users page 12687, total collated: 131552 users
# Users page 12688, total collated: 131571 users
# Users page 12689, total collated: 131588 users
# Users page 12690, total collated: 131606 users
# Users page 12691, total collated: 131617 users
# Users page 12692, total collated: 131635 users
# Users page 12693, total collated: 131649 users
# Users page 12694, total collated: 131662 users
# Users page 12695, total collated: 131680 users
# Users page 12696, total collated: 131696 users
# Users page 12697, total collated: 131712 users
# Users page 12698, total collated: 131727 users
# Users page 12699, total collated: 131740 users
# Users page 12700, total collated: 131757 users
# Users page 12701, total collated: 131770 users
# Users page 12702, total collated: 131785 users
# Users page 12703, total collated: 131795 users
# Users page 12704, total collated: 131810 users
# Users page 12705, total collated: 131824 users
# Users page 12706, total collated: 131843 users
# Users page 12707, total collated: 131857 users
# Users page 12708, total collated: 131873 users
# Users page 12709, total collated: 131891 users
# Users page 12710, total collated: 131907 users
# Users page 12711, total collated: 131916 users
# Users page 12712, total collated: 131925 users
# Users page 12713, total collated: 131935 users
# Users page 12714, total collated: 131945 users
# Users page 12715, total collated: 131959 users
# Users page 12716, total collated: 131974 users
# Users page 12717, total collated: 131987 users
# Users page 12718, total collated: 132001 users
# Users page 12719, total collated: 132018 users
# Users page 12720, total collated: 132030 users
# Users page 12721, total collated: 132045 users
# Users page 12722, total collated: 132063 users
# Users page 12723, total collated: 132075 users
# Users page 12724, total collated: 132095 users
# Users page 12725, total collated: 132111 users
# Users page 12726, total collated: 132126 users
# Users page 12727, total collated: 132135 users
# Users page 12728, total collated: 132149 users
# Users page 12729, total collated: 132160 users
# Users page 12730, total collated: 132176 users
# Users page 12731, total collated: 132187 users
# Users page 12732, total collated: 132201 users
# Users page 12733, total collated: 132216 users
# Users page 12734, total collated: 132228 users
# Users page 12735, total collated: 132246 users
# Users page 12736, total collated: 132260 users
# Users page 12737, total collated: 132281 users
# Users page 12738, total collated: 132297 users
# Users page 12739, total collated: 132314 users
# Users page 12740, total collated: 132332 users
# Users page 12741, total collated: 132350 users
# Users page 12742, total collated: 132359 users
# Users page 12743, total collated: 132375 users
# Users page 12744, total collated: 132384 users
# Users page 12745, total collated: 132399 users
# Users page 12746, total collated: 132416 users
# Users page 12747, total collated: 132433 users
# Users page 12748, total collated: 132447 users
# Users page 12749, total collated: 132460 users
# Users page 12750, total collated: 132480 users
# Users page 12751, total collated: 132495 users
# Users page 12752, total collated: 132508 users
# Users page 12753, total collated: 132522 users
# Users page 12754, total collated: 132537 users
# Users page 12755, total collated: 132556 users
# Users page 12756, total collated: 132569 users
# Users page 12757, total collated: 132587 users
# Users page 12758, total collated: 132604 users
# Users page 12759, total collated: 132616 users
# Users page 12760, total collated: 132626 users
# Users page 12761, total collated: 132645 users
# Users page 12762, total collated: 132656 users
# Users page 12763, total collated: 132674 users
# Users page 12764, total collated: 132688 users
# Users page 12765, total collated: 132707 users
# Users page 12766, total collated: 132728 users
# Users page 12767, total collated: 132741 users
# Users page 12768, total collated: 132759 users
# Users page 12769, total collated: 132775 users
# Users page 12770, total collated: 132792 users
# Users page 12771, total collated: 132808 users
# Users page 12772, total collated: 132822 users
# Users page 12773, total collated: 132841 users
# Users page 12774, total collated: 132860 users
# Users page 12775, total collated: 132884 users
# Users page 12776, total collated: 132903 users
# Users page 12777, total collated: 132911 users
# Users page 12778, total collated: 132926 users
# Users page 12779, total collated: 132940 users
# Users page 12780, total collated: 132960 users
# Users page 12781, total collated: 132978 users
# Users page 12782, total collated: 132993 users
# Users page 12783, total collated: 133006 users
# Users page 12784, total collated: 133018 users
# Users page 12785, total collated: 133037 users
# Users page 12786, total collated: 133052 users
# Users page 12787, total collated: 133067 users
# Users page 12788, total collated: 133079 users
# Users page 12789, total collated: 133096 users
# Users page 12790, total collated: 133115 users
# Users page 12791, total collated: 133134 users
# Users page 12792, total collated: 133150 users
# Users page 12793, total collated: 133166 users
# Users page 12794, total collated: 133180 users
# Users page 12795, total collated: 133196 users
# Users page 12796, total collated: 133208 users
# Users page 12797, total collated: 133222 users
# Users page 12798, total collated: 133235 users
# Users page 12799, total collated: 133254 users
# Users page 12800, total collated: 133271 users
# Users page 12801, total collated: 133285 users
# Users page 12802, total collated: 133299 users
# Users page 12803, total collated: 133317 users
# Users page 12804, total collated: 133331 users
# Users page 12805, total collated: 133346 users
# Users page 12806, total collated: 133372 users
# Users page 12807, total collated: 133388 users
# Users page 12808, total collated: 133409 users
# Users page 12809, total collated: 133431 users
# Users page 12810, total collated: 133447 users
# Users page 12811, total collated: 133461 users
# Users page 12812, total collated: 133475 users
# Users page 12813, total collated: 133490 users
# Users page 12814, total collated: 133501 users
# Users page 12815, total collated: 133511 users
# Users page 12816, total collated: 133529 users
# Users page 12817, total collated: 133548 users
# Users page 12818, total collated: 133567 users
# Users page 12819, total collated: 133582 users
# Users page 12820, total collated: 133596 users
# Users page 12821, total collated: 133612 users
# Users page 12822, total collated: 133626 users
# Users page 12823, total collated: 133642 users
# Users page 12824, total collated: 133665 users
# Users page 12825, total collated: 133684 users
# Users page 12826, total collated: 133700 users
# Users page 12827, total collated: 133717 users
# Users page 12828, total collated: 133732 users
# Users page 12829, total collated: 133749 users
# Users page 12830, total collated: 133763 users
# Users page 12831, total collated: 133775 users
# Users page 12832, total collated: 133794 users
# Users page 12833, total collated: 133811 users
# Users page 12834, total collated: 133823 users
# Users page 12835, total collated: 133836 users
# Users page 12836, total collated: 133853 users
# Users page 12837, total collated: 133869 users
# Users page 12838, total collated: 133882 users
# Users page 12839, total collated: 133892 users
# Users page 12840, total collated: 133908 users
# Users page 12841, total collated: 133919 users
# Users page 12842, total collated: 133934 users
# Users page 12843, total collated: 133949 users
# Users page 12844, total collated: 133962 users
# Users page 12845, total collated: 133975 users
# Users page 12846, total collated: 133989 users
# Users page 12847, total collated: 134005 users
# Users page 12848, total collated: 134024 users
# Users page 12849, total collated: 134044 users
# Users page 12850, total collated: 134061 users
# Users page 12851, total collated: 134085 users
# Users page 12852, total collated: 134103 users
# Users page 12853, total collated: 134117 users
# Users page 12854, total collated: 134137 users
# Users page 12855, total collated: 134150 users
# Users page 12856, total collated: 134162 users
# Users page 12857, total collated: 134176 users
# Users page 12858, total collated: 134192 users
# Users page 12859, total collated: 134211 users
# Users page 12860, total collated: 134227 users
# Users page 12861, total collated: 134239 users
# Users page 12862, total collated: 134255 users
# Users page 12863, total collated: 134272 users
# Users page 12864, total collated: 134281 users
# Users page 12865, total collated: 134300 users
# Users page 12866, total collated: 134316 users
# Users page 12867, total collated: 134331 users
# Users page 12868, total collated: 134353 users
# Users page 12869, total collated: 134368 users
# Users page 12870, total collated: 134384 users
# Users page 12871, total collated: 134393 users
# Users page 12872, total collated: 134404 users
# Users page 12873, total collated: 134411 users
# Users page 12874, total collated: 134430 users
# Users page 12875, total collated: 134443 users
# Users page 12876, total collated: 134458 users
# Users page 12877, total collated: 134475 users
# Users page 12878, total collated: 134492 users
# Users page 12879, total collated: 134513 users
# Users page 12880, total collated: 134531 users
# Users page 12881, total collated: 134543 users
# Users page 12882, total collated: 134562 users
# Users page 12883, total collated: 134581 users
# Users page 12884, total collated: 134596 users
# Users page 12885, total collated: 134612 users
# Users page 12886, total collated: 134628 users
# Users page 12887, total collated: 134641 users
# Users page 12888, total collated: 134657 users
# Users page 12889, total collated: 134672 users
# Users page 12890, total collated: 134684 users
# Users page 12891, total collated: 134699 users
# Users page 12892, total collated: 134709 users
# Users page 12893, total collated: 134726 users
# Users page 12894, total collated: 134749 users
# Users page 12895, total collated: 134772 users
# Users page 12896, total collated: 134788 users
# Users page 12897, total collated: 134801 users
# Users page 12898, total collated: 134815 users
# Users page 12899, total collated: 134831 users
# Users page 12900, total collated: 134848 users
# Users page 12901, total collated: 134866 users
# Users page 12902, total collated: 134879 users
# Users page 12903, total collated: 134896 users
# Users page 12904, total collated: 134915 users
# Users page 12905, total collated: 134927 users
# Users page 12906, total collated: 134947 users
# Users page 12907, total collated: 134965 users
# Users page 12908, total collated: 134979 users
# Users page 12909, total collated: 135002 users
# Users page 12910, total collated: 135020 users
# Users page 12911, total collated: 135039 users
# Users page 12912, total collated: 135061 users
# Users page 12913, total collated: 135081 users
# Users page 12914, total collated: 135094 users
# Users page 12915, total collated: 135109 users
# Users page 12916, total collated: 135123 users
# Users page 12917, total collated: 135142 users
# Users page 12918, total collated: 135158 users
# Users page 12919, total collated: 135173 users
# Users page 12920, total collated: 135186 users
# Users page 12921, total collated: 135200 users
# Users page 12922, total collated: 135212 users
# Users page 12923, total collated: 135224 users
# Users page 12924, total collated: 135237 users
# Users page 12925, total collated: 135250 users
# Users page 12926, total collated: 135265 users
# Users page 12927, total collated: 135285 users
# Users page 12928, total collated: 135304 users
# Users page 12929, total collated: 135321 users
# Users page 12930, total collated: 135338 users
# Users page 12931, total collated: 135345 users
# Users page 12932, total collated: 135359 users
# Users page 12933, total collated: 135377 users
# Users page 12934, total collated: 135389 users
# Users page 12935, total collated: 135406 users
# Users page 12936, total collated: 135417 users
# Users page 12937, total collated: 135434 users
# Users page 12938, total collated: 135452 users
# Users page 12939, total collated: 135463 users
# Users page 12940, total collated: 135479 users
# Users page 12941, total collated: 135494 users
# Users page 12942, total collated: 135519 users
# Users page 12943, total collated: 135533 users
# Users page 12944, total collated: 135548 users
# Users page 12945, total collated: 135567 users
# Users page 12946, total collated: 135576 users
# Users page 12947, total collated: 135590 users
# Users page 12948, total collated: 135610 users
# Users page 12949, total collated: 135628 users
# Users page 12950, total collated: 135647 users
# Users page 12951, total collated: 135667 users
# Users page 12952, total collated: 135679 users
# Users page 12953, total collated: 135694 users
# Users page 12954, total collated: 135711 users
# Users page 12955, total collated: 135728 users
# Users page 12956, total collated: 135745 users
# Users page 12957, total collated: 135760 users
# Users page 12958, total collated: 135776 users
# Users page 12959, total collated: 135789 users
# Users page 12960, total collated: 135808 users
# Users page 12961, total collated: 135824 users
# Users page 12962, total collated: 135843 users
# Users page 12963, total collated: 135855 users
# Users page 12964, total collated: 135868 users
# Users page 12965, total collated: 135885 users
# Users page 12966, total collated: 135908 users
# Users page 12967, total collated: 135924 users
# Users page 12968, total collated: 135940 users
# Users page 12969, total collated: 135957 users
# Users page 12970, total collated: 135973 users
# Users page 12971, total collated: 135993 users
# Users page 12972, total collated: 136011 users
# Users page 12973, total collated: 136036 users
# Users page 12974, total collated: 136052 users
# Users page 12975, total collated: 136067 users
# Users page 12976, total collated: 136089 users
# Users page 12977, total collated: 136109 users
# Users page 12978, total collated: 136125 users
# Users page 12979, total collated: 136143 users
# Users page 12980, total collated: 136160 users
# Users page 12981, total collated: 136175 users
# Users page 12982, total collated: 136188 users
# Users page 12983, total collated: 136199 users
# Users page 12984, total collated: 136216 users
# Users page 12985, total collated: 136235 users
# Users page 12986, total collated: 136254 users
# Users page 12987, total collated: 136272 users
# Users page 12988, total collated: 136288 users
# Users page 12989, total collated: 136309 users
# Users page 12990, total collated: 136327 users
# Users page 12991, total collated: 136343 users
# Users page 12992, total collated: 136358 users
# Users page 12993, total collated: 136370 users
# Users page 12994, total collated: 136386 users
# Users page 12995, total collated: 136409 users
# Users page 12996, total collated: 136428 users
# Users page 12997, total collated: 136443 users
# Users page 12998, total collated: 136462 users
# Users page 12999, total collated: 136476 users
# Users page 13000, total collated: 136495 users

# %%
user_db_full = pd.DataFrame(api_output_users_full)

# %%
#user_db['statistics'] = user_db['statistics'].apply(lambda x: x['anime']['scores'])
user_db_full['statistics'] = user_db_full['statistics'].apply(split_scores)
user_db_full = user_db_full.join(pd.json_normalize(user_db_full['statistics']))
user_db_full = user_db_full.drop(columns=['statistics'])

# %%
print(user_db_full.shape)
user_db_full.head()
# Out:
# (127635, 13504)
#    id        name      score_format  10620    849   225  12477  1575  8460  \
# 0   2     matchai  POINT_10_DECIMAL   80.0   80.0  80.0   80.0  80.0  80.0
# 1   5  kaotikmynd           POINT_5    NaN  100.0   NaN    NaN  80.0   NaN
# 2   7  jamiejakov  POINT_10_DECIMAL   70.0   70.0   NaN    NaN  90.0   NaN
# 3  12    JesterOW          POINT_10   70.0   80.0   NaN    NaN  80.0   NaN
# 4  19      rayanp          POINT_10    NaN    NaN   NaN    NaN   NaN   NaN
#
#    6880  ...  145209  145354  111859  138565  128675  135605  139354  135801  \
# 0  80.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    140111  113138
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
# [5 rows x 13504 columns]

# %%
user_db_full.to_csv("../data/user_list_full.csv",index=False,encoding="utf-8")

# %%
d = {'userId': [1, 1, 1,2,2,2], 'mediaId': [1,2,3,1,2,3],'rating': [6,7,8,6,7,8]}
df = pd.DataFrame(d)
df
# Out:
#    userId  mediaId  rating
# 0       1        1       6
# 1       1        2       7
# 2       1        3       8
# 3       2        1       6
# 4       2        2       7
# 5       2        3       8
